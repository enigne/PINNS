# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAAllNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 5]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 50000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 0
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = False
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_segCF.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data_all(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAAllNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8,
        loss_weights=[1e-6, 1e-4, 1e-2, 1e-6])

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     5
#   ],
#   "tf_epochs": 50000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": false,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# WARNING:tensorflow:From ./utils/logger.py:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True

# %%
# train the model
pinn.fit(X_star, u_star)
# pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:15 (+15.6)  loss = 1.6523e+03
# tf_epoch =   1000  elapsed = 00:43 (+28.2)  loss = 6.9383e+00
# tf_epoch =   2000  elapsed = 01:11 (+27.3)  loss = 6.7281e+00
# tf_epoch =   3000  elapsed = 01:38 (+27.4)  loss = 6.6745e+00
# tf_epoch =   4000  elapsed = 02:05 (+27.0)  loss = 6.6505e+00
# tf_epoch =   5000  elapsed = 02:32 (+26.8)  loss = 6.6317e+00
# tf_epoch =   6000  elapsed = 03:00 (+27.6)  loss = 6.6158e+00
# tf_epoch =   7000  elapsed = 03:27 (+27.0)  loss = 6.6000e+00
# tf_epoch =   8000  elapsed = 03:54 (+27.2)  loss = 6.5807e+00
# tf_epoch =   9000  elapsed = 04:21 (+27.2)  loss = 6.5535e+00
# tf_epoch =  10000  elapsed = 04:48 (+27.0)  loss = 6.4961e+00
# tf_epoch =  11000  elapsed = 05:16 (+27.1)  loss = 5.7477e+00
# tf_epoch =  12000  elapsed = 05:42 (+26.8)  loss = 3.5113e+00
# tf_epoch =  13000  elapsed = 06:09 (+26.9)  loss = 6.5958e-01
# tf_epoch =  14000  elapsed = 06:36 (+27.0)  loss = 3.4015e-01
# tf_epoch =  15000  elapsed = 07:04 (+27.5)  loss = 2.3037e-01
# tf_epoch =  16000  elapsed = 07:31 (+27.0)  loss = 1.8507e-01
# tf_epoch =  17000  elapsed = 07:58 (+27.0)  loss = 1.5524e-01
# tf_epoch =  18000  elapsed = 08:25 (+26.9)  loss = 1.3228e-01
# tf_epoch =  19000  elapsed = 08:52 (+27.4)  loss = 1.1610e-01
# tf_epoch =  20000  elapsed = 09:19 (+26.9)  loss = 1.0450e-01
# tf_epoch =  21000  elapsed = 09:47 (+27.2)  loss = 9.7110e-02
# tf_epoch =  22000  elapsed = 10:14 (+27.2)  loss = 9.0595e-02
# tf_epoch =  23000  elapsed = 10:42 (+27.8)  loss = 8.5616e-02
# tf_epoch =  24000  elapsed = 11:09 (+27.0)  loss = 8.2128e-02
# tf_epoch =  25000  elapsed = 11:36 (+27.1)  loss = 7.8678e-02
# tf_epoch =  26000  elapsed = 12:03 (+26.9)  loss = 7.6438e-02
# tf_epoch =  27000  elapsed = 12:30 (+27.0)  loss = 7.4257e-02
# tf_epoch =  28000  elapsed = 12:57 (+26.9)  loss = 7.1606e-02
# tf_epoch =  29000  elapsed = 13:24 (+26.9)  loss = 7.0674e-02
# tf_epoch =  30000  elapsed = 13:51 (+27.6)  loss = 6.8528e-02
# tf_epoch =  31000  elapsed = 14:18 (+26.9)  loss = 6.6341e-02
# tf_epoch =  32000  elapsed = 14:46 (+27.5)  loss = 6.5036e-02
# tf_epoch =  33000  elapsed = 15:13 (+27.0)  loss = 6.7144e-02
# tf_epoch =  34000  elapsed = 15:41 (+27.7)  loss = 6.2277e-02
# tf_epoch =  35000  elapsed = 16:08 (+27.0)  loss = 6.2216e-02
# tf_epoch =  36000  elapsed = 16:35 (+26.9)  loss = 6.0167e-02
# tf_epoch =  37000  elapsed = 17:02 (+27.1)  loss = 5.8750e-02
# tf_epoch =  38000  elapsed = 17:29 (+26.8)  loss = 5.6325e-02
# tf_epoch =  39000  elapsed = 17:56 (+26.9)  loss = 5.5077e-02
# tf_epoch =  40000  elapsed = 18:23 (+27.1)  loss = 6.6319e-02
# tf_epoch =  41000  elapsed = 18:50 (+27.0)  loss = 6.0376e-02
# tf_epoch =  42000  elapsed = 19:17 (+27.3)  loss = 5.2785e-02
# tf_epoch =  43000  elapsed = 19:44 (+27.1)  loss = 5.1372e-02
# tf_epoch =  44000  elapsed = 20:11 (+26.9)  loss = 5.0049e-02
# tf_epoch =  45000  elapsed = 20:38 (+27.0)  loss = 4.9259e-02
# tf_epoch =  46000  elapsed = 21:05 (+26.9)  loss = 4.8966e-02
# tf_epoch =  47000  elapsed = 21:32 (+26.9)  loss = 4.9652e-02
# tf_epoch =  48000  elapsed = 21:59 (+27.0)  loss = 5.3753e-02
# tf_epoch =  49000  elapsed = 22:26 (+26.8)  loss = 4.7009e-02
# -- Starting LBFGS optimization --
# ==================
# Training finished (epoch 50000): duration = 22:53  error = 3.0757e-01

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub)

# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
