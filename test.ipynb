# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAAllNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 5]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 10000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 10000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_segCF.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data_all(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAAllNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8,
        loss_weights=[1e-6, 1e-3, 1e-2, 1e-6])

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     5
#   ],
#   "tf_epochs": 10000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 1000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 100,
#   "use_tfp": true,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# train the model
pinn.fit(X_star, u_star)
# pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:15 (+15.7)  loss = 1.7110e+03
# tf_epoch =    100  elapsed = 00:18 (+02.6)  loss = 5.6484e+01
# tf_epoch =    200  elapsed = 00:21 (+02.6)  loss = 2.0605e+01
# tf_epoch =    300  elapsed = 00:23 (+02.6)  loss = 1.7824e+01
# tf_epoch =    400  elapsed = 00:26 (+02.6)  loss = 1.1706e+01
# tf_epoch =    500  elapsed = 00:29 (+02.6)  loss = 1.0566e+01
# tf_epoch =    600  elapsed = 00:31 (+02.6)  loss = 9.7354e+00
# tf_epoch =    700  elapsed = 00:34 (+02.6)  loss = 9.3881e+00
# tf_epoch =    800  elapsed = 00:37 (+02.6)  loss = 9.2180e+00
# tf_epoch =    900  elapsed = 00:39 (+02.6)  loss = 9.1022e+00
# tf_epoch =   1000  elapsed = 00:42 (+02.6)  loss = 9.0064e+00
# tf_epoch =   1100  elapsed = 00:45 (+02.6)  loss = 8.9298e+00
# tf_epoch =   1200  elapsed = 00:47 (+02.6)  loss = 8.8561e+00
# tf_epoch =   1300  elapsed = 00:50 (+02.6)  loss = 8.7883e+00
# tf_epoch =   1400  elapsed = 00:53 (+02.6)  loss = 8.7243e+00
# tf_epoch =   1500  elapsed = 00:55 (+02.6)  loss = 8.6643e+00
# tf_epoch =   1600  elapsed = 00:58 (+02.6)  loss = 8.6072e+00
# tf_epoch =   1700  elapsed = 01:01 (+02.6)  loss = 8.5513e+00
# tf_epoch =   1800  elapsed = 01:03 (+02.6)  loss = 8.5031e+00
# tf_epoch =   1900  elapsed = 01:06 (+02.6)  loss = 8.4567e+00
# tf_epoch =   2000  elapsed = 01:09 (+02.6)  loss = 8.4217e+00
# tf_epoch =   2100  elapsed = 01:11 (+02.6)  loss = 8.3935e+00
# tf_epoch =   2200  elapsed = 01:14 (+02.6)  loss = 8.3685e+00
# tf_epoch =   2300  elapsed = 01:17 (+02.6)  loss = 8.3465e+00
# tf_epoch =   2400  elapsed = 01:19 (+02.6)  loss = 8.3256e+00
# tf_epoch =   2500  elapsed = 01:22 (+02.6)  loss = 8.3058e+00
# tf_epoch =   2600  elapsed = 01:25 (+02.6)  loss = 8.2867e+00
# tf_epoch =   2700  elapsed = 01:27 (+02.6)  loss = 8.2681e+00
# tf_epoch =   2800  elapsed = 01:30 (+02.6)  loss = 8.2495e+00
# tf_epoch =   2900  elapsed = 01:33 (+02.6)  loss = 8.2307e+00
# tf_epoch =   3000  elapsed = 01:35 (+02.6)  loss = 8.2117e+00
# tf_epoch =   3100  elapsed = 01:38 (+02.6)  loss = 8.1921e+00
# tf_epoch =   3200  elapsed = 01:41 (+02.6)  loss = 8.1716e+00
# tf_epoch =   3300  elapsed = 01:43 (+02.6)  loss = 8.1501e+00
# tf_epoch =   3400  elapsed = 01:46 (+02.6)  loss = 8.1272e+00
# tf_epoch =   3500  elapsed = 01:49 (+02.6)  loss = 8.1026e+00
# tf_epoch =   3600  elapsed = 01:51 (+02.6)  loss = 8.0764e+00
# tf_epoch =   3700  elapsed = 01:54 (+02.6)  loss = 8.0481e+00
# tf_epoch =   3800  elapsed = 01:57 (+02.6)  loss = 8.0175e+00
# tf_epoch =   3900  elapsed = 02:00 (+02.6)  loss = 7.9846e+00
# tf_epoch =   4000  elapsed = 02:02 (+02.6)  loss = 7.9492e+00
# tf_epoch =   4100  elapsed = 02:05 (+02.6)  loss = 7.9111e+00
# tf_epoch =   4200  elapsed = 02:08 (+02.6)  loss = 7.8705e+00
# tf_epoch =   4300  elapsed = 02:10 (+02.6)  loss = 7.8281e+00
# tf_epoch =   4400  elapsed = 02:13 (+02.6)  loss = 7.7850e+00
# tf_epoch =   4500  elapsed = 02:16 (+02.6)  loss = 7.7429e+00
# tf_epoch =   4600  elapsed = 02:18 (+02.6)  loss = 7.7034e+00
# tf_epoch =   4700  elapsed = 02:21 (+02.6)  loss = 7.6675e+00
# tf_epoch =   4800  elapsed = 02:24 (+02.6)  loss = 7.6360e+00
# tf_epoch =   4900  elapsed = 02:26 (+02.6)  loss = 7.6099e+00
# tf_epoch =   5000  elapsed = 02:29 (+02.7)  loss = 7.5878e+00
# tf_epoch =   5100  elapsed = 02:32 (+02.7)  loss = 7.5685e+00
# tf_epoch =   5200  elapsed = 02:34 (+02.7)  loss = 7.5515e+00
# tf_epoch =   5300  elapsed = 02:37 (+02.7)  loss = 7.5363e+00
# tf_epoch =   5400  elapsed = 02:40 (+02.6)  loss = 7.5223e+00
# tf_epoch =   5500  elapsed = 02:42 (+02.6)  loss = 7.5090e+00
# tf_epoch =   5600  elapsed = 02:45 (+02.6)  loss = 7.4960e+00
# tf_epoch =   5700  elapsed = 02:48 (+02.6)  loss = 7.4834e+00
# tf_epoch =   5800  elapsed = 02:51 (+02.6)  loss = 7.4705e+00
# tf_epoch =   5900  elapsed = 02:53 (+02.6)  loss = 7.4576e+00
# tf_epoch =   6000  elapsed = 02:56 (+02.6)  loss = 7.4449e+00
# tf_epoch =   6100  elapsed = 02:59 (+02.6)  loss = 7.4320e+00
# tf_epoch =   6200  elapsed = 03:01 (+02.6)  loss = 7.4179e+00
# tf_epoch =   6300  elapsed = 03:04 (+02.6)  loss = 7.4028e+00
# tf_epoch =   6400  elapsed = 03:07 (+02.6)  loss = 7.3865e+00
# tf_epoch =   6500  elapsed = 03:09 (+02.6)  loss = 7.3697e+00
# tf_epoch =   6600  elapsed = 03:12 (+02.6)  loss = 7.3494e+00
# tf_epoch =   6700  elapsed = 03:15 (+02.6)  loss = 7.3282e+00
# tf_epoch =   6800  elapsed = 03:17 (+02.6)  loss = 7.3022e+00
# tf_epoch =   6900  elapsed = 03:20 (+02.6)  loss = 7.2731e+00
# tf_epoch =   7000  elapsed = 03:23 (+02.6)  loss = 7.2353e+00
# tf_epoch =   7100  elapsed = 03:25 (+02.6)  loss = 7.1849e+00
# tf_epoch =   7200  elapsed = 03:28 (+02.7)  loss = 7.1229e+00
# tf_epoch =   7300  elapsed = 03:31 (+02.6)  loss = 7.0441e+00
# tf_epoch =   7400  elapsed = 03:33 (+02.6)  loss = 6.9524e+00
# tf_epoch =   7500  elapsed = 03:36 (+02.6)  loss = 6.8345e+00
# tf_epoch =   7600  elapsed = 03:39 (+02.6)  loss = 6.6827e+00
# tf_epoch =   7700  elapsed = 03:41 (+02.6)  loss = 6.4682e+00
# tf_epoch =   7800  elapsed = 03:44 (+02.6)  loss = 6.1799e+00
# tf_epoch =   7900  elapsed = 03:47 (+02.6)  loss = 5.8006e+00
# tf_epoch =   8000  elapsed = 03:49 (+02.6)  loss = 5.3355e+00
# tf_epoch =   8100  elapsed = 03:52 (+02.6)  loss = 4.8486e+00
# tf_epoch =   8200  elapsed = 03:55 (+02.6)  loss = 4.3720e+00
# tf_epoch =   8300  elapsed = 03:57 (+02.6)  loss = 3.9419e+00
# tf_epoch =   8400  elapsed = 04:00 (+02.6)  loss = 3.5937e+00
# tf_epoch =   8500  elapsed = 04:03 (+02.6)  loss = 3.2750e+00
# tf_epoch =   8600  elapsed = 04:06 (+02.6)  loss = 2.9541e+00
# tf_epoch =   8700  elapsed = 04:08 (+02.6)  loss = 2.6380e+00
# tf_epoch =   8800  elapsed = 04:11 (+02.6)  loss = 2.3578e+00
# tf_epoch =   8900  elapsed = 04:14 (+02.7)  loss = 2.0965e+00
# tf_epoch =   9000  elapsed = 04:17 (+02.9)  loss = 1.8614e+00
# tf_epoch =   9100  elapsed = 04:19 (+02.7)  loss = 1.6690e+00
# tf_epoch =   9200  elapsed = 04:22 (+02.8)  loss = 1.4805e+00
# tf_epoch =   9300  elapsed = 04:25 (+02.6)  loss = 1.3234e+00
# tf_epoch =   9400  elapsed = 04:28 (+02.6)  loss = 1.1941e+00
# tf_epoch =   9500  elapsed = 04:30 (+02.6)  loss = 1.0942e+00
# tf_epoch =   9600  elapsed = 04:33 (+02.6)  loss = 1.0282e+00
# tf_epoch =   9700  elapsed = 04:36 (+02.6)  loss = 9.6596e-01
# tf_epoch =   9800  elapsed = 04:38 (+02.6)  loss = 9.1719e-01
# tf_epoch =   9900  elapsed = 04:41 (+02.6)  loss = 8.8201e-01
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =    100  elapsed = 04:54 (+13.4)  loss = 8.2632e-01
# nt_epoch =    200  elapsed = 04:58 (+03.4)  loss = 7.8555e-01
# nt_epoch =    300  elapsed = 05:01 (+03.5)  loss = 7.4719e-01
# nt_epoch =    400  elapsed = 05:05 (+03.5)  loss = 7.2844e-01
# nt_epoch =    500  elapsed = 05:09 (+03.5)  loss = 7.1155e-01
# nt_epoch =    600  elapsed = 05:12 (+03.4)  loss = 6.9745e-01
# nt_epoch =    700  elapsed = 05:16 (+03.5)  loss = 6.8561e-01
# nt_epoch =    800  elapsed = 05:19 (+03.5)  loss = 6.7412e-01
# nt_epoch =    900  elapsed = 05:23 (+03.6)  loss = 6.6143e-01
# ==================
# Training finished (epoch 11000): duration = 05:26  error = 2.7228e-01

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub)

# history
plot_log_history(pinn)
# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
