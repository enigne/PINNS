# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSA3NN_calvingfront_invertC
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 500
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
hp["h_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
# path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
path = os.path.join(appDataPath, "SSA2D_segCF.mat")
# path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data_all(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSA3NN_calvingfront_invertC(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        mu=1.1060e8,
        loss_weights=[1e-1, 1e-2, 1e-2, 1e-4, 1e-12])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 500,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "h_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "C_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# train the model
pinn.fit(X_u_train, u_train)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer (MinmaxSc (None, 2)                 6
# _________________________________________________________________
# dense (Dense)                (None, 20)                60
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 42
# _________________________________________________________________
# up_scale_layer (UpScaleLayer (None, 2)                 6
# =================================================================
# Total params: 3,054
# Trainable params: 3,042
# Non-trainable params: 12
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_1 (Minmax (None, 2)                 6
# _________________________________________________________________
# dense_9 (Dense)              (None, 20)                60
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_14 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 42
# _________________________________________________________________
# up_scale_layer_1 (UpScaleLay (None, 2)                 6
# =================================================================
# Total params: 3,054
# Trainable params: 3,042
# Non-trainable params: 12
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_2 (Minmax (None, 2)                 6
# _________________________________________________________________
# dense_18 (Dense)             (None, 20)                60
# _________________________________________________________________
# dense_19 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_20 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_21 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_22 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_23 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_24 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_25 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 21
# _________________________________________________________________
# up_scale_layer_2 (UpScaleLay (None, 1)                 4
# =================================================================
# Total params: 3,031
# Trainable params: 3,021
# Non-trainable params: 10
# _________________________________________________________________
# (None, None, None)
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:25 (+25.8)  loss = 2.2495e+06
# tf_epoch =   1000  elapsed = 01:00 (+34.8)  loss = 1.9162e+04
# tf_epoch =   2000  elapsed = 01:36 (+35.9)  loss = 5.3197e+03
# tf_epoch =   3000  elapsed = 02:09 (+33.3)  loss = 2.9388e+03
# tf_epoch =   4000  elapsed = 02:43 (+33.7)  loss = 2.3003e+04
# tf_epoch =   5000  elapsed = 03:17 (+33.4)  loss = 2.3658e+03
# tf_epoch =   6000  elapsed = 03:50 (+33.4)  loss = 1.5530e+03
# tf_epoch =   7000  elapsed = 04:24 (+33.4)  loss = 1.1360e+03
# tf_epoch =   8000  elapsed = 04:57 (+33.4)  loss = 1.1360e+03
# tf_epoch =   9000  elapsed = 05:30 (+33.4)  loss = 3.8015e+03
# tf_epoch =  10000  elapsed = 06:04 (+33.5)  loss = 1.0122e+03
# tf_epoch =  11000  elapsed = 06:37 (+33.4)  loss = 7.8405e+02
# tf_epoch =  12000  elapsed = 07:11 (+33.5)  loss = 5.1510e+02
# tf_epoch =  13000  elapsed = 07:44 (+33.4)  loss = 3.5824e+02
# tf_epoch =  14000  elapsed = 08:18 (+33.6)  loss = 2.5360e+02
# tf_epoch =  15000  elapsed = 08:52 (+33.4)  loss = 2.0731e+02
# tf_epoch =  16000  elapsed = 09:25 (+33.3)  loss = 1.6132e+02
# tf_epoch =  17000  elapsed = 09:58 (+33.3)  loss = 1.4876e+02
# tf_epoch =  18000  elapsed = 10:32 (+33.5)  loss = 1.2070e+02
# tf_epoch =  19000  elapsed = 11:05 (+33.5)  loss = 1.0743e+02
# tf_epoch =  20000  elapsed = 11:39 (+33.5)  loss = 9.7375e+01
# tf_epoch =  21000  elapsed = 12:12 (+33.4)  loss = 9.6445e+01
# tf_epoch =  22000  elapsed = 12:46 (+33.4)  loss = 8.4269e+01
# tf_epoch =  23000  elapsed = 13:19 (+33.1)  loss = 8.2284e+01
# tf_epoch =  24000  elapsed = 13:52 (+33.4)  loss = 8.4158e+01
# tf_epoch =  25000  elapsed = 14:26 (+33.7)  loss = 8.8721e+01
# tf_epoch =  26000  elapsed = 15:00 (+33.6)  loss = 6.9984e+01
# tf_epoch =  27000  elapsed = 15:33 (+33.5)  loss = 8.0407e+01
# tf_epoch =  28000  elapsed = 16:07 (+33.6)  loss = 6.7670e+01
# tf_epoch =  29000  elapsed = 16:40 (+33.4)  loss = 6.8205e+01
# tf_epoch =  30000  elapsed = 17:14 (+33.3)  loss = 7.0554e+01
# tf_epoch =  31000  elapsed = 17:47 (+33.3)  loss = 5.7638e+01
# tf_epoch =  32000  elapsed = 18:21 (+33.5)  loss = 6.6531e+01
# tf_epoch =  33000  elapsed = 18:54 (+33.7)  loss = 6.0149e+01
# tf_epoch =  34000  elapsed = 19:28 (+33.2)  loss = 6.0395e+01
# tf_epoch =  35000  elapsed = 20:01 (+33.4)  loss = 5.1569e+01
# tf_epoch =  36000  elapsed = 20:35 (+33.5)  loss = 6.3065e+01
# tf_epoch =  37000  elapsed = 21:08 (+33.4)  loss = 5.8507e+01
# tf_epoch =  38000  elapsed = 21:41 (+33.2)  loss = 5.7308e+01
# tf_epoch =  39000  elapsed = 22:15 (+33.7)  loss = 4.6954e+01
# tf_epoch =  40000  elapsed = 22:49 (+33.5)  loss = 5.8000e+01
# tf_epoch =  41000  elapsed = 23:22 (+33.5)  loss = 5.5545e+01
# tf_epoch =  42000  elapsed = 23:56 (+33.5)  loss = 4.1978e+01
# tf_epoch =  43000  elapsed = 24:29 (+33.0)  loss = 4.6610e+01
# tf_epoch =  44000  elapsed = 25:02 (+33.4)  loss = 4.8847e+01
# tf_epoch =  45000  elapsed = 25:36 (+33.7)  loss = 4.4030e+01
# tf_epoch =  46000  elapsed = 26:09 (+33.3)  loss = 3.7953e+01
# tf_epoch =  47000  elapsed = 26:43 (+33.5)  loss = 4.8666e+01
# tf_epoch =  48000  elapsed = 27:17 (+33.9)  loss = 4.5244e+01
# tf_epoch =  49000  elapsed = 27:50 (+33.3)  loss = 4.2276e+01
# tf_epoch =  50000  elapsed = 28:24 (+33.4)  loss = 3.2950e+01
# tf_epoch =  51000  elapsed = 28:57 (+33.5)  loss = 3.4089e+01
# tf_epoch =  52000  elapsed = 29:31 (+33.5)  loss = 3.8003e+01
# tf_epoch =  53000  elapsed = 30:04 (+33.5)  loss = 3.8147e+01
# tf_epoch =  54000  elapsed = 30:38 (+33.5)  loss = 2.7089e+01
# tf_epoch =  55000  elapsed = 31:11 (+33.4)  loss = 2.6322e+01
# tf_epoch =  56000  elapsed = 31:45 (+33.6)  loss = 3.7362e+01
# tf_epoch =  57000  elapsed = 32:18 (+33.3)  loss = 3.3340e+01
# tf_epoch =  58000  elapsed = 32:52 (+33.3)  loss = 2.6475e+01
# tf_epoch =  59000  elapsed = 33:25 (+33.4)  loss = 2.5927e+01
# tf_epoch =  60000  elapsed = 33:58 (+33.3)  loss = 3.2867e+01
# tf_epoch =  61000  elapsed = 34:32 (+33.3)  loss = 2.2752e+01
# tf_epoch =  62000  elapsed = 35:05 (+33.6)  loss = 3.0863e+01
# tf_epoch =  63000  elapsed = 35:39 (+33.3)  loss = 2.4614e+01
# tf_epoch =  64000  elapsed = 36:12 (+33.4)  loss = 2.0869e+01
# tf_epoch =  65000  elapsed = 36:45 (+33.3)  loss = 2.9384e+01
# tf_epoch =  66000  elapsed = 37:19 (+33.7)  loss = 2.8738e+01
# tf_epoch =  67000  elapsed = 37:53 (+33.5)  loss = 3.0218e+01
# tf_epoch =  68000  elapsed = 38:26 (+33.3)  loss = 2.5113e+01
# tf_epoch =  69000  elapsed = 39:00 (+33.4)  loss = 2.5815e+01
# tf_epoch =  70000  elapsed = 39:33 (+33.6)  loss = 2.2508e+01
# tf_epoch =  71000  elapsed = 40:06 (+33.3)  loss = 1.8566e+01
# tf_epoch =  72000  elapsed = 40:40 (+33.7)  loss = 2.9641e+01
# tf_epoch =  73000  elapsed = 41:14 (+33.5)  loss = 2.4185e+01
# tf_epoch =  74000  elapsed = 41:47 (+33.4)  loss = 1.7508e+01
# tf_epoch =  75000  elapsed = 42:20 (+33.3)  loss = 2.4583e+01
# tf_epoch =  76000  elapsed = 42:54 (+33.4)  loss = 2.3451e+01
# tf_epoch =  77000  elapsed = 43:27 (+33.4)  loss = 1.6753e+01
# tf_epoch =  78000  elapsed = 44:01 (+33.3)  loss = 1.6475e+01
# tf_epoch =  79000  elapsed = 44:34 (+33.3)  loss = 2.2634e+01
# tf_epoch =  80000  elapsed = 45:08 (+33.5)  loss = 2.1216e+01
# tf_epoch =  81000  elapsed = 45:41 (+33.4)  loss = 1.5499e+01
# tf_epoch =  82000  elapsed = 46:15 (+33.6)  loss = 1.7826e+01
# tf_epoch =  83000  elapsed = 46:48 (+33.3)  loss = 1.7155e+01
# tf_epoch =  84000  elapsed = 47:22 (+34.0)  loss = 2.3148e+01
# tf_epoch =  85000  elapsed = 47:55 (+33.4)  loss = 1.8229e+01
# tf_epoch =  86000  elapsed = 48:29 (+33.5)  loss = 1.6012e+01
# tf_epoch =  87000  elapsed = 49:02 (+33.0)  loss = 2.2337e+01
# tf_epoch =  88000  elapsed = 49:35 (+33.3)  loss = 2.1475e+01
# tf_epoch =  89000  elapsed = 50:09 (+33.4)  loss = 2.1144e+01
# tf_epoch =  90000  elapsed = 50:42 (+33.4)  loss = 2.1424e+01
# tf_epoch =  91000  elapsed = 51:16 (+33.6)  loss = 1.4733e+01
# tf_epoch =  92000  elapsed = 51:50 (+33.4)  loss = 1.5644e+01
# tf_epoch =  93000  elapsed = 52:23 (+33.2)  loss = 1.5456e+01
# tf_epoch =  94000  elapsed = 52:56 (+33.6)  loss = 2.0490e+01
# tf_epoch =  95000  elapsed = 53:30 (+33.4)  loss = 1.5820e+01
# tf_epoch =  96000  elapsed = 54:04 (+33.8)  loss = 2.0625e+01
# tf_epoch =  97000  elapsed = 54:38 (+34.2)  loss = 2.1412e+01
# tf_epoch =  98000  elapsed = 55:11 (+33.3)  loss = 1.3474e+01
# tf_epoch =  99000  elapsed = 55:45 (+33.1)  loss = 1.7443e+01
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =   1000  elapsed = 57:13 (+28.2)  loss = 1.2046e+01
# nt_epoch =   2000  elapsed = 57:57 (+43.7)  loss = 1.1953e+01
# nt_epoch =   3000  elapsed = 58:39 (+42.8)  loss = 1.1857e+01
# nt_epoch =   4000  elapsed = 59:21 (+42.0)  loss = 1.1762e+01
# nt_epoch =   5000  elapsed = 00:04 (+42.1)  loss = 1.1638e+01
# nt_epoch =   6000  elapsed = 00:46 (+42.2)  loss = 1.1519e+01
# nt_epoch =   7000  elapsed = 01:28 (+41.8)  loss = 1.1423e+01
# nt_epoch =   8000  elapsed = 02:09 (+41.7)  loss = 1.1292e+01
# nt_epoch =   9000  elapsed = 02:51 (+41.6)  loss = 1.1175e+01
# nt_epoch =  10000  elapsed = 03:33 (+41.8)  loss = 1.1074e+01
# nt_epoch =  11000  elapsed = 04:15 (+41.7)  loss = 1.0971e+01
# nt_epoch =  12000  elapsed = 04:57 (+42.4)  loss = 1.0850e+01
# nt_epoch =  13000  elapsed = 05:41 (+43.7)  loss = 1.0673e+01
# nt_epoch =  14000  elapsed = 06:25 (+44.2)  loss = 1.0528e+01
# nt_epoch =  15000  elapsed = 07:09 (+44.0)  loss = 1.0399e+01
# nt_epoch =  16000  elapsed = 07:53 (+44.1)  loss = 1.0260e+01
# nt_epoch =  17000  elapsed = 08:37 (+43.9)  loss = 1.0127e+01
# nt_epoch =  18000  elapsed = 09:22 (+44.2)  loss = 9.9891e+00
# nt_epoch =  19000  elapsed = 10:06 (+43.9)  loss = 9.8669e+00
# nt_epoch =  20000  elapsed = 10:50 (+44.0)  loss = 9.7530e+00
# nt_epoch =  21000  elapsed = 11:34 (+44.0)  loss = 9.6575e+00
# nt_epoch =  22000  elapsed = 12:18 (+44.4)  loss = 9.5621e+00
# nt_epoch =  23000  elapsed = 13:03 (+44.4)  loss = 9.4474e+00
# nt_epoch =  24000  elapsed = 13:46 (+43.7)  loss = 9.3658e+00
# nt_epoch =  25000  elapsed = 14:31 (+44.3)  loss = 9.2834e+00
# nt_epoch =  26000  elapsed = 15:15 (+44.0)  loss = 9.1961e+00
# nt_epoch =  27000  elapsed = 15:59 (+44.0)  loss = 9.1197e+00
# nt_epoch =  28000  elapsed = 16:43 (+44.1)  loss = 9.0337e+00
# nt_epoch =  29000  elapsed = 17:27 (+43.9)  loss = 8.9538e+00
# nt_epoch =  30000  elapsed = 18:11 (+43.9)  loss = 8.8700e+00
# nt_epoch =  31000  elapsed = 18:55 (+44.0)  loss = 8.7833e+00
# nt_epoch =  32000  elapsed = 19:39 (+43.9)  loss = 8.7020e+00
# nt_epoch =  33000  elapsed = 20:23 (+44.3)  loss = 8.5954e+00
# nt_epoch =  34000  elapsed = 21:07 (+44.0)  loss = 8.4924e+00
# nt_epoch =  35000  elapsed = 21:51 (+43.7)  loss = 8.3955e+00
# nt_epoch =  36000  elapsed = 22:33 (+42.6)  loss = 8.3076e+00
# nt_epoch =  37000  elapsed = 23:16 (+42.1)  loss = 8.2263e+00
# nt_epoch =  38000  elapsed = 23:58 (+41.9)  loss = 8.1350e+00
# nt_epoch =  39000  elapsed = 24:40 (+42.1)  loss = 8.0527e+00
# nt_epoch =  40000  elapsed = 25:22 (+42.2)  loss = 7.9434e+00
# nt_epoch =  41000  elapsed = 26:04 (+42.2)  loss = 7.8692e+00
# nt_epoch =  42000  elapsed = 26:46 (+42.0)  loss = 7.7913e+00
# nt_epoch =  43000  elapsed = 27:29 (+42.1)  loss = 7.7370e+00
# nt_epoch =  44000  elapsed = 28:10 (+41.8)  loss = 7.6801e+00
# nt_epoch =  45000  elapsed = 28:52 (+41.9)  loss = 7.6056e+00
# nt_epoch =  46000  elapsed = 29:35 (+42.9)  loss = 7.5420e+00
# nt_epoch =  47000  elapsed = 30:17 (+42.1)  loss = 7.4888e+00
# nt_epoch =  48000  elapsed = 31:00 (+42.1)  loss = 7.4231e+00
# nt_epoch =  49000  elapsed = 31:42 (+42.3)  loss = 7.3695e+00
# nt_epoch =  50000  elapsed = 32:25 (+42.7)  loss = 7.3156e+00
# ==================
# Training finished (epoch 150000): duration = 32:48  error = 4.1734e-02

# %%
# plot
vranges = {}
vranges['u - u obs']=[-20, 20]
vranges['v - v obs']=[-20, 20]
vranges['H - H obs']=[-20, 20]
vranges['h - h obs']=[-20, 20]
vranges['C - C obs']=[-500, 500]
vranges['C pred']=[0, 3500]
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub, vranges)

# history
plot_log_history(pinn)
# Out:
# ./utils/plotting.py:615: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.axes.set_yscale('log')
