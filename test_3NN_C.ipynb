# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSA3NN_invertC
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 500
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
hp["h_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
# path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_segCF.mat")
# path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data_all(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSA3NN_invertC(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        mu=1.1060e8,
        loss_weights=[1e-1, 1e-2, 1e-2, 1e-4, 1e-14])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 500,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "h_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "C_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# train the model
pinn.fit(X_u_train, u_train)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer (MinmaxSc (None, 2)                 6
# _________________________________________________________________
# dense (Dense)                (None, 20)                60
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 42
# _________________________________________________________________
# up_scale_layer (UpScaleLayer (None, 2)                 6
# =================================================================
# Total params: 3,054
# Trainable params: 3,042
# Non-trainable params: 12
# _________________________________________________________________
# None
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:22 (+22.9)  loss = 2.2495e+06
# tf_epoch =   1000  elapsed = 00:53 (+30.2)  loss = 1.8292e+04
# tf_epoch =   2000  elapsed = 01:23 (+30.1)  loss = 5.9785e+03
# tf_epoch =   3000  elapsed = 01:53 (+30.1)  loss = 3.1929e+03
# tf_epoch =   4000  elapsed = 02:23 (+30.1)  loss = 1.8777e+03
# tf_epoch =   5000  elapsed = 02:53 (+30.2)  loss = 1.1408e+03
# tf_epoch =   6000  elapsed = 03:24 (+30.1)  loss = 8.1819e+02
# tf_epoch =   7000  elapsed = 03:54 (+30.2)  loss = 5.5189e+02
# tf_epoch =   8000  elapsed = 04:24 (+30.1)  loss = 3.6689e+02
# tf_epoch =   9000  elapsed = 04:54 (+30.1)  loss = 2.8907e+02
# tf_epoch =  10000  elapsed = 05:24 (+30.1)  loss = 2.3950e+02
# tf_epoch =  11000  elapsed = 05:55 (+30.5)  loss = 2.0504e+02
# tf_epoch =  12000  elapsed = 06:25 (+30.4)  loss = 1.9348e+02
# tf_epoch =  13000  elapsed = 06:56 (+30.3)  loss = 1.7764e+02
# tf_epoch =  14000  elapsed = 07:26 (+30.3)  loss = 1.5862e+02
# tf_epoch =  15000  elapsed = 07:57 (+30.4)  loss = 1.4862e+02
# tf_epoch =  16000  elapsed = 08:27 (+30.2)  loss = 1.3121e+02
# tf_epoch =  17000  elapsed = 08:57 (+30.1)  loss = 1.1748e+02
# tf_epoch =  18000  elapsed = 09:27 (+30.1)  loss = 1.1408e+02
# tf_epoch =  19000  elapsed = 09:57 (+30.0)  loss = 9.4975e+01
# tf_epoch =  20000  elapsed = 10:27 (+30.1)  loss = 8.6478e+01
# tf_epoch =  21000  elapsed = 10:57 (+30.0)  loss = 9.0025e+01
# tf_epoch =  22000  elapsed = 11:27 (+30.1)  loss = 8.7615e+01
# tf_epoch =  23000  elapsed = 11:58 (+30.2)  loss = 7.5134e+01
# tf_epoch =  24000  elapsed = 12:28 (+30.1)  loss = 8.0744e+01
# tf_epoch =  25000  elapsed = 12:58 (+30.2)  loss = 7.9921e+01
# tf_epoch =  26000  elapsed = 13:28 (+30.2)  loss = 7.4717e+01
# tf_epoch =  27000  elapsed = 13:59 (+30.1)  loss = 7.5222e+01
# tf_epoch =  28000  elapsed = 14:29 (+30.1)  loss = 7.2938e+01
# tf_epoch =  29000  elapsed = 14:59 (+30.2)  loss = 6.7618e+01
# tf_epoch =  30000  elapsed = 15:29 (+30.1)  loss = 5.7425e+01
# tf_epoch =  31000  elapsed = 15:59 (+30.0)  loss = 6.5235e+01
# tf_epoch =  32000  elapsed = 16:29 (+30.0)  loss = 6.4712e+01
# tf_epoch =  33000  elapsed = 16:59 (+30.1)  loss = 6.1275e+01
# tf_epoch =  34000  elapsed = 17:30 (+30.1)  loss = 5.9349e+01
# tf_epoch =  35000  elapsed = 18:00 (+30.0)  loss = 5.9732e+01
# tf_epoch =  36000  elapsed = 18:30 (+30.1)  loss = 5.2222e+01
# tf_epoch =  37000  elapsed = 19:00 (+30.1)  loss = 4.3197e+01
# tf_epoch =  38000  elapsed = 19:30 (+30.2)  loss = 5.3781e+01
# tf_epoch =  39000  elapsed = 20:00 (+30.2)  loss = 4.1732e+01
# tf_epoch =  40000  elapsed = 20:31 (+30.2)  loss = 3.9465e+01
# tf_epoch =  41000  elapsed = 21:01 (+30.1)  loss = 4.5195e+01
# tf_epoch =  42000  elapsed = 21:31 (+30.0)  loss = 3.7652e+01
# tf_epoch =  43000  elapsed = 22:01 (+30.0)  loss = 4.2359e+01
# tf_epoch =  44000  elapsed = 22:31 (+30.0)  loss = 4.1426e+01
# tf_epoch =  45000  elapsed = 23:01 (+30.0)  loss = 4.0586e+01
# tf_epoch =  46000  elapsed = 23:31 (+30.1)  loss = 2.9172e+01
# tf_epoch =  47000  elapsed = 24:02 (+30.2)  loss = 3.7111e+01
# tf_epoch =  48000  elapsed = 24:32 (+30.2)  loss = 3.4790e+01
# tf_epoch =  49000  elapsed = 25:02 (+30.2)  loss = 3.3029e+01
# tf_epoch =  50000  elapsed = 25:32 (+30.3)  loss = 2.7267e+01
# tf_epoch =  51000  elapsed = 26:03 (+30.1)  loss = 2.8741e+01
# tf_epoch =  52000  elapsed = 26:33 (+30.3)  loss = 2.9112e+01
# tf_epoch =  53000  elapsed = 27:03 (+30.2)  loss = 3.1935e+01
# tf_epoch =  54000  elapsed = 27:34 (+30.3)  loss = 2.8792e+01
# tf_epoch =  55000  elapsed = 28:04 (+30.2)  loss = 2.4881e+01
# tf_epoch =  56000  elapsed = 28:34 (+30.1)  loss = 2.9962e+01
# tf_epoch =  57000  elapsed = 29:04 (+30.2)  loss = 2.8298e+01
# tf_epoch =  58000  elapsed = 29:34 (+30.3)  loss = 2.8634e+01
# tf_epoch =  59000  elapsed = 30:05 (+30.4)  loss = 2.0294e+01
# tf_epoch =  60000  elapsed = 30:35 (+30.2)  loss = 2.6006e+01
# tf_epoch =  61000  elapsed = 31:05 (+30.3)  loss = 1.8683e+01
# tf_epoch =  62000  elapsed = 31:36 (+30.1)  loss = 2.6495e+01
# tf_epoch =  63000  elapsed = 32:06 (+30.1)  loss = 1.9195e+01
# tf_epoch =  64000  elapsed = 32:36 (+30.1)  loss = 1.8190e+01
# tf_epoch =  65000  elapsed = 33:06 (+30.1)  loss = 2.4392e+01
# tf_epoch =  66000  elapsed = 33:36 (+30.2)  loss = 1.7109e+01
# tf_epoch =  67000  elapsed = 34:07 (+30.2)  loss = 1.8044e+01
# tf_epoch =  68000  elapsed = 34:37 (+30.1)  loss = 2.1601e+01
# tf_epoch =  69000  elapsed = 35:07 (+30.2)  loss = 1.6889e+01
# tf_epoch =  70000  elapsed = 35:37 (+30.2)  loss = 2.5691e+01
# tf_epoch =  71000  elapsed = 36:07 (+30.1)  loss = 2.3354e+01
# tf_epoch =  72000  elapsed = 36:38 (+30.2)  loss = 1.9666e+01
# tf_epoch =  73000  elapsed = 37:08 (+30.3)  loss = 1.8486e+01
# tf_epoch =  74000  elapsed = 37:38 (+30.4)  loss = 1.9946e+01
# tf_epoch =  75000  elapsed = 38:09 (+30.4)  loss = 1.6434e+01
# tf_epoch =  76000  elapsed = 38:39 (+30.4)  loss = 2.2641e+01
# tf_epoch =  77000  elapsed = 39:10 (+30.3)  loss = 1.7776e+01
# tf_epoch =  78000  elapsed = 39:40 (+30.2)  loss = 1.4804e+01
# tf_epoch =  79000  elapsed = 40:10 (+30.2)  loss = 1.8438e+01
# tf_epoch =  80000  elapsed = 40:40 (+30.2)  loss = 2.1678e+01
# tf_epoch =  81000  elapsed = 41:11 (+30.2)  loss = 1.8936e+01
# tf_epoch =  82000  elapsed = 41:41 (+30.2)  loss = 1.7376e+01
# tf_epoch =  83000  elapsed = 42:11 (+30.2)  loss = 1.4660e+01
# tf_epoch =  84000  elapsed = 42:41 (+30.1)  loss = 1.4077e+01
# tf_epoch =  85000  elapsed = 43:12 (+30.1)  loss = 1.3930e+01
# tf_epoch =  86000  elapsed = 43:42 (+30.1)  loss = 2.1083e+01
# tf_epoch =  87000  elapsed = 44:12 (+30.0)  loss = 1.5610e+01
# tf_epoch =  88000  elapsed = 44:42 (+30.1)  loss = 1.5836e+01
# tf_epoch =  89000  elapsed = 45:12 (+30.1)  loss = 1.2977e+01
# tf_epoch =  90000  elapsed = 45:42 (+30.0)  loss = 2.0072e+01
# tf_epoch =  91000  elapsed = 46:12 (+30.1)  loss = 1.4042e+01
# tf_epoch =  92000  elapsed = 46:42 (+30.0)  loss = 1.9437e+01
# tf_epoch =  93000  elapsed = 47:12 (+30.1)  loss = 1.2112e+01
# tf_epoch =  94000  elapsed = 47:43 (+30.0)  loss = 1.6227e+01
# tf_epoch =  95000  elapsed = 48:13 (+30.1)  loss = 1.5358e+01
# tf_epoch =  96000  elapsed = 48:43 (+30.0)  loss = 1.5924e+01
# tf_epoch =  97000  elapsed = 49:14 (+30.7)  loss = 1.3979e+01
# tf_epoch =  98000  elapsed = 49:45 (+31.7)  loss = 1.5234e+01
# tf_epoch =  99000  elapsed = 50:17 (+31.5)  loss = 1.6676e+01
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =   1000  elapsed = 51:43 (+25.6)  loss = 1.0226e+01
# nt_epoch =   2000  elapsed = 52:24 (+41.8)  loss = 1.0113e+01
# nt_epoch =   3000  elapsed = 53:06 (+41.6)  loss = 9.9856e+00
# nt_epoch =   4000  elapsed = 53:48 (+41.5)  loss = 9.8811e+00
# nt_epoch =   5000  elapsed = 54:29 (+41.6)  loss = 9.7717e+00
# nt_epoch =   6000  elapsed = 55:11 (+41.7)  loss = 9.6521e+00
# nt_epoch =   7000  elapsed = 55:52 (+41.0)  loss = 9.5515e+00
# nt_epoch =   8000  elapsed = 56:33 (+41.5)  loss = 9.4265e+00
# nt_epoch =   9000  elapsed = 57:15 (+41.3)  loss = 9.2921e+00
# nt_epoch =  10000  elapsed = 57:57 (+41.6)  loss = 9.1836e+00
# nt_epoch =  11000  elapsed = 58:38 (+41.2)  loss = 9.0888e+00
# nt_epoch =  12000  elapsed = 59:19 (+41.6)  loss = 9.0009e+00
# nt_epoch =  13000  elapsed = 00:01 (+41.4)  loss = 8.9054e+00
# nt_epoch =  14000  elapsed = 00:42 (+40.9)  loss = 8.8224e+00
# nt_epoch =  15000  elapsed = 01:24 (+42.3)  loss = 8.7257e+00
# nt_epoch =  16000  elapsed = 02:05 (+41.0)  loss = 8.6203e+00
# nt_epoch =  17000  elapsed = 02:47 (+41.5)  loss = 8.5326e+00
# nt_epoch =  18000  elapsed = 03:28 (+41.5)  loss = 8.4585e+00
# nt_epoch =  19000  elapsed = 04:09 (+41.1)  loss = 8.3721e+00
# nt_epoch =  20000  elapsed = 04:51 (+41.3)  loss = 8.2790e+00
# nt_epoch =  21000  elapsed = 05:32 (+41.4)  loss = 8.1965e+00
# nt_epoch =  22000  elapsed = 06:13 (+41.1)  loss = 8.0975e+00
# nt_epoch =  23000  elapsed = 06:55 (+41.5)  loss = 8.0210e+00
# nt_epoch =  24000  elapsed = 07:36 (+41.1)  loss = 7.9259e+00
# nt_epoch =  25000  elapsed = 08:17 (+40.7)  loss = 7.8326e+00
# nt_epoch =  26000  elapsed = 08:57 (+40.6)  loss = 7.7519e+00
# nt_epoch =  27000  elapsed = 09:38 (+40.6)  loss = 7.6667e+00
# nt_epoch =  28000  elapsed = 10:19 (+40.5)  loss = 7.5817e+00
# nt_epoch =  29000  elapsed = 11:00 (+41.0)  loss = 7.5121e+00
# nt_epoch =  30000  elapsed = 11:40 (+40.6)  loss = 7.4280e+00
# nt_epoch =  31000  elapsed = 12:21 (+40.7)  loss = 7.3536e+00
# nt_epoch =  32000  elapsed = 13:00 (+38.6)  loss = 7.2820e+00
# nt_epoch =  33000  elapsed = 13:38 (+38.3)  loss = 7.2251e+00
# nt_epoch =  34000  elapsed = 14:17 (+38.3)  loss = 7.1597e+00
# nt_epoch =  35000  elapsed = 14:55 (+38.2)  loss = 7.0936e+00
# nt_epoch =  36000  elapsed = 15:33 (+38.2)  loss = 7.0201e+00
# nt_epoch =  37000  elapsed = 16:11 (+38.3)  loss = 6.9466e+00
# nt_epoch =  38000  elapsed = 16:50 (+38.2)  loss = 6.8823e+00
# nt_epoch =  39000  elapsed = 17:28 (+38.2)  loss = 6.8212e+00
# nt_epoch =  40000  elapsed = 18:06 (+38.2)  loss = 6.7696e+00
# nt_epoch =  41000  elapsed = 18:45 (+38.3)  loss = 6.6998e+00
# nt_epoch =  42000  elapsed = 19:23 (+38.4)  loss = 6.6443e+00
# nt_epoch =  43000  elapsed = 20:03 (+39.6)  loss = 6.5808e+00
# nt_epoch =  44000  elapsed = 20:42 (+39.6)  loss = 6.5149e+00
# nt_epoch =  45000  elapsed = 21:21 (+39.1)  loss = 6.4552e+00
# nt_epoch =  46000  elapsed = 22:01 (+39.0)  loss = 6.3883e+00
# nt_epoch =  47000  elapsed = 22:39 (+38.5)  loss = 6.3281e+00
# nt_epoch =  48000  elapsed = 23:18 (+38.6)  loss = 6.2688e+00
# nt_epoch =  49000  elapsed = 23:57 (+38.9)  loss = 6.2229e+00
# nt_epoch =  50000  elapsed = 24:36 (+39.2)  loss = 6.1905e+00
# ==================
# Training finished (epoch 150000): duration = 25:06  error = 5.4442e-02

# %%
# plot
vranges = {}
vranges['u - u obs']=[-20, 20]
vranges['v - v obs']=[-20, 20]
vranges['H - H obs']=[-20, 20]
vranges['h - h obs']=[-20, 20]
vranges['C - C obs']=[-500, 500]
vranges['C pred']=[0, 3500]
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub, vranges)

# history
plot_log_history(pinn)
