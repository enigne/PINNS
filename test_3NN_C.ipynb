# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSA3NN_calvingfront_invertC
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 500
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
hp["h_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
# path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
path = os.path.join(appDataPath, "SSA2D_segCF.mat")
# path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data_all(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSA3NN_calvingfront_invertC(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        mu=1.1060e8,
        loss_weights=[1e-1, 1e-2, 1e-2, 1e-4, 1e-12])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 500,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "h_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "C_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# train the model
pinn.fit(X_u_train, u_train)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer (MinmaxSc (None, 2)                 6
# _________________________________________________________________
# dense (Dense)                (None, 20)                60
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 42
# _________________________________________________________________
# up_scale_layer (UpScaleLayer (None, 2)                 6
# =================================================================
# Total params: 3,054
# Trainable params: 3,042
# Non-trainable params: 12
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_1 (Minmax (None, 2)                 6
# _________________________________________________________________
# dense_9 (Dense)              (None, 20)                60
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_14 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 42
# _________________________________________________________________
# up_scale_layer_1 (UpScaleLay (None, 2)                 6
# =================================================================
# Total params: 3,054
# Trainable params: 3,042
# Non-trainable params: 12
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_2 (Minmax (None, 2)                 6
# _________________________________________________________________
# dense_18 (Dense)             (None, 20)                60
# _________________________________________________________________
# dense_19 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_20 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_21 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_22 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_23 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_24 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_25 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 21
# _________________________________________________________________
# up_scale_layer_2 (UpScaleLay (None, 1)                 4
# =================================================================
# Total params: 3,031
# Trainable params: 3,021
# Non-trainable params: 10
# _________________________________________________________________
# (None, None, None)
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:28 (+28.4)  loss = 3.0515e+06
# tf_epoch =   1000  elapsed = 01:04 (+35.9)  loss = 2.3726e+04
# tf_epoch =   2000  elapsed = 01:40 (+35.8)  loss = 6.9095e+03
# tf_epoch =   3000  elapsed = 02:16 (+35.8)  loss = 1.0730e+04
# tf_epoch =   4000  elapsed = 02:51 (+35.6)  loss = 2.8618e+03
# tf_epoch =   5000  elapsed = 03:27 (+35.7)  loss = 2.0793e+03
# tf_epoch =   6000  elapsed = 04:03 (+35.7)  loss = 1.5615e+03
# tf_epoch =   7000  elapsed = 04:39 (+35.7)  loss = 1.1105e+03
# tf_epoch =   8000  elapsed = 05:15 (+36.0)  loss = 8.4627e+02
# tf_epoch =   9000  elapsed = 05:51 (+36.0)  loss = 5.8032e+02
# tf_epoch =  10000  elapsed = 06:27 (+35.8)  loss = 4.1213e+02
# tf_epoch =  11000  elapsed = 07:02 (+35.7)  loss = 3.0838e+02
# tf_epoch =  12000  elapsed = 07:38 (+35.7)  loss = 2.6434e+02
# tf_epoch =  13000  elapsed = 08:14 (+35.6)  loss = 2.1878e+02
# tf_epoch =  14000  elapsed = 08:49 (+35.6)  loss = 2.1104e+02
# tf_epoch =  15000  elapsed = 09:25 (+35.7)  loss = 1.8447e+02
# tf_epoch =  16000  elapsed = 10:02 (+36.8)  loss = 1.7220e+02
# tf_epoch =  17000  elapsed = 10:38 (+35.7)  loss = 1.6339e+02
# tf_epoch =  18000  elapsed = 11:13 (+35.6)  loss = 1.4329e+02
# tf_epoch =  19000  elapsed = 11:49 (+35.8)  loss = 1.4080e+02
# tf_epoch =  20000  elapsed = 12:25 (+35.8)  loss = 1.2298e+02
# tf_epoch =  21000  elapsed = 13:01 (+35.7)  loss = 1.2654e+02
# tf_epoch =  22000  elapsed = 13:36 (+35.7)  loss = 1.1808e+02
# tf_epoch =  23000  elapsed = 14:12 (+35.8)  loss = 1.0332e+02
# tf_epoch =  24000  elapsed = 14:48 (+35.8)  loss = 1.1190e+02
# tf_epoch =  25000  elapsed = 15:24 (+35.6)  loss = 9.8896e+01
# tf_epoch =  26000  elapsed = 16:00 (+35.8)  loss = 1.0061e+02
# tf_epoch =  27000  elapsed = 16:36 (+36.0)  loss = 8.9457e+01
# tf_epoch =  28000  elapsed = 17:12 (+36.0)  loss = 9.1425e+01
# tf_epoch =  29000  elapsed = 17:48 (+35.9)  loss = 9.3243e+01
# tf_epoch =  30000  elapsed = 18:23 (+35.8)  loss = 7.4262e+01
# tf_epoch =  31000  elapsed = 18:59 (+35.9)  loss = 7.1300e+01
# tf_epoch =  32000  elapsed = 19:35 (+35.6)  loss = 8.0986e+01
# tf_epoch =  33000  elapsed = 20:11 (+35.8)  loss = 6.7973e+01
# tf_epoch =  34000  elapsed = 20:47 (+36.5)  loss = 6.4839e+01
# tf_epoch =  35000  elapsed = 21:23 (+35.9)  loss = 6.9792e+01
# tf_epoch =  36000  elapsed = 21:59 (+35.8)  loss = 6.6337e+01
# tf_epoch =  37000  elapsed = 22:35 (+36.1)  loss = 6.8985e+01
# tf_epoch =  38000  elapsed = 23:12 (+36.2)  loss = 6.3107e+01
# tf_epoch =  39000  elapsed = 23:48 (+36.0)  loss = 5.8736e+01
# tf_epoch =  40000  elapsed = 24:24 (+35.8)  loss = 6.1588e+01
# tf_epoch =  41000  elapsed = 24:59 (+35.7)  loss = 6.3287e+01
# tf_epoch =  42000  elapsed = 25:35 (+35.8)  loss = 5.6068e+01
# tf_epoch =  43000  elapsed = 26:11 (+35.9)  loss = 5.1664e+01
# tf_epoch =  44000  elapsed = 26:47 (+35.5)  loss = 5.3614e+01
# tf_epoch =  45000  elapsed = 27:23 (+35.8)  loss = 5.9814e+01
# tf_epoch =  46000  elapsed = 27:58 (+35.7)  loss = 5.5137e+01
# tf_epoch =  47000  elapsed = 28:34 (+35.9)  loss = 5.1213e+01
# tf_epoch =  48000  elapsed = 29:10 (+35.7)  loss = 4.9780e+01
# tf_epoch =  49000  elapsed = 29:46 (+35.6)  loss = 4.2529e+01
# tf_epoch =  50000  elapsed = 30:21 (+35.9)  loss = 4.0778e+01
# tf_epoch =  51000  elapsed = 30:57 (+35.7)  loss = 4.4871e+01
# tf_epoch =  52000  elapsed = 31:33 (+35.9)  loss = 3.9222e+01
# tf_epoch =  53000  elapsed = 32:09 (+35.9)  loss = 3.9351e+01
# tf_epoch =  54000  elapsed = 32:45 (+35.7)  loss = 4.7888e+01
# tf_epoch =  55000  elapsed = 33:21 (+36.1)  loss = 3.9800e+01
# tf_epoch =  56000  elapsed = 33:57 (+35.8)  loss = 3.6139e+01
# tf_epoch =  57000  elapsed = 34:33 (+35.9)  loss = 4.2398e+01
# tf_epoch =  58000  elapsed = 35:09 (+35.7)  loss = 3.6417e+01
# tf_epoch =  59000  elapsed = 35:45 (+36.3)  loss = 4.1097e+01
# tf_epoch =  60000  elapsed = 36:21 (+35.8)  loss = 3.5032e+01
# tf_epoch =  61000  elapsed = 36:56 (+35.6)  loss = 3.8471e+01
# tf_epoch =  62000  elapsed = 37:32 (+35.7)  loss = 3.7058e+01
# tf_epoch =  63000  elapsed = 38:08 (+35.6)  loss = 3.3760e+01
# tf_epoch =  64000  elapsed = 38:43 (+35.6)  loss = 3.3181e+01
# tf_epoch =  65000  elapsed = 39:20 (+36.1)  loss = 3.6293e+01
# tf_epoch =  66000  elapsed = 39:56 (+35.9)  loss = 3.9593e+01
# tf_epoch =  67000  elapsed = 40:31 (+35.7)  loss = 3.7544e+01
# tf_epoch =  68000  elapsed = 41:08 (+36.2)  loss = 3.0253e+01
# tf_epoch =  69000  elapsed = 41:43 (+35.7)  loss = 3.7621e+01
# tf_epoch =  70000  elapsed = 42:19 (+35.8)  loss = 3.7863e+01
# tf_epoch =  71000  elapsed = 42:55 (+35.6)  loss = 3.9037e+01
# tf_epoch =  72000  elapsed = 43:31 (+35.9)  loss = 3.6920e+01
# tf_epoch =  73000  elapsed = 44:07 (+36.1)  loss = 3.4696e+01
# tf_epoch =  74000  elapsed = 44:43 (+36.0)  loss = 3.5596e+01
# tf_epoch =  75000  elapsed = 45:18 (+35.7)  loss = 3.1849e+01
# tf_epoch =  76000  elapsed = 45:55 (+36.0)  loss = 2.7327e+01
# tf_epoch =  77000  elapsed = 46:30 (+35.7)  loss = 2.7354e+01
# tf_epoch =  78000  elapsed = 47:06 (+35.6)  loss = 2.8240e+01
# tf_epoch =  79000  elapsed = 47:42 (+35.6)  loss = 3.5652e+01
# tf_epoch =  80000  elapsed = 48:18 (+36.1)  loss = 2.9085e+01
# tf_epoch =  81000  elapsed = 48:54 (+35.8)  loss = 3.1342e+01
# tf_epoch =  82000  elapsed = 49:29 (+35.7)  loss = 3.1354e+01
# tf_epoch =  83000  elapsed = 50:05 (+35.8)  loss = 3.1690e+01
# tf_epoch =  84000  elapsed = 50:41 (+36.1)  loss = 2.4623e+01
# tf_epoch =  85000  elapsed = 51:17 (+36.0)  loss = 2.5980e+01
# tf_epoch =  86000  elapsed = 51:53 (+35.8)  loss = 3.3220e+01
# tf_epoch =  87000  elapsed = 52:29 (+35.8)  loss = 2.9530e+01
# tf_epoch =  88000  elapsed = 53:05 (+35.8)  loss = 3.0850e+01
# tf_epoch =  89000  elapsed = 53:41 (+36.0)  loss = 2.2610e+01
# tf_epoch =  90000  elapsed = 54:17 (+35.7)  loss = 2.9616e+01
# tf_epoch =  91000  elapsed = 54:53 (+36.4)  loss = 3.2008e+01
# tf_epoch =  92000  elapsed = 55:29 (+35.7)  loss = 2.6172e+01
# tf_epoch =  93000  elapsed = 56:05 (+36.1)  loss = 2.2423e+01
# tf_epoch =  94000  elapsed = 56:41 (+35.8)  loss = 2.9559e+01
# tf_epoch =  95000  elapsed = 57:17 (+35.8)  loss = 2.7722e+01
# tf_epoch =  96000  elapsed = 57:53 (+35.6)  loss = 2.0672e+01
# tf_epoch =  97000  elapsed = 58:29 (+36.5)  loss = 2.1867e+01
# tf_epoch =  98000  elapsed = 59:05 (+35.6)  loss = 2.5782e+01
# tf_epoch =  99000  elapsed = 59:41 (+36.1)  loss = 2.0438e+01
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =   1000  elapsed = 01:18 (+36.9)  loss = 1.9044e+01
# nt_epoch =   2000  elapsed = 02:07 (+49.0)  loss = 1.8896e+01
# nt_epoch =   3000  elapsed = 02:57 (+49.7)  loss = 1.8738e+01
# nt_epoch =   4000  elapsed = 03:45 (+48.5)  loss = 1.8580e+01
# nt_epoch =   5000  elapsed = 04:34 (+49.1)  loss = 1.8387e+01
# nt_epoch =   6000  elapsed = 05:23 (+49.0)  loss = 1.8238e+01
# nt_epoch =   7000  elapsed = 06:12 (+48.9)  loss = 1.7959e+01
# nt_epoch =   8000  elapsed = 07:01 (+48.6)  loss = 1.7700e+01
# nt_epoch =   9000  elapsed = 07:50 (+49.2)  loss = 1.7491e+01
# nt_epoch =  10000  elapsed = 08:39 (+49.1)  loss = 1.7258e+01
# nt_epoch =  11000  elapsed = 09:29 (+49.0)  loss = 1.7056e+01
# nt_epoch =  12000  elapsed = 10:18 (+49.3)  loss = 1.6861e+01
# nt_epoch =  13000  elapsed = 11:07 (+48.8)  loss = 1.6678e+01
# nt_epoch =  14000  elapsed = 11:56 (+48.9)  loss = 1.6473e+01
# nt_epoch =  15000  elapsed = 12:45 (+49.6)  loss = 1.6260e+01
# nt_epoch =  16000  elapsed = 13:34 (+48.5)  loss = 1.6001e+01
# nt_epoch =  17000  elapsed = 14:22 (+48.0)  loss = 1.5765e+01
# nt_epoch =  18000  elapsed = 15:10 (+48.4)  loss = 1.5588e+01
# nt_epoch =  19000  elapsed = 15:59 (+48.3)  loss = 1.5419e+01
# nt_epoch =  20000  elapsed = 16:47 (+48.7)  loss = 1.5244e+01
# nt_epoch =  21000  elapsed = 17:36 (+48.6)  loss = 1.4971e+01
# nt_epoch =  22000  elapsed = 18:25 (+48.4)  loss = 1.4797e+01
# nt_epoch =  23000  elapsed = 19:13 (+48.6)  loss = 1.4574e+01
# nt_epoch =  24000  elapsed = 20:02 (+48.3)  loss = 1.4423e+01
# nt_epoch =  25000  elapsed = 20:50 (+48.8)  loss = 1.4208e+01
# nt_epoch =  26000  elapsed = 21:39 (+48.5)  loss = 1.4060e+01
# nt_epoch =  27000  elapsed = 22:27 (+48.4)  loss = 1.3888e+01
# nt_epoch =  28000  elapsed = 23:16 (+48.4)  loss = 1.3730e+01
# nt_epoch =  29000  elapsed = 24:04 (+48.2)  loss = 1.3523e+01
# nt_epoch =  30000  elapsed = 24:53 (+48.4)  loss = 1.3369e+01
# nt_epoch =  31000  elapsed = 25:41 (+48.3)  loss = 1.3185e+01
# nt_epoch =  32000  elapsed = 26:30 (+48.8)  loss = 1.2995e+01
# nt_epoch =  33000  elapsed = 27:18 (+48.6)  loss = 1.2883e+01
# nt_epoch =  34000  elapsed = 28:06 (+48.0)  loss = 1.2708e+01
# nt_epoch =  35000  elapsed = 28:55 (+48.7)  loss = 1.2596e+01
# nt_epoch =  36000  elapsed = 29:44 (+48.3)  loss = 1.2476e+01
# nt_epoch =  37000  elapsed = 30:32 (+48.3)  loss = 1.2351e+01
# nt_epoch =  38000  elapsed = 31:20 (+47.6)  loss = 1.2258e+01
# nt_epoch =  39000  elapsed = 32:08 (+48.3)  loss = 1.2109e+01
# nt_epoch =  40000  elapsed = 32:56 (+48.0)  loss = 1.2017e+01
# nt_epoch =  41000  elapsed = 33:44 (+48.1)  loss = 1.1912e+01
# nt_epoch =  42000  elapsed = 34:33 (+48.4)  loss = 1.1805e+01
# nt_epoch =  43000  elapsed = 35:21 (+48.2)  loss = 1.1677e+01
# nt_epoch =  44000  elapsed = 36:09 (+47.9)  loss = 1.1548e+01
# nt_epoch =  45000  elapsed = 36:57 (+48.1)  loss = 1.1439e+01
# nt_epoch =  46000  elapsed = 37:45 (+47.9)  loss = 1.1348e+01
# nt_epoch =  47000  elapsed = 38:34 (+48.6)  loss = 1.1245e+01
# nt_epoch =  48000  elapsed = 39:22 (+48.5)  loss = 1.1153e+01
# nt_epoch =  49000  elapsed = 40:10 (+48.3)  loss = 1.1038e+01
# nt_epoch =  50000  elapsed = 40:58 (+48.0)  loss = 1.0918e+01
# ==================
# Training finished (epoch 150000): duration = 41:23  error = 7.4581e-02

# %%
# plot
vranges = {}
vranges['u - u obs']=[-20, 20]
vranges['v - v obs']=[-20, 20]
vranges['H - H obs']=[-20, 20]
vranges['h - h obs']=[-20, 20]
vranges['C - C obs']=[-500, 500]
vranges['C pred']=[0, 3500]
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub, vranges)

# history
plot_log_history(pinn)
