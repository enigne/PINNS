# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSANN_invertC
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 500
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 5]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
# path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_segCF.mat")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_Dirichlet(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSANN_invertC(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        mu=1.2680e8,
        loss_weights=[1e-5, 1e-3, 1e-5, 1e-7])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 500,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     5
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# train the model
pinn.fit(X_u_train, u_train)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:16 (+16.1)  loss = 1.4021e+05
# tf_epoch =   1000  elapsed = 00:41 (+25.0)  loss = 3.2628e+02
# tf_epoch =   2000  elapsed = 01:06 (+25.2)  loss = 2.8808e+02
# tf_epoch =   3000  elapsed = 01:31 (+24.9)  loss = 2.5567e+02
# tf_epoch =   4000  elapsed = 01:56 (+25.2)  loss = 2.0585e+02
# tf_epoch =   5000  elapsed = 02:21 (+25.2)  loss = 1.5988e+02
# tf_epoch =   6000  elapsed = 02:46 (+24.7)  loss = 1.5607e+02
# tf_epoch =   7000  elapsed = 03:11 (+25.3)  loss = 1.4733e+02
# tf_epoch =   8000  elapsed = 03:38 (+26.2)  loss = 1.2040e+02
# tf_epoch =   9000  elapsed = 04:05 (+26.8)  loss = 7.6621e+01
# tf_epoch =  10000  elapsed = 04:31 (+26.3)  loss = 4.6836e+01
# tf_epoch =  11000  elapsed = 04:57 (+26.4)  loss = 3.2497e+01
# tf_epoch =  12000  elapsed = 05:23 (+25.9)  loss = 2.5778e+01
# tf_epoch =  13000  elapsed = 05:50 (+26.4)  loss = 2.1190e+01
# tf_epoch =  14000  elapsed = 06:16 (+26.4)  loss = 1.7817e+01
# tf_epoch =  15000  elapsed = 06:43 (+26.4)  loss = 1.5450e+01
# tf_epoch =  16000  elapsed = 07:09 (+26.5)  loss = 1.3844e+01
# tf_epoch =  17000  elapsed = 07:36 (+26.5)  loss = 1.2760e+01
# tf_epoch =  18000  elapsed = 08:02 (+26.6)  loss = 1.1893e+01
# tf_epoch =  19000  elapsed = 08:29 (+26.2)  loss = 1.1157e+01
# tf_epoch =  20000  elapsed = 08:55 (+26.3)  loss = 1.0482e+01
# tf_epoch =  21000  elapsed = 09:21 (+25.9)  loss = 9.9391e+00
# tf_epoch =  22000  elapsed = 09:47 (+26.1)  loss = 9.4613e+00
# tf_epoch =  23000  elapsed = 10:13 (+26.3)  loss = 9.0052e+00
# tf_epoch =  24000  elapsed = 10:40 (+26.6)  loss = 8.6230e+00
# tf_epoch =  25000  elapsed = 11:06 (+26.1)  loss = 8.3137e+00
# tf_epoch =  26000  elapsed = 11:32 (+26.0)  loss = 7.9877e+00
# tf_epoch =  27000  elapsed = 11:58 (+26.2)  loss = 7.7137e+00
# tf_epoch =  28000  elapsed = 12:25 (+26.2)  loss = 7.5099e+00
# tf_epoch =  29000  elapsed = 12:51 (+26.1)  loss = 7.3333e+00
# tf_epoch =  30000  elapsed = 13:17 (+26.3)  loss = 7.1580e+00
# tf_epoch =  31000  elapsed = 13:43 (+25.8)  loss = 7.0100e+00
# tf_epoch =  32000  elapsed = 14:09 (+26.4)  loss = 6.9375e+00
# tf_epoch =  33000  elapsed = 14:36 (+26.9)  loss = 6.7270e+00
# tf_epoch =  34000  elapsed = 15:03 (+26.1)  loss = 6.5823e+00
# tf_epoch =  35000  elapsed = 15:29 (+26.1)  loss = 6.4510e+00
# tf_epoch =  36000  elapsed = 15:55 (+26.1)  loss = 6.4007e+00
# tf_epoch =  37000  elapsed = 16:21 (+25.9)  loss = 6.2140e+00
# tf_epoch =  38000  elapsed = 16:47 (+26.1)  loss = 6.1250e+00
# tf_epoch =  39000  elapsed = 17:13 (+26.2)  loss = 6.0305e+00
# tf_epoch =  40000  elapsed = 17:39 (+26.1)  loss = 5.9399e+00
# tf_epoch =  41000  elapsed = 18:06 (+26.3)  loss = 5.8585e+00
# tf_epoch =  42000  elapsed = 18:32 (+26.3)  loss = 5.7615e+00
# tf_epoch =  43000  elapsed = 18:58 (+26.5)  loss = 5.6646e+00
# tf_epoch =  44000  elapsed = 19:25 (+26.5)  loss = 5.5819e+00
# tf_epoch =  45000  elapsed = 19:52 (+26.7)  loss = 5.5613e+00
# tf_epoch =  46000  elapsed = 20:18 (+26.1)  loss = 5.4545e+00
# tf_epoch =  47000  elapsed = 20:44 (+26.0)  loss = 5.3851e+00
# tf_epoch =  48000  elapsed = 21:10 (+26.1)  loss = 5.3302e+00
# tf_epoch =  49000  elapsed = 21:36 (+25.8)  loss = 5.2771e+00
# tf_epoch =  50000  elapsed = 22:02 (+26.4)  loss = 5.1721e+00
# tf_epoch =  51000  elapsed = 22:28 (+25.7)  loss = 5.1054e+00
# tf_epoch =  52000  elapsed = 22:55 (+26.4)  loss = 5.0572e+00
# tf_epoch =  53000  elapsed = 23:21 (+26.7)  loss = 5.0126e+00
# tf_epoch =  54000  elapsed = 23:47 (+26.0)  loss = 4.9774e+00
# tf_epoch =  55000  elapsed = 24:14 (+26.3)  loss = 4.8990e+00
# tf_epoch =  56000  elapsed = 24:40 (+26.6)  loss = 4.8576e+00
# tf_epoch =  57000  elapsed = 25:07 (+26.4)  loss = 4.7784e+00
# tf_epoch =  58000  elapsed = 25:33 (+26.1)  loss = 4.7412e+00
# tf_epoch =  59000  elapsed = 25:59 (+26.2)  loss = 4.7067e+00
# tf_epoch =  60000  elapsed = 26:26 (+26.3)  loss = 4.6859e+00
# tf_epoch =  61000  elapsed = 26:52 (+26.1)  loss = 4.6497e+00
# tf_epoch =  62000  elapsed = 27:18 (+26.3)  loss = 4.6206e+00
# tf_epoch =  63000  elapsed = 27:44 (+25.8)  loss = 4.5950e+00
# tf_epoch =  64000  elapsed = 28:10 (+25.9)  loss = 4.4831e+00
# tf_epoch =  65000  elapsed = 28:36 (+26.0)  loss = 4.4831e+00
# tf_epoch =  66000  elapsed = 29:02 (+26.0)  loss = 4.4209e+00
# tf_epoch =  67000  elapsed = 29:28 (+26.2)  loss = 4.3872e+00
# tf_epoch =  68000  elapsed = 29:54 (+26.0)  loss = 4.3703e+00
# tf_epoch =  69000  elapsed = 30:21 (+26.3)  loss = 4.3093e+00
# tf_epoch =  70000  elapsed = 30:47 (+26.2)  loss = 4.3487e+00
# tf_epoch =  71000  elapsed = 31:13 (+25.9)  loss = 4.2543e+00
# tf_epoch =  72000  elapsed = 31:39 (+26.3)  loss = 4.2139e+00
# tf_epoch =  73000  elapsed = 32:05 (+25.7)  loss = 4.1818e+00
# tf_epoch =  74000  elapsed = 32:31 (+26.2)  loss = 4.1470e+00
# tf_epoch =  75000  elapsed = 32:57 (+25.9)  loss = 4.1139e+00
# tf_epoch =  76000  elapsed = 33:23 (+26.4)  loss = 4.1720e+00
# tf_epoch =  77000  elapsed = 33:50 (+26.4)  loss = 4.0809e+00
# tf_epoch =  78000  elapsed = 34:16 (+26.1)  loss = 4.0280e+00
# tf_epoch =  79000  elapsed = 34:42 (+25.9)  loss = 3.9680e+00
# tf_epoch =  80000  elapsed = 35:09 (+26.4)  loss = 3.9834e+00
# tf_epoch =  81000  elapsed = 35:35 (+26.2)  loss = 3.9108e+00
# tf_epoch =  82000  elapsed = 36:01 (+25.9)  loss = 3.9034e+00
# tf_epoch =  83000  elapsed = 36:27 (+26.0)  loss = 3.9376e+00
# tf_epoch =  84000  elapsed = 36:53 (+25.7)  loss = 3.8795e+00
# tf_epoch =  85000  elapsed = 37:19 (+26.3)  loss = 3.8090e+00
# tf_epoch =  86000  elapsed = 37:45 (+25.7)  loss = 3.7583e+00
# tf_epoch =  87000  elapsed = 38:11 (+26.1)  loss = 3.7871e+00
# tf_epoch =  88000  elapsed = 38:37 (+25.9)  loss = 3.7259e+00
# tf_epoch =  89000  elapsed = 39:03 (+26.4)  loss = 3.7061e+00
# tf_epoch =  90000  elapsed = 39:30 (+26.4)  loss = 3.7507e+00
# tf_epoch =  91000  elapsed = 39:56 (+26.3)  loss = 3.6804e+00
# tf_epoch =  92000  elapsed = 40:23 (+26.3)  loss = 3.6612e+00
# tf_epoch =  93000  elapsed = 40:49 (+26.3)  loss = 3.6237e+00
# tf_epoch =  94000  elapsed = 41:15 (+26.0)  loss = 3.5916e+00
# tf_epoch =  95000  elapsed = 41:41 (+26.4)  loss = 3.5625e+00
# tf_epoch =  96000  elapsed = 42:08 (+26.2)  loss = 3.5493e+00
# tf_epoch =  97000  elapsed = 42:34 (+26.3)  loss = 3.5262e+00
# tf_epoch =  98000  elapsed = 43:00 (+25.9)  loss = 3.5236e+00
# tf_epoch =  99000  elapsed = 43:26 (+26.3)  loss = 3.4843e+00
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =   1000  elapsed = 44:35 (+09.2)  loss = 3.3886e+00
# nt_epoch =   2000  elapsed = 45:11 (+35.1)  loss = 3.3411e+00
# nt_epoch =   3000  elapsed = 45:45 (+34.6)  loss = 3.3002e+00
# nt_epoch =   4000  elapsed = 46:20 (+34.8)  loss = 3.2848e+00
# nt_epoch =   5000  elapsed = 46:55 (+34.7)  loss = 3.2739e+00
# nt_epoch =   6000  elapsed = 47:30 (+34.7)  loss = 3.2641e+00
# nt_epoch =   7000  elapsed = 48:04 (+34.7)  loss = 3.2531e+00
# nt_epoch =   8000  elapsed = 48:40 (+35.4)  loss = 3.2425e+00
# nt_epoch =   9000  elapsed = 49:14 (+34.6)  loss = 3.2362e+00
# nt_epoch =  10000  elapsed = 49:49 (+34.7)  loss = 3.2275e+00
# nt_epoch =  11000  elapsed = 50:24 (+34.8)  loss = 3.2179e+00
# nt_epoch =  12000  elapsed = 50:59 (+35.1)  loss = 3.2115e+00
# nt_epoch =  13000  elapsed = 51:35 (+35.4)  loss = 3.2071e+00
# nt_epoch =  14000  elapsed = 52:10 (+35.3)  loss = 3.1699e+00
# nt_epoch =  15000  elapsed = 52:45 (+35.4)  loss = 3.0749e+00
# nt_epoch =  16000  elapsed = 53:21 (+35.2)  loss = 3.0156e+00
# nt_epoch =  17000  elapsed = 53:56 (+35.2)  loss = 2.9765e+00
# nt_epoch =  18000  elapsed = 54:31 (+35.3)  loss = 2.9478e+00
# nt_epoch =  19000  elapsed = 55:06 (+35.0)  loss = 2.9268e+00
# nt_epoch =  20000  elapsed = 55:42 (+35.5)  loss = 2.8989e+00
# nt_epoch =  21000  elapsed = 56:17 (+35.3)  loss = 2.8771e+00
# nt_epoch =  22000  elapsed = 56:53 (+35.2)  loss = 2.8580e+00
# nt_epoch =  23000  elapsed = 57:28 (+35.0)  loss = 2.8363e+00
# nt_epoch =  24000  elapsed = 58:03 (+35.2)  loss = 2.8186e+00
# nt_epoch =  25000  elapsed = 58:38 (+35.2)  loss = 2.8034e+00
# nt_epoch =  26000  elapsed = 59:14 (+35.5)  loss = 2.7838e+00
# nt_epoch =  27000  elapsed = 59:49 (+35.4)  loss = 2.7681e+00
# nt_epoch =  28000  elapsed = 00:24 (+35.2)  loss = 2.7557e+00
# nt_epoch =  29000  elapsed = 01:00 (+35.3)  loss = 2.7412e+00
# nt_epoch =  30000  elapsed = 01:35 (+34.8)  loss = 2.7231e+00
# nt_epoch =  31000  elapsed = 02:10 (+35.1)  loss = 2.7069e+00
# nt_epoch =  32000  elapsed = 02:45 (+35.2)  loss = 2.6942e+00
# nt_epoch =  33000  elapsed = 03:20 (+35.2)  loss = 2.6818e+00
# nt_epoch =  34000  elapsed = 03:55 (+35.0)  loss = 2.6690e+00
# nt_epoch =  35000  elapsed = 04:30 (+34.8)  loss = 2.6593e+00
# nt_epoch =  36000  elapsed = 05:05 (+34.9)  loss = 2.6492e+00
# nt_epoch =  37000  elapsed = 05:40 (+35.1)  loss = 2.6398e+00
# nt_epoch =  38000  elapsed = 06:16 (+35.4)  loss = 2.6284e+00
# nt_epoch =  39000  elapsed = 06:51 (+34.8)  loss = 2.6174e+00
# nt_epoch =  40000  elapsed = 07:26 (+35.3)  loss = 2.6075e+00
# nt_epoch =  41000  elapsed = 08:01 (+34.8)  loss = 2.5989e+00
# nt_epoch =  42000  elapsed = 08:36 (+34.9)  loss = 2.5900e+00
# nt_epoch =  43000  elapsed = 09:11 (+35.1)  loss = 2.5803e+00
# nt_epoch =  44000  elapsed = 09:46 (+35.2)  loss = 2.5708e+00
# nt_epoch =  45000  elapsed = 10:21 (+35.3)  loss = 2.5603e+00
# nt_epoch =  46000  elapsed = 10:57 (+35.1)  loss = 2.5525e+00
# nt_epoch =  47000  elapsed = 11:32 (+34.8)  loss = 2.5449e+00
# nt_epoch =  48000  elapsed = 12:06 (+34.8)  loss = 2.5384e+00
# nt_epoch =  49000  elapsed = 12:41 (+35.1)  loss = 2.5326e+00
# ==================
# Training finished (epoch 150000): duration = 13:04  error = 2.6364e-01

# %%
# plot
vranges = {}
vranges['u - u obs']=[-500, 500]
vranges['v - v obs']=[-500, 500]
vranges['H - H obs']=[-100, 100]
vranges['h - h obs']=[-100, 100]
vranges['C - C obs']=[-2000, 2000]
vranges['C pred']=[0, 8000]
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub, vranges)

# history
plot_log_history(pinn)
