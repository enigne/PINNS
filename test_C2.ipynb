# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSANN_calvingfront_invertC
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 500
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 5]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
# path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_segCF.mat")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data_all(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSANN_calvingfront_invertC(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        mu=1.2680e8,
        loss_weights=[1e-5, 1e-3, 1e-5, 1e-9, 1e-16])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 500,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     5
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# train the model
pinn.fit(X_u_train, u_train)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer (MinmaxSc (None, 2)                 6
# _________________________________________________________________
# dense (Dense)                (None, 20)                60
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 105
# _________________________________________________________________
# up_scale_layer (UpScaleLayer (None, 5)                 12
# =================================================================
# Total params: 3,123
# Trainable params: 3,105
# Non-trainable params: 18
# _________________________________________________________________
# None
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:19 (+19.7)  loss = 6.6922e+03
# tf_epoch =   1000  elapsed = 00:49 (+30.0)  loss = 1.4391e+02
# tf_epoch =   2000  elapsed = 01:19 (+29.2)  loss = 1.3082e+02
# tf_epoch =   3000  elapsed = 01:48 (+29.4)  loss = 8.3022e+01
# tf_epoch =   4000  elapsed = 02:17 (+29.2)  loss = 3.6295e+01
# tf_epoch =   5000  elapsed = 02:46 (+29.2)  loss = 2.2251e+01
# tf_epoch =   6000  elapsed = 03:16 (+29.3)  loss = 1.6060e+01
# tf_epoch =   7000  elapsed = 03:45 (+29.0)  loss = 1.1005e+01
# tf_epoch =   8000  elapsed = 04:14 (+29.1)  loss = 7.5271e+00
# tf_epoch =   9000  elapsed = 04:43 (+29.3)  loss = 6.0056e+00
# tf_epoch =  10000  elapsed = 05:12 (+29.0)  loss = 5.1792e+00
# tf_epoch =  11000  elapsed = 05:42 (+29.2)  loss = 4.6349e+00
# tf_epoch =  12000  elapsed = 06:11 (+28.9)  loss = 4.2032e+00
# tf_epoch =  13000  elapsed = 06:40 (+29.0)  loss = 3.8603e+00
# tf_epoch =  14000  elapsed = 07:09 (+29.5)  loss = 3.6541e+00
# tf_epoch =  15000  elapsed = 07:38 (+29.3)  loss = 3.4662e+00
# tf_epoch =  16000  elapsed = 08:08 (+29.2)  loss = 3.3181e+00
# tf_epoch =  17000  elapsed = 08:37 (+29.3)  loss = 3.2330e+00
# tf_epoch =  18000  elapsed = 09:06 (+28.9)  loss = 3.1408e+00
# tf_epoch =  19000  elapsed = 09:35 (+29.2)  loss = 3.0462e+00
# tf_epoch =  20000  elapsed = 10:04 (+28.9)  loss = 2.9425e+00
# tf_epoch =  21000  elapsed = 10:33 (+29.1)  loss = 2.8293e+00
# tf_epoch =  22000  elapsed = 11:03 (+29.0)  loss = 2.7428e+00
# tf_epoch =  23000  elapsed = 11:32 (+29.0)  loss = 2.6223e+00
# tf_epoch =  24000  elapsed = 12:01 (+29.2)  loss = 2.5302e+00
# tf_epoch =  25000  elapsed = 12:30 (+29.2)  loss = 2.4711e+00
# tf_epoch =  26000  elapsed = 13:00 (+29.4)  loss = 2.3743e+00
# tf_epoch =  27000  elapsed = 13:29 (+29.1)  loss = 2.3159e+00
# tf_epoch =  28000  elapsed = 13:58 (+29.0)  loss = 2.2399e+00
# tf_epoch =  29000  elapsed = 14:27 (+29.3)  loss = 2.1805e+00
# tf_epoch =  30000  elapsed = 14:56 (+29.1)  loss = 2.1204e+00
# tf_epoch =  31000  elapsed = 15:25 (+29.1)  loss = 2.0939e+00
# tf_epoch =  32000  elapsed = 15:55 (+29.3)  loss = 2.0610e+00
# tf_epoch =  33000  elapsed = 16:24 (+29.0)  loss = 1.9936e+00
# tf_epoch =  34000  elapsed = 16:53 (+28.9)  loss = 1.9731e+00
# tf_epoch =  35000  elapsed = 17:22 (+29.4)  loss = 1.9307e+00
# tf_epoch =  36000  elapsed = 17:52 (+29.2)  loss = 1.8925e+00
# tf_epoch =  37000  elapsed = 18:21 (+28.9)  loss = 1.8655e+00
# tf_epoch =  38000  elapsed = 18:50 (+29.2)  loss = 1.8293e+00
# tf_epoch =  39000  elapsed = 19:19 (+29.0)  loss = 1.8088e+00
# tf_epoch =  40000  elapsed = 19:48 (+29.0)  loss = 1.7797e+00
# tf_epoch =  41000  elapsed = 20:17 (+29.5)  loss = 1.7330e+00
# tf_epoch =  42000  elapsed = 20:46 (+29.0)  loss = 1.7104e+00
# tf_epoch =  43000  elapsed = 21:16 (+29.0)  loss = 1.6778e+00
# tf_epoch =  44000  elapsed = 21:45 (+29.2)  loss = 1.8582e+00
# tf_epoch =  45000  elapsed = 22:14 (+29.3)  loss = 1.6217e+00
# tf_epoch =  46000  elapsed = 22:44 (+29.4)  loss = 1.5949e+00
# tf_epoch =  47000  elapsed = 23:13 (+29.3)  loss = 1.5825e+00
# tf_epoch =  48000  elapsed = 23:42 (+29.0)  loss = 1.5609e+00
# tf_epoch =  49000  elapsed = 24:11 (+29.2)  loss = 1.5168e+00
# tf_epoch =  50000  elapsed = 24:40 (+29.0)  loss = 1.4935e+00
# tf_epoch =  51000  elapsed = 25:09 (+28.9)  loss = 1.4797e+00
# tf_epoch =  52000  elapsed = 25:38 (+29.1)  loss = 1.4551e+00
# tf_epoch =  53000  elapsed = 26:07 (+29.0)  loss = 1.4404e+00
# tf_epoch =  54000  elapsed = 26:37 (+29.8)  loss = 1.4155e+00
# tf_epoch =  55000  elapsed = 27:07 (+29.9)  loss = 1.4007e+00
# tf_epoch =  56000  elapsed = 27:37 (+30.1)  loss = 1.3809e+00
# tf_epoch =  57000  elapsed = 28:07 (+29.4)  loss = 1.3570e+00
# tf_epoch =  58000  elapsed = 28:36 (+29.5)  loss = 1.3387e+00
# tf_epoch =  59000  elapsed = 29:06 (+29.6)  loss = 1.3193e+00
# tf_epoch =  60000  elapsed = 29:35 (+29.1)  loss = 1.3014e+00
# tf_epoch =  61000  elapsed = 30:05 (+29.8)  loss = 1.2807e+00
# tf_epoch =  62000  elapsed = 30:35 (+29.7)  loss = 1.2644e+00
# tf_epoch =  63000  elapsed = 31:04 (+29.5)  loss = 1.2410e+00
# tf_epoch =  64000  elapsed = 31:33 (+29.0)  loss = 1.2245e+00
# tf_epoch =  65000  elapsed = 32:03 (+29.4)  loss = 1.2062e+00
# tf_epoch =  66000  elapsed = 32:33 (+29.8)  loss = 1.1871e+00
# tf_epoch =  67000  elapsed = 33:02 (+29.2)  loss = 1.1712e+00
# tf_epoch =  68000  elapsed = 33:32 (+29.9)  loss = 1.1525e+00
# tf_epoch =  69000  elapsed = 34:01 (+29.6)  loss = 1.1358e+00
# tf_epoch =  70000  elapsed = 34:31 (+29.5)  loss = 1.1214e+00
# tf_epoch =  71000  elapsed = 35:00 (+29.1)  loss = 1.1064e+00
# tf_epoch =  72000  elapsed = 35:29 (+29.3)  loss = 1.0926e+00
# tf_epoch =  73000  elapsed = 35:59 (+29.5)  loss = 1.0820e+00
# tf_epoch =  74000  elapsed = 36:28 (+29.3)  loss = 1.1219e+00
# tf_epoch =  75000  elapsed = 36:58 (+29.4)  loss = 1.0658e+00
# tf_epoch =  76000  elapsed = 37:27 (+29.6)  loss = 1.0485e+00
# tf_epoch =  77000  elapsed = 37:57 (+29.4)  loss = 1.0395e+00
# tf_epoch =  78000  elapsed = 38:26 (+29.4)  loss = 1.0309e+00
# tf_epoch =  79000  elapsed = 38:56 (+29.7)  loss = 1.0190e+00
# tf_epoch =  80000  elapsed = 39:25 (+29.4)  loss = 1.0108e+00
# tf_epoch =  81000  elapsed = 39:55 (+29.1)  loss = 1.0077e+00
# tf_epoch =  82000  elapsed = 40:24 (+29.2)  loss = 9.9259e-01
# tf_epoch =  83000  elapsed = 40:53 (+29.4)  loss = 9.8468e-01
# tf_epoch =  84000  elapsed = 41:23 (+29.6)  loss = 9.7524e-01
# tf_epoch =  85000  elapsed = 41:53 (+30.0)  loss = 9.6817e-01
# tf_epoch =  86000  elapsed = 42:23 (+30.0)  loss = 9.5807e-01
# tf_epoch =  87000  elapsed = 42:53 (+29.4)  loss = 9.5429e-01
# tf_epoch =  88000  elapsed = 43:22 (+29.4)  loss = 9.4596e-01
# tf_epoch =  89000  elapsed = 43:51 (+29.0)  loss = 9.3904e-01
# tf_epoch =  90000  elapsed = 44:20 (+29.3)  loss = 9.3169e-01
# tf_epoch =  91000  elapsed = 44:50 (+29.2)  loss = 9.2497e-01
# tf_epoch =  92000  elapsed = 45:19 (+29.5)  loss = 9.2051e-01
# tf_epoch =  93000  elapsed = 45:49 (+29.2)  loss = 9.1630e-01
# tf_epoch =  94000  elapsed = 46:18 (+29.5)  loss = 9.5761e-01
# tf_epoch =  95000  elapsed = 46:47 (+29.1)  loss = 9.0450e-01
# tf_epoch =  96000  elapsed = 47:17 (+29.7)  loss = 8.9973e-01
# tf_epoch =  97000  elapsed = 47:47 (+29.6)  loss = 8.9565e-01
# tf_epoch =  98000  elapsed = 48:16 (+29.2)  loss = 8.9645e-01
# tf_epoch =  99000  elapsed = 48:46 (+30.1)  loss = 8.8902e-01
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =   1000  elapsed = 50:05 (+18.5)  loss = 8.7743e-01
# nt_epoch =   2000  elapsed = 50:46 (+41.2)  loss = 8.7718e-01
# nt_epoch =   3000  elapsed = 51:28 (+42.1)  loss = 8.7718e-01
# nt_epoch =   4000  elapsed = 52:10 (+41.3)  loss = 8.7714e-01
# nt_epoch =   5000  elapsed = 52:51 (+41.2)  loss = 8.7709e-01
# nt_epoch =   6000  elapsed = 53:33 (+41.8)  loss = 8.7709e-01
# nt_epoch =   7000  elapsed = 54:14 (+41.5)  loss = 8.7709e-01
# nt_epoch =   8000  elapsed = 54:56 (+41.7)  loss = 8.7709e-01
# nt_epoch =   9000  elapsed = 55:37 (+41.6)  loss = 8.7709e-01
# nt_epoch =  10000  elapsed = 56:19 (+41.9)  loss = 8.7709e-01
# nt_epoch =  11000  elapsed = 57:00 (+40.6)  loss = 8.7709e-01
# ==================
# Training finished (epoch 150000): duration = 57:15  error = 3.1392e-01

# %%
# plot
vranges = {}
vranges['u - u obs']=[-500, 500]
vranges['v - v obs']=[-500, 500]
vranges['H - H obs']=[-100, 100]
vranges['h - h obs']=[-100, 100]
vranges['C - C obs']=[-2000, 2000]
vranges['C pred']=[0, 8000]
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub, vranges)

# history
plot_log_history(pinn)
