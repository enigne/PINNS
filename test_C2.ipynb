# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSANN_invertC
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 500
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 5]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
# path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
# path = os.path.join(appDataPath, "SSA2D_segCF.mat")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow.mat")
modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_Dirichlet(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSANN_invertC(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        mu=1.2680e8,
        loss_weights=[1e-5, 1e-3, 1e-5, 1e-8])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 500,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     5
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# train the model
pinn.fit(X_u_train, u_train)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:15 (+15.9)  loss = 1.4743e+04
# tf_epoch =   1000  elapsed = 00:40 (+24.7)  loss = 1.6180e+02
# tf_epoch =   2000  elapsed = 01:05 (+24.8)  loss = 1.5801e+02
# tf_epoch =   3000  elapsed = 01:30 (+24.9)  loss = 1.3477e+02
# tf_epoch =   4000  elapsed = 01:55 (+24.6)  loss = 1.0517e+02
# tf_epoch =   5000  elapsed = 02:20 (+24.8)  loss = 5.1219e+01
# tf_epoch =   6000  elapsed = 02:44 (+24.7)  loss = 2.6298e+01
# tf_epoch =   7000  elapsed = 03:09 (+24.7)  loss = 1.7481e+01
# tf_epoch =   8000  elapsed = 03:34 (+24.4)  loss = 1.3111e+01
# tf_epoch =   9000  elapsed = 03:58 (+24.8)  loss = 1.0249e+01
# tf_epoch =  10000  elapsed = 04:23 (+24.4)  loss = 8.3415e+00
# tf_epoch =  11000  elapsed = 04:48 (+24.7)  loss = 6.9249e+00
# tf_epoch =  12000  elapsed = 05:12 (+24.6)  loss = 6.1652e+00
# tf_epoch =  13000  elapsed = 05:37 (+24.5)  loss = 5.8146e+00
# tf_epoch =  14000  elapsed = 06:01 (+24.5)  loss = 5.4231e+00
# tf_epoch =  15000  elapsed = 06:26 (+24.8)  loss = 5.1657e+00
# tf_epoch =  16000  elapsed = 06:51 (+24.5)  loss = 4.9338e+00
# tf_epoch =  17000  elapsed = 07:16 (+24.7)  loss = 4.7438e+00
# tf_epoch =  18000  elapsed = 07:40 (+24.5)  loss = 4.6142e+00
# tf_epoch =  19000  elapsed = 08:05 (+24.4)  loss = 4.4930e+00
# tf_epoch =  20000  elapsed = 08:29 (+24.4)  loss = 4.3757e+00
# tf_epoch =  21000  elapsed = 08:54 (+24.8)  loss = 4.2341e+00
# tf_epoch =  22000  elapsed = 09:18 (+24.3)  loss = 4.1537e+00
# tf_epoch =  23000  elapsed = 09:43 (+24.5)  loss = 4.0914e+00
# tf_epoch =  24000  elapsed = 10:07 (+24.4)  loss = 3.9898e+00
# tf_epoch =  25000  elapsed = 10:32 (+24.5)  loss = 3.9060e+00
# tf_epoch =  26000  elapsed = 10:57 (+24.7)  loss = 3.8268e+00
# tf_epoch =  27000  elapsed = 11:21 (+24.2)  loss = 3.7523e+00
# tf_epoch =  28000  elapsed = 11:45 (+24.5)  loss = 3.6889e+00
# tf_epoch =  29000  elapsed = 12:10 (+24.4)  loss = 3.6330e+00
# tf_epoch =  30000  elapsed = 12:35 (+24.7)  loss = 3.5574e+00
# tf_epoch =  31000  elapsed = 12:59 (+24.4)  loss = 3.4588e+00
# tf_epoch =  32000  elapsed = 13:23 (+24.4)  loss = 3.3925e+00
# tf_epoch =  33000  elapsed = 13:48 (+24.5)  loss = 3.3704e+00
# tf_epoch =  34000  elapsed = 14:13 (+24.5)  loss = 3.2907e+00
# tf_epoch =  35000  elapsed = 14:37 (+24.5)  loss = 3.2177e+00
# tf_epoch =  36000  elapsed = 15:02 (+24.5)  loss = 3.1236e+00
# tf_epoch =  37000  elapsed = 15:26 (+24.5)  loss = 3.0890e+00
# tf_epoch =  38000  elapsed = 15:51 (+24.5)  loss = 3.0315e+00
# tf_epoch =  39000  elapsed = 16:15 (+24.4)  loss = 2.9429e+00
# tf_epoch =  40000  elapsed = 16:40 (+24.4)  loss = 2.9134e+00
# tf_epoch =  41000  elapsed = 17:04 (+24.3)  loss = 2.8454e+00
# tf_epoch =  42000  elapsed = 17:28 (+24.3)  loss = 2.7999e+00
# tf_epoch =  43000  elapsed = 17:53 (+24.3)  loss = 2.7732e+00
# tf_epoch =  44000  elapsed = 18:18 (+24.8)  loss = 2.7365e+00
# tf_epoch =  45000  elapsed = 18:43 (+25.0)  loss = 2.6714e+00
# tf_epoch =  46000  elapsed = 19:07 (+24.4)  loss = 2.6365e+00
# tf_epoch =  47000  elapsed = 19:32 (+24.7)  loss = 2.6069e+00
# tf_epoch =  48000  elapsed = 19:57 (+24.7)  loss = 2.5574e+00
# tf_epoch =  49000  elapsed = 20:21 (+24.6)  loss = 2.5031e+00
# tf_epoch =  50000  elapsed = 20:46 (+24.5)  loss = 2.5043e+00
# tf_epoch =  51000  elapsed = 21:10 (+24.3)  loss = 2.4184e+00
# tf_epoch =  52000  elapsed = 21:35 (+24.3)  loss = 2.3926e+00
# tf_epoch =  53000  elapsed = 21:59 (+24.3)  loss = 2.4024e+00
# tf_epoch =  54000  elapsed = 22:23 (+24.3)  loss = 2.3560e+00
# tf_epoch =  55000  elapsed = 22:48 (+24.5)  loss = 2.2905e+00
# tf_epoch =  56000  elapsed = 23:13 (+24.8)  loss = 2.2690e+00
# tf_epoch =  57000  elapsed = 23:37 (+24.4)  loss = 2.2616e+00
# tf_epoch =  58000  elapsed = 24:02 (+24.5)  loss = 2.2161e+00
# tf_epoch =  59000  elapsed = 24:26 (+24.2)  loss = 2.2609e+00
# tf_epoch =  60000  elapsed = 24:51 (+24.7)  loss = 2.1972e+00
# tf_epoch =  61000  elapsed = 25:16 (+24.9)  loss = 2.2422e+00
# tf_epoch =  62000  elapsed = 25:40 (+24.7)  loss = 2.1151e+00
# tf_epoch =  63000  elapsed = 26:05 (+24.3)  loss = 2.1109e+00
# tf_epoch =  64000  elapsed = 26:29 (+24.3)  loss = 2.0715e+00
# tf_epoch =  65000  elapsed = 26:54 (+24.4)  loss = 2.1106e+00
# tf_epoch =  66000  elapsed = 27:18 (+24.4)  loss = 2.0456e+00
# tf_epoch =  67000  elapsed = 27:42 (+24.3)  loss = 2.0374e+00
# tf_epoch =  68000  elapsed = 28:07 (+24.4)  loss = 2.0514e+00
# tf_epoch =  69000  elapsed = 28:31 (+24.5)  loss = 1.9660e+00
# tf_epoch =  70000  elapsed = 28:56 (+24.4)  loss = 1.9864e+00
# tf_epoch =  71000  elapsed = 29:20 (+24.3)  loss = 1.9421e+00
# tf_epoch =  72000  elapsed = 29:45 (+24.6)  loss = 1.9406e+00
# tf_epoch =  73000  elapsed = 30:09 (+24.4)  loss = 1.9172e+00
# tf_epoch =  74000  elapsed = 30:34 (+24.3)  loss = 1.8998e+00
# tf_epoch =  75000  elapsed = 30:58 (+24.5)  loss = 1.8998e+00
# tf_epoch =  76000  elapsed = 31:23 (+24.4)  loss = 1.8454e+00
# tf_epoch =  77000  elapsed = 31:47 (+24.2)  loss = 1.8829e+00
# tf_epoch =  78000  elapsed = 32:11 (+24.4)  loss = 1.8369e+00
# tf_epoch =  79000  elapsed = 32:36 (+24.4)  loss = 1.8078e+00
# tf_epoch =  80000  elapsed = 33:01 (+24.6)  loss = 1.8033e+00
# tf_epoch =  81000  elapsed = 33:25 (+24.2)  loss = 1.8092e+00
# tf_epoch =  82000  elapsed = 33:49 (+24.5)  loss = 1.7739e+00
# tf_epoch =  83000  elapsed = 34:14 (+24.7)  loss = 1.7404e+00
# tf_epoch =  84000  elapsed = 34:39 (+24.8)  loss = 1.7206e+00
# tf_epoch =  85000  elapsed = 35:03 (+24.3)  loss = 1.6947e+00
# tf_epoch =  86000  elapsed = 35:28 (+24.2)  loss = 1.6947e+00
# tf_epoch =  87000  elapsed = 35:52 (+24.6)  loss = 1.6753e+00
# tf_epoch =  88000  elapsed = 36:17 (+24.5)  loss = 1.6709e+00
# tf_epoch =  89000  elapsed = 36:42 (+24.8)  loss = 1.6472e+00
# tf_epoch =  90000  elapsed = 37:06 (+24.5)  loss = 1.6363e+00
# tf_epoch =  91000  elapsed = 37:31 (+24.5)  loss = 1.6189e+00
# tf_epoch =  92000  elapsed = 37:55 (+24.3)  loss = 1.6082e+00
# tf_epoch =  93000  elapsed = 38:19 (+24.4)  loss = 1.5840e+00
# tf_epoch =  94000  elapsed = 38:44 (+24.5)  loss = 1.5731e+00
# tf_epoch =  95000  elapsed = 39:09 (+24.6)  loss = 1.5682e+00
# tf_epoch =  96000  elapsed = 39:33 (+24.4)  loss = 1.5444e+00
# tf_epoch =  97000  elapsed = 39:58 (+25.1)  loss = 1.5338e+00
# tf_epoch =  98000  elapsed = 40:23 (+24.5)  loss = 1.5244e+00
# tf_epoch =  99000  elapsed = 40:47 (+24.4)  loss = 1.5142e+00
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =   1000  elapsed = 41:53 (+05.2)  loss = 1.4857e+00
# nt_epoch =   2000  elapsed = 42:25 (+32.5)  loss = 1.4738e+00
# nt_epoch =   3000  elapsed = 42:58 (+32.7)  loss = 1.4708e+00
# nt_epoch =   4000  elapsed = 43:31 (+32.7)  loss = 1.4687e+00
# nt_epoch =   5000  elapsed = 44:04 (+32.9)  loss = 1.4662e+00
# nt_epoch =   6000  elapsed = 44:36 (+32.6)  loss = 1.4639e+00
# nt_epoch =   7000  elapsed = 45:09 (+33.0)  loss = 1.4616e+00
# nt_epoch =   8000  elapsed = 45:42 (+32.8)  loss = 1.4587e+00
# nt_epoch =   9000  elapsed = 46:15 (+32.8)  loss = 1.4564e+00
# nt_epoch =  10000  elapsed = 46:48 (+32.5)  loss = 1.4537e+00
# nt_epoch =  11000  elapsed = 47:20 (+32.6)  loss = 1.4498e+00
# nt_epoch =  12000  elapsed = 47:53 (+32.8)  loss = 1.4447e+00
# nt_epoch =  13000  elapsed = 48:26 (+32.9)  loss = 1.4412e+00
# nt_epoch =  14000  elapsed = 48:59 (+33.0)  loss = 1.4389e+00
# nt_epoch =  15000  elapsed = 49:32 (+32.8)  loss = 1.4354e+00
# nt_epoch =  16000  elapsed = 50:05 (+32.9)  loss = 1.4327e+00
# nt_epoch =  17000  elapsed = 50:37 (+32.6)  loss = 1.4303e+00
# nt_epoch =  18000  elapsed = 51:10 (+32.6)  loss = 1.4288e+00
# nt_epoch =  19000  elapsed = 51:43 (+32.8)  loss = 1.4268e+00
# nt_epoch =  20000  elapsed = 52:16 (+32.6)  loss = 1.4247e+00
# nt_epoch =  21000  elapsed = 52:49 (+32.9)  loss = 1.4225e+00
# nt_epoch =  22000  elapsed = 53:21 (+32.6)  loss = 1.4209e+00
# nt_epoch =  23000  elapsed = 53:54 (+32.6)  loss = 1.4188e+00
# nt_epoch =  24000  elapsed = 54:26 (+32.5)  loss = 1.4165e+00
# nt_epoch =  25000  elapsed = 54:59 (+32.4)  loss = 1.4140e+00
# nt_epoch =  26000  elapsed = 55:31 (+32.5)  loss = 1.4097e+00
# nt_epoch =  27000  elapsed = 56:04 (+32.9)  loss = 1.4068e+00
# nt_epoch =  28000  elapsed = 56:37 (+32.9)  loss = 1.4039e+00
# nt_epoch =  29000  elapsed = 57:10 (+33.0)  loss = 1.3998e+00
# nt_epoch =  30000  elapsed = 57:43 (+32.9)  loss = 1.3957e+00
# nt_epoch =  31000  elapsed = 58:16 (+33.0)  loss = 1.3904e+00
# nt_epoch =  32000  elapsed = 58:49 (+32.6)  loss = 1.3858e+00
# nt_epoch =  33000  elapsed = 59:21 (+32.4)  loss = 1.3804e+00
# nt_epoch =  34000  elapsed = 59:54 (+32.4)  loss = 1.3757e+00
# nt_epoch =  35000  elapsed = 00:26 (+32.3)  loss = 1.3707e+00
# nt_epoch =  36000  elapsed = 00:59 (+32.4)  loss = 1.3650e+00
# nt_epoch =  37000  elapsed = 01:32 (+32.8)  loss = 1.3592e+00
# nt_epoch =  38000  elapsed = 02:04 (+32.4)  loss = 1.3553e+00
# nt_epoch =  39000  elapsed = 02:37 (+32.5)  loss = 1.3525e+00
# nt_epoch =  40000  elapsed = 03:10 (+32.9)  loss = 1.3501e+00
# nt_epoch =  41000  elapsed = 03:42 (+32.3)  loss = 1.3489e+00
# nt_epoch =  42000  elapsed = 04:14 (+32.6)  loss = 1.3482e+00
# nt_epoch =  43000  elapsed = 04:47 (+32.6)  loss = 1.3474e+00
# nt_epoch =  44000  elapsed = 05:19 (+32.3)  loss = 1.3467e+00
# nt_epoch =  45000  elapsed = 05:52 (+32.9)  loss = 1.3459e+00
# nt_epoch =  46000  elapsed = 06:25 (+32.6)  loss = 1.3451e+00
# nt_epoch =  47000  elapsed = 06:58 (+32.5)  loss = 1.3445e+00
# nt_epoch =  48000  elapsed = 07:30 (+32.4)  loss = 1.3440e+00
# ==================
# Training finished (epoch 150000): duration = 08:00  error = 2.1209e-01

# %%
# plot
vranges = {}
vranges['u - u obs']=[-500, 500]
vranges['v - v obs']=[-500, 500]
vranges['H - H obs']=[-100, 100]
vranges['h - h obs']=[-100, 100]
vranges['C - C obs']=[-2000, 2000]
vranges['C pred']=[0, 8000]
plot_Helheim_all(pinn, X_f, X_star, u_star, xlb, xub, vranges)

# history
plot_log_history(pinn)
