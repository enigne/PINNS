# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAInformedNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 0
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = False
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
path = os.path.join(appDataPath, "SSA2D_circleF.mat")
# path = os.path.join(appDataPath, "SSA2D_segCF.mat")
modelPath = "./Models/SheetCircleF"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAInformedNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8, 
        geoDataNN="./Models/SheetCircleF_H_bed/", 
        FrictionCNN="./Models/SheetCircleF_C/")

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": false,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# WARNING:tensorflow:From ./utils/logger.py:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# train the model
#pinn.fit(X_star, u_star)
pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:19 (+19.3)  loss = 4.5789e+05
# tf_epoch =   1000  elapsed = 00:42 (+23.1)  loss = 8.0628e+02
# tf_epoch =   2000  elapsed = 01:05 (+23.0)  loss = 5.7189e+02
# tf_epoch =   3000  elapsed = 01:28 (+23.0)  loss = 4.6723e+02
# tf_epoch =   4000  elapsed = 01:51 (+23.0)  loss = 3.7980e+02
# tf_epoch =   5000  elapsed = 02:14 (+23.1)  loss = 3.2137e+02
# tf_epoch =   6000  elapsed = 02:37 (+23.0)  loss = 1.1235e+03
# tf_epoch =   7000  elapsed = 03:01 (+23.1)  loss = 2.9479e+02
# tf_epoch =   8000  elapsed = 03:24 (+23.1)  loss = 2.7062e+02
# tf_epoch =   9000  elapsed = 03:47 (+23.1)  loss = 2.5675e+02
# tf_epoch =  10000  elapsed = 04:10 (+23.1)  loss = 2.2522e+02
# tf_epoch =  11000  elapsed = 04:33 (+23.1)  loss = 2.1012e+02
# tf_epoch =  12000  elapsed = 04:56 (+23.1)  loss = 1.8479e+02
# tf_epoch =  13000  elapsed = 05:19 (+23.1)  loss = 1.7556e+02
# tf_epoch =  14000  elapsed = 05:43 (+23.1)  loss = 1.5718e+02
# tf_epoch =  15000  elapsed = 06:06 (+23.1)  loss = 1.3468e+02
# tf_epoch =  16000  elapsed = 06:29 (+23.1)  loss = 1.2894e+02
# tf_epoch =  17000  elapsed = 06:52 (+23.1)  loss = 1.1397e+02
# tf_epoch =  18000  elapsed = 07:15 (+23.1)  loss = 1.2605e+02
# tf_epoch =  19000  elapsed = 07:38 (+23.1)  loss = 1.0734e+02
# tf_epoch =  20000  elapsed = 08:01 (+23.1)  loss = 8.9139e+01
# tf_epoch =  21000  elapsed = 08:25 (+23.1)  loss = 8.0108e+01
# tf_epoch =  22000  elapsed = 08:48 (+23.1)  loss = 1.1333e+02
# tf_epoch =  23000  elapsed = 09:11 (+23.1)  loss = 8.3836e+01
# tf_epoch =  24000  elapsed = 09:34 (+23.1)  loss = 8.2339e+01
# tf_epoch =  25000  elapsed = 09:57 (+23.1)  loss = 6.9593e+01
# tf_epoch =  26000  elapsed = 10:20 (+23.1)  loss = 7.1236e+01
# tf_epoch =  27000  elapsed = 10:43 (+23.1)  loss = 6.3003e+01
# tf_epoch =  28000  elapsed = 11:07 (+23.1)  loss = 6.2744e+01
# tf_epoch =  29000  elapsed = 11:30 (+23.1)  loss = 6.8139e+01
# tf_epoch =  30000  elapsed = 11:53 (+23.1)  loss = 6.4771e+01
# tf_epoch =  31000  elapsed = 12:16 (+23.3)  loss = 4.3069e+01
# tf_epoch =  32000  elapsed = 12:39 (+23.1)  loss = 3.7932e+01
# tf_epoch =  33000  elapsed = 13:02 (+23.1)  loss = 3.2973e+01
# tf_epoch =  34000  elapsed = 13:26 (+23.1)  loss = 4.2594e+01
# tf_epoch =  35000  elapsed = 13:49 (+23.1)  loss = 3.0931e+01
# tf_epoch =  36000  elapsed = 14:12 (+23.1)  loss = 2.8690e+01
# tf_epoch =  37000  elapsed = 14:35 (+23.1)  loss = 2.6566e+01
# tf_epoch =  38000  elapsed = 14:58 (+23.1)  loss = 2.8527e+01
# tf_epoch =  39000  elapsed = 15:22 (+23.3)  loss = 3.4015e+01
# tf_epoch =  40000  elapsed = 15:45 (+23.1)  loss = 2.3266e+01
# tf_epoch =  41000  elapsed = 16:08 (+23.1)  loss = 2.2090e+01
# tf_epoch =  42000  elapsed = 16:31 (+23.1)  loss = 2.0648e+01
# tf_epoch =  43000  elapsed = 16:54 (+23.1)  loss = 2.8458e+01
# tf_epoch =  44000  elapsed = 17:17 (+23.1)  loss = 1.9378e+01
# tf_epoch =  45000  elapsed = 17:40 (+23.1)  loss = 1.8572e+01
# tf_epoch =  46000  elapsed = 18:04 (+23.1)  loss = 5.1799e+01
# tf_epoch =  47000  elapsed = 18:27 (+23.1)  loss = 1.8054e+01
# tf_epoch =  48000  elapsed = 18:50 (+23.1)  loss = 2.9930e+01
# tf_epoch =  49000  elapsed = 19:13 (+23.1)  loss = 1.7979e+01
# tf_epoch =  50000  elapsed = 19:36 (+23.1)  loss = 1.7251e+01
# tf_epoch =  51000  elapsed = 19:59 (+23.1)  loss = 2.9297e+01
# tf_epoch =  52000  elapsed = 20:22 (+23.1)  loss = 1.8501e+01
# tf_epoch =  53000  elapsed = 20:46 (+23.1)  loss = 1.9710e+01
# tf_epoch =  54000  elapsed = 21:09 (+23.1)  loss = 1.7149e+01
# tf_epoch =  55000  elapsed = 21:32 (+23.1)  loss = 2.8562e+01
# tf_epoch =  56000  elapsed = 21:55 (+23.1)  loss = 2.5126e+01
# tf_epoch =  57000  elapsed = 22:18 (+23.1)  loss = 1.6108e+01
# tf_epoch =  58000  elapsed = 22:41 (+23.1)  loss = 1.5580e+01
# tf_epoch =  59000  elapsed = 23:05 (+23.1)  loss = 2.3158e+01
# tf_epoch =  60000  elapsed = 23:28 (+23.1)  loss = 1.5012e+01
# tf_epoch =  61000  elapsed = 23:51 (+23.1)  loss = 1.4095e+01
# tf_epoch =  62000  elapsed = 24:14 (+23.1)  loss = 1.3370e+01
# tf_epoch =  63000  elapsed = 24:37 (+23.1)  loss = 1.6175e+01
# tf_epoch =  64000  elapsed = 25:00 (+23.1)  loss = 1.2971e+01
# tf_epoch =  65000  elapsed = 25:24 (+23.2)  loss = 1.2442e+01
# tf_epoch =  66000  elapsed = 25:47 (+23.1)  loss = 1.1773e+01
# tf_epoch =  67000  elapsed = 26:10 (+23.1)  loss = 2.5106e+01
# tf_epoch =  68000  elapsed = 26:33 (+23.1)  loss = 1.1532e+01
# tf_epoch =  69000  elapsed = 26:56 (+23.1)  loss = 1.0737e+01
# tf_epoch =  70000  elapsed = 27:19 (+23.1)  loss = 9.7610e+00
# tf_epoch =  71000  elapsed = 27:43 (+23.1)  loss = 8.7396e+00
# tf_epoch =  72000  elapsed = 28:06 (+23.1)  loss = 1.6991e+01
# tf_epoch =  73000  elapsed = 28:29 (+23.1)  loss = 8.4004e+00
# tf_epoch =  74000  elapsed = 28:52 (+23.1)  loss = 7.9217e+00
# tf_epoch =  75000  elapsed = 29:15 (+23.1)  loss = 7.3678e+00
# tf_epoch =  76000  elapsed = 29:38 (+23.1)  loss = 6.5918e+00
# tf_epoch =  77000  elapsed = 30:02 (+23.1)  loss = 6.6416e+00
# tf_epoch =  78000  elapsed = 30:25 (+23.1)  loss = 6.1806e+00
# tf_epoch =  79000  elapsed = 30:48 (+23.1)  loss = 5.8100e+00
# tf_epoch =  80000  elapsed = 31:11 (+23.1)  loss = 3.9374e+01
# tf_epoch =  81000  elapsed = 31:34 (+23.1)  loss = 5.5385e+00
# tf_epoch =  82000  elapsed = 31:57 (+23.1)  loss = 5.2439e+00
# tf_epoch =  83000  elapsed = 32:20 (+23.1)  loss = 4.9890e+00
# tf_epoch =  84000  elapsed = 32:44 (+23.1)  loss = 1.8975e+01
# tf_epoch =  85000  elapsed = 33:07 (+23.1)  loss = 5.1130e+00
# tf_epoch =  86000  elapsed = 33:30 (+23.1)  loss = 4.6625e+00
# tf_epoch =  87000  elapsed = 33:53 (+23.1)  loss = 4.4769e+00
# tf_epoch =  88000  elapsed = 34:16 (+23.1)  loss = 4.2548e+00
# tf_epoch =  89000  elapsed = 34:40 (+23.1)  loss = 4.4992e+00
# tf_epoch =  90000  elapsed = 35:03 (+23.1)  loss = 4.0974e+00
# tf_epoch =  91000  elapsed = 35:26 (+23.1)  loss = 3.9518e+00
# tf_epoch =  92000  elapsed = 35:49 (+23.1)  loss = 3.0078e+01
# tf_epoch =  93000  elapsed = 36:12 (+23.1)  loss = 3.9340e+00
# tf_epoch =  94000  elapsed = 36:35 (+23.1)  loss = 3.7469e+00
# tf_epoch =  95000  elapsed = 36:59 (+23.1)  loss = 3.6135e+00
# tf_epoch =  96000  elapsed = 37:22 (+23.1)  loss = 3.9315e+01
# tf_epoch =  97000  elapsed = 37:45 (+23.2)  loss = 3.9336e+00
# tf_epoch =  98000  elapsed = 38:08 (+23.1)  loss = 3.4987e+00
# tf_epoch =  99000  elapsed = 38:31 (+23.1)  loss = 3.3202e+00
# -- Starting LBFGS optimization --
# ==================
# Training finished (epoch 100000): duration = 38:54  error = 1.2607e-01

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim(pinn, X_f, X_star, u_star, xlb, xub)

# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
