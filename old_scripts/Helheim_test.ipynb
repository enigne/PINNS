# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAInformedNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 300000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 0
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = False
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN.mat")
modelPath = "./Models/Helheim"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAInformedNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8, 
        loss_weights=[1e-8, 1e-12, 1e-18],
        geoDataNN="./Models/Helheim_H_bed/", 
        FrictionCNN="./Models/Helheim_C/")

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "tf_epochs": 300000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": false,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# WARNING:tensorflow:From ./utils/logger.py:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# train the model
#pinn.fit(X_star, u_star)
pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:20 (+20.8)  loss = 3.0924e-01
# tf_epoch =   1000  elapsed = 00:45 (+24.3)  loss = 4.3414e-02
# tf_epoch =   2000  elapsed = 01:08 (+23.6)  loss = 4.2186e-02
# tf_epoch =   3000  elapsed = 01:32 (+23.8)  loss = 4.1565e-02
# tf_epoch =   4000  elapsed = 01:56 (+23.6)  loss = 4.1162e-02
# tf_epoch =   5000  elapsed = 02:19 (+23.6)  loss = 4.0875e-02
# tf_epoch =   6000  elapsed = 02:44 (+24.0)  loss = 4.0689e-02
# tf_epoch =   7000  elapsed = 03:08 (+24.1)  loss = 4.0549e-02
# tf_epoch =   8000  elapsed = 03:32 (+23.8)  loss = 4.0425e-02
# tf_epoch =   9000  elapsed = 03:56 (+24.2)  loss = 4.0321e-02
# tf_epoch =  10000  elapsed = 04:19 (+23.5)  loss = 4.0239e-02
# tf_epoch =  11000  elapsed = 04:43 (+23.7)  loss = 4.0174e-02
# tf_epoch =  12000  elapsed = 05:07 (+24.2)  loss = 4.0123e-02
# tf_epoch =  13000  elapsed = 05:31 (+23.8)  loss = 4.0081e-02
# tf_epoch =  14000  elapsed = 05:55 (+23.7)  loss = 4.0043e-02
# tf_epoch =  15000  elapsed = 06:19 (+24.0)  loss = 4.0007e-02
# tf_epoch =  16000  elapsed = 06:43 (+23.5)  loss = 3.9972e-02
# tf_epoch =  17000  elapsed = 07:06 (+23.5)  loss = 3.9937e-02
# tf_epoch =  18000  elapsed = 07:30 (+23.5)  loss = 3.9903e-02
# tf_epoch =  19000  elapsed = 07:53 (+23.6)  loss = 3.9867e-02
# tf_epoch =  20000  elapsed = 08:17 (+23.6)  loss = 3.9831e-02
# tf_epoch =  21000  elapsed = 08:41 (+23.7)  loss = 3.9791e-02
# tf_epoch =  22000  elapsed = 09:04 (+23.7)  loss = 3.9742e-02
# tf_epoch =  23000  elapsed = 09:28 (+23.6)  loss = 3.9685e-02
# tf_epoch =  24000  elapsed = 09:52 (+23.8)  loss = 3.9627e-02
# tf_epoch =  25000  elapsed = 10:16 (+23.5)  loss = 3.9561e-02
# tf_epoch =  26000  elapsed = 10:39 (+23.7)  loss = 3.9492e-02
# tf_epoch =  27000  elapsed = 11:03 (+23.5)  loss = 3.9426e-02
# tf_epoch =  28000  elapsed = 11:26 (+23.5)  loss = 3.9365e-02
# tf_epoch =  29000  elapsed = 11:51 (+24.3)  loss = 3.9306e-02
# tf_epoch =  30000  elapsed = 12:14 (+23.7)  loss = 3.9251e-02
# tf_epoch =  31000  elapsed = 12:38 (+23.6)  loss = 3.9197e-02
# tf_epoch =  32000  elapsed = 13:02 (+23.5)  loss = 3.9145e-02
# tf_epoch =  33000  elapsed = 13:26 (+24.3)  loss = 3.9096e-02
# tf_epoch =  34000  elapsed = 13:50 (+23.6)  loss = 3.9050e-02
# tf_epoch =  35000  elapsed = 14:13 (+23.5)  loss = 3.9007e-02
# tf_epoch =  36000  elapsed = 14:37 (+24.0)  loss = 3.8967e-02
# tf_epoch =  37000  elapsed = 15:01 (+23.6)  loss = 3.8934e-02
# tf_epoch =  38000  elapsed = 15:24 (+23.5)  loss = 3.8900e-02
# tf_epoch =  39000  elapsed = 15:48 (+23.5)  loss = 3.8866e-02
# tf_epoch =  40000  elapsed = 16:12 (+23.6)  loss = 3.8868e-02
# tf_epoch =  41000  elapsed = 16:35 (+23.6)  loss = 3.8812e-02
# tf_epoch =  42000  elapsed = 16:59 (+23.6)  loss = 3.8786e-02
# tf_epoch =  43000  elapsed = 17:22 (+23.5)  loss = 3.8762e-02
# tf_epoch =  44000  elapsed = 17:46 (+23.6)  loss = 3.8718e-02
# tf_epoch =  45000  elapsed = 18:10 (+23.9)  loss = 3.8678e-02
# tf_epoch =  46000  elapsed = 18:33 (+23.5)  loss = 3.8656e-02
# tf_epoch =  47000  elapsed = 18:57 (+23.9)  loss = 3.8631e-02
# tf_epoch =  48000  elapsed = 19:21 (+23.9)  loss = 3.8605e-02
# tf_epoch =  49000  elapsed = 19:45 (+23.5)  loss = 3.8580e-02
# tf_epoch =  50000  elapsed = 20:08 (+23.5)  loss = 3.8561e-02
# tf_epoch =  51000  elapsed = 20:32 (+23.6)  loss = 3.8536e-02
# tf_epoch =  52000  elapsed = 20:56 (+23.7)  loss = 3.8511e-02
# tf_epoch =  53000  elapsed = 21:19 (+23.5)  loss = 3.8488e-02
# tf_epoch =  54000  elapsed = 21:43 (+23.7)  loss = 3.8474e-02
# tf_epoch =  55000  elapsed = 22:07 (+23.7)  loss = 3.8453e-02
# tf_epoch =  56000  elapsed = 22:31 (+23.6)  loss = 3.8430e-02
# tf_epoch =  57000  elapsed = 22:54 (+23.6)  loss = 3.8397e-02
# tf_epoch =  58000  elapsed = 23:18 (+23.5)  loss = 3.8359e-02
# tf_epoch =  59000  elapsed = 23:41 (+23.5)  loss = 3.8326e-02
# tf_epoch =  60000  elapsed = 24:05 (+23.6)  loss = 3.8297e-02
# tf_epoch =  61000  elapsed = 24:29 (+23.6)  loss = 3.8284e-02
# tf_epoch =  62000  elapsed = 24:52 (+23.6)  loss = 3.8263e-02
# tf_epoch =  63000  elapsed = 25:17 (+24.1)  loss = 3.8222e-02
# tf_epoch =  64000  elapsed = 25:40 (+23.7)  loss = 3.8203e-02
# tf_epoch =  65000  elapsed = 26:04 (+23.7)  loss = 3.8176e-02
# tf_epoch =  66000  elapsed = 26:28 (+23.5)  loss = 3.8160e-02
# tf_epoch =  67000  elapsed = 26:52 (+23.9)  loss = 3.8132e-02
# tf_epoch =  68000  elapsed = 27:15 (+23.6)  loss = 3.8107e-02
# tf_epoch =  69000  elapsed = 27:39 (+23.7)  loss = 3.8085e-02
# tf_epoch =  70000  elapsed = 28:03 (+23.7)  loss = 3.8064e-02
# tf_epoch =  71000  elapsed = 28:26 (+23.5)  loss = 3.8043e-02
# tf_epoch =  72000  elapsed = 28:50 (+23.5)  loss = 3.8023e-02
# tf_epoch =  73000  elapsed = 29:13 (+23.6)  loss = 3.8003e-02
# tf_epoch =  74000  elapsed = 29:37 (+23.8)  loss = 3.7983e-02
# tf_epoch =  75000  elapsed = 30:01 (+23.6)  loss = 3.7965e-02
# tf_epoch =  76000  elapsed = 30:25 (+23.7)  loss = 3.7946e-02
# tf_epoch =  77000  elapsed = 30:49 (+23.8)  loss = 3.7929e-02
# tf_epoch =  78000  elapsed = 31:12 (+23.6)  loss = 3.7912e-02
# tf_epoch =  79000  elapsed = 31:36 (+23.6)  loss = 3.7861e-02
# tf_epoch =  80000  elapsed = 32:00 (+23.7)  loss = 3.7827e-02
# tf_epoch =  81000  elapsed = 32:23 (+23.6)  loss = 3.7794e-02
# tf_epoch =  82000  elapsed = 32:47 (+23.6)  loss = 3.7777e-02
# tf_epoch =  83000  elapsed = 33:11 (+23.5)  loss = 3.7775e-02
# tf_epoch =  84000  elapsed = 33:34 (+23.6)  loss = 3.7744e-02
# tf_epoch =  85000  elapsed = 33:58 (+23.6)  loss = 3.7745e-02
# tf_epoch =  86000  elapsed = 34:22 (+23.7)  loss = 3.7723e-02
# tf_epoch =  87000  elapsed = 34:45 (+23.5)  loss = 3.7683e-02
# tf_epoch =  88000  elapsed = 35:09 (+23.5)  loss = 3.7660e-02
# tf_epoch =  89000  elapsed = 35:33 (+23.7)  loss = 3.7669e-02
# tf_epoch =  90000  elapsed = 35:56 (+23.6)  loss = 3.7623e-02
# tf_epoch =  91000  elapsed = 36:20 (+23.6)  loss = 3.7656e-02
# tf_epoch =  92000  elapsed = 36:43 (+23.6)  loss = 3.7708e-02
# tf_epoch =  93000  elapsed = 37:07 (+23.6)  loss = 3.7636e-02
# tf_epoch =  94000  elapsed = 37:31 (+23.8)  loss = 3.7655e-02
# tf_epoch =  95000  elapsed = 37:55 (+23.8)  loss = 3.7547e-02
# tf_epoch =  96000  elapsed = 38:19 (+23.7)  loss = 3.7562e-02
# tf_epoch =  97000  elapsed = 38:42 (+23.7)  loss = 3.7565e-02
# tf_epoch =  98000  elapsed = 39:06 (+23.8)  loss = 3.7531e-02
# tf_epoch =  99000  elapsed = 39:30 (+23.7)  loss = 3.7541e-02
# tf_epoch = 100000  elapsed = 39:54 (+23.7)  loss = 3.7529e-02
# tf_epoch = 101000  elapsed = 40:17 (+23.5)  loss = 3.7492e-02
# tf_epoch = 102000  elapsed = 40:41 (+23.7)  loss = 3.7517e-02
# tf_epoch = 103000  elapsed = 41:05 (+23.7)  loss = 3.7522e-02
# tf_epoch = 104000  elapsed = 41:28 (+23.6)  loss = 3.7474e-02
# tf_epoch = 105000  elapsed = 41:52 (+23.5)  loss = 3.7451e-02
# tf_epoch = 106000  elapsed = 42:15 (+23.5)  loss = 3.7418e-02
# tf_epoch = 107000  elapsed = 42:39 (+23.5)  loss = 3.7372e-02
# tf_epoch = 108000  elapsed = 43:03 (+23.8)  loss = 3.7450e-02
# tf_epoch = 109000  elapsed = 43:27 (+23.7)  loss = 3.7403e-02
# tf_epoch = 110000  elapsed = 43:50 (+23.6)  loss = 3.7342e-02
# tf_epoch = 111000  elapsed = 44:14 (+23.5)  loss = 3.7408e-02
# tf_epoch = 112000  elapsed = 44:37 (+23.6)  loss = 3.7367e-02
# tf_epoch = 113000  elapsed = 45:01 (+23.6)  loss = 3.7303e-02
# tf_epoch = 114000  elapsed = 45:25 (+23.5)  loss = 3.7312e-02
# tf_epoch = 115000  elapsed = 45:48 (+23.5)  loss = 3.7287e-02
# tf_epoch = 116000  elapsed = 46:12 (+23.6)  loss = 3.7347e-02
# tf_epoch = 117000  elapsed = 46:36 (+23.9)  loss = 3.7362e-02
# tf_epoch = 118000  elapsed = 46:59 (+23.5)  loss = 3.7283e-02
# tf_epoch = 119000  elapsed = 47:23 (+23.5)  loss = 3.7231e-02
# tf_epoch = 120000  elapsed = 47:47 (+23.5)  loss = 3.7214e-02
# tf_epoch = 121000  elapsed = 48:10 (+23.6)  loss = 3.7265e-02
# tf_epoch = 122000  elapsed = 48:34 (+23.6)  loss = 3.7285e-02
# tf_epoch = 123000  elapsed = 48:57 (+23.6)  loss = 3.7196e-02
# tf_epoch = 124000  elapsed = 49:21 (+23.5)  loss = 3.7192e-02
# tf_epoch = 125000  elapsed = 49:45 (+23.8)  loss = 3.7132e-02
# tf_epoch = 126000  elapsed = 50:08 (+23.5)  loss = 3.7154e-02
# tf_epoch = 127000  elapsed = 50:32 (+23.6)  loss = 3.7182e-02
# tf_epoch = 128000  elapsed = 50:56 (+23.7)  loss = 3.7082e-02
# tf_epoch = 129000  elapsed = 51:19 (+23.6)  loss = 3.7095e-02
# tf_epoch = 130000  elapsed = 51:43 (+23.6)  loss = 3.7098e-02
# tf_epoch = 131000  elapsed = 52:07 (+23.6)  loss = 3.7137e-02
# tf_epoch = 132000  elapsed = 52:30 (+23.5)  loss = 3.7030e-02
# tf_epoch = 133000  elapsed = 52:54 (+23.7)  loss = 3.7054e-02
# tf_epoch = 134000  elapsed = 53:18 (+23.6)  loss = 3.7049e-02
# tf_epoch = 135000  elapsed = 53:41 (+23.6)  loss = 3.7010e-02
# tf_epoch = 136000  elapsed = 54:05 (+23.6)  loss = 3.6996e-02
# tf_epoch = 137000  elapsed = 54:29 (+24.0)  loss = 3.6985e-02
# tf_epoch = 138000  elapsed = 54:53 (+23.5)  loss = 3.6985e-02
# tf_epoch = 139000  elapsed = 55:16 (+23.5)  loss = 3.7058e-02
# tf_epoch = 140000  elapsed = 55:40 (+24.0)  loss = 3.6989e-02
# tf_epoch = 141000  elapsed = 56:04 (+23.7)  loss = 3.6959e-02
# tf_epoch = 142000  elapsed = 56:28 (+23.8)  loss = 3.6996e-02
# tf_epoch = 143000  elapsed = 56:51 (+23.7)  loss = 3.7210e-02
# tf_epoch = 144000  elapsed = 57:15 (+23.5)  loss = 3.7224e-02
# tf_epoch = 145000  elapsed = 57:39 (+23.6)  loss = 3.7005e-02
# tf_epoch = 146000  elapsed = 58:02 (+23.5)  loss = 3.6953e-02
# tf_epoch = 147000  elapsed = 58:26 (+23.5)  loss = 3.6991e-02
# tf_epoch = 148000  elapsed = 58:50 (+23.6)  loss = 3.6912e-02
# tf_epoch = 149000  elapsed = 59:13 (+23.7)  loss = 3.6944e-02
# tf_epoch = 150000  elapsed = 59:37 (+23.5)  loss = 3.6874e-02
# tf_epoch = 151000  elapsed = 00:01 (+23.6)  loss = 3.6866e-02
# tf_epoch = 152000  elapsed = 00:24 (+23.9)  loss = 3.6857e-02
# tf_epoch = 153000  elapsed = 00:48 (+23.6)  loss = 3.6848e-02
# tf_epoch = 154000  elapsed = 01:12 (+23.7)  loss = 3.6839e-02
# tf_epoch = 155000  elapsed = 01:36 (+23.7)  loss = 3.6831e-02
# tf_epoch = 156000  elapsed = 01:59 (+23.6)  loss = 3.6822e-02
# tf_epoch = 157000  elapsed = 02:23 (+23.5)  loss = 3.6813e-02
# tf_epoch = 158000  elapsed = 02:46 (+23.6)  loss = 3.6804e-02
# tf_epoch = 159000  elapsed = 03:10 (+23.7)  loss = 3.6795e-02
# tf_epoch = 160000  elapsed = 03:34 (+23.8)  loss = 3.6786e-02
# tf_epoch = 161000  elapsed = 03:58 (+23.7)  loss = 3.6776e-02
# tf_epoch = 162000  elapsed = 04:21 (+23.6)  loss = 3.6767e-02
# tf_epoch = 163000  elapsed = 04:45 (+23.5)  loss = 3.6757e-02
# tf_epoch = 164000  elapsed = 05:09 (+23.5)  loss = 3.6748e-02
# tf_epoch = 165000  elapsed = 05:32 (+23.6)  loss = 3.6738e-02
# tf_epoch = 166000  elapsed = 05:56 (+24.0)  loss = 3.6729e-02
# tf_epoch = 167000  elapsed = 06:20 (+23.6)  loss = 3.6719e-02
# tf_epoch = 168000  elapsed = 06:43 (+23.5)  loss = 3.6709e-02
# tf_epoch = 169000  elapsed = 07:07 (+23.5)  loss = 3.6700e-02
# tf_epoch = 170000  elapsed = 07:31 (+23.7)  loss = 3.6690e-02
# tf_epoch = 171000  elapsed = 07:54 (+23.5)  loss = 3.6680e-02
# tf_epoch = 172000  elapsed = 08:18 (+23.5)  loss = 3.6670e-02
# tf_epoch = 173000  elapsed = 08:42 (+23.7)  loss = 3.6661e-02
# tf_epoch = 174000  elapsed = 09:05 (+23.7)  loss = 3.6650e-02
# tf_epoch = 175000  elapsed = 09:29 (+23.6)  loss = 3.6640e-02
# tf_epoch = 176000  elapsed = 09:53 (+23.8)  loss = 3.6630e-02
# tf_epoch = 177000  elapsed = 10:17 (+23.6)  loss = 3.6619e-02
# tf_epoch = 178000  elapsed = 10:40 (+23.8)  loss = 3.6608e-02
# tf_epoch = 179000  elapsed = 11:04 (+23.6)  loss = 3.6597e-02
# tf_epoch = 180000  elapsed = 11:28 (+23.9)  loss = 3.6586e-02
# tf_epoch = 181000  elapsed = 11:52 (+23.5)  loss = 3.6575e-02
# tf_epoch = 182000  elapsed = 12:15 (+23.6)  loss = 3.6563e-02
# tf_epoch = 183000  elapsed = 12:39 (+23.8)  loss = 3.6552e-02
# tf_epoch = 184000  elapsed = 13:03 (+23.6)  loss = 3.6540e-02
# tf_epoch = 185000  elapsed = 13:26 (+23.8)  loss = 3.6529e-02
# tf_epoch = 186000  elapsed = 13:50 (+23.8)  loss = 3.6517e-02
# tf_epoch = 187000  elapsed = 14:14 (+23.5)  loss = 3.6504e-02
# tf_epoch = 188000  elapsed = 14:38 (+23.6)  loss = 3.6492e-02
# tf_epoch = 189000  elapsed = 15:01 (+23.6)  loss = 3.6479e-02
# tf_epoch = 190000  elapsed = 15:25 (+23.6)  loss = 3.6466e-02
# tf_epoch = 191000  elapsed = 15:48 (+23.6)  loss = 3.6452e-02
# tf_epoch = 192000  elapsed = 16:12 (+23.6)  loss = 3.6438e-02
# tf_epoch = 193000  elapsed = 16:36 (+23.5)  loss = 3.6424e-02
# tf_epoch = 194000  elapsed = 16:59 (+23.7)  loss = 3.6409e-02
# tf_epoch = 195000  elapsed = 17:23 (+23.6)  loss = 3.6393e-02
# tf_epoch = 196000  elapsed = 17:47 (+23.7)  loss = 3.6377e-02
# tf_epoch = 197000  elapsed = 18:10 (+23.6)  loss = 3.6360e-02
# tf_epoch = 198000  elapsed = 18:34 (+23.6)  loss = 3.6343e-02
# tf_epoch = 199000  elapsed = 18:58 (+23.6)  loss = 3.6326e-02
# tf_epoch = 200000  elapsed = 19:21 (+23.6)  loss = 3.6308e-02
# tf_epoch = 201000  elapsed = 19:45 (+23.5)  loss = 3.6289e-02
# tf_epoch = 202000  elapsed = 20:09 (+23.7)  loss = 3.6269e-02
# tf_epoch = 203000  elapsed = 20:32 (+23.5)  loss = 3.6249e-02
# tf_epoch = 204000  elapsed = 20:56 (+23.6)  loss = 3.6227e-02
# tf_epoch = 205000  elapsed = 21:20 (+23.7)  loss = 3.6204e-02
# tf_epoch = 206000  elapsed = 21:43 (+23.6)  loss = 3.6180e-02
# tf_epoch = 207000  elapsed = 22:07 (+23.6)  loss = 3.6154e-02
# tf_epoch = 208000  elapsed = 22:31 (+23.6)  loss = 3.6125e-02
# tf_epoch = 209000  elapsed = 22:54 (+23.7)  loss = 3.6094e-02
# tf_epoch = 210000  elapsed = 23:18 (+23.5)  loss = 3.6057e-02
# tf_epoch = 211000  elapsed = 23:42 (+23.7)  loss = 3.6011e-02
# tf_epoch = 212000  elapsed = 24:05 (+23.5)  loss = 3.5951e-02
# tf_epoch = 213000  elapsed = 24:29 (+23.7)  loss = 3.5860e-02
# tf_epoch = 214000  elapsed = 24:53 (+23.7)  loss = 3.4675e-02
# tf_epoch = 215000  elapsed = 25:16 (+23.6)  loss = 3.4274e-02
# tf_epoch = 216000  elapsed = 25:40 (+23.7)  loss = 3.4000e-02
# tf_epoch = 217000  elapsed = 26:04 (+23.5)  loss = 3.3706e-02
# tf_epoch = 218000  elapsed = 26:27 (+23.6)  loss = 3.3451e-02
# tf_epoch = 219000  elapsed = 26:51 (+23.7)  loss = 3.3214e-02
# tf_epoch = 220000  elapsed = 27:15 (+23.6)  loss = 3.2990e-02
# tf_epoch = 221000  elapsed = 27:38 (+23.5)  loss = 3.2744e-02
# tf_epoch = 222000  elapsed = 28:02 (+23.6)  loss = 3.2451e-02
# tf_epoch = 223000  elapsed = 28:26 (+23.6)  loss = 3.2103e-02
# tf_epoch = 224000  elapsed = 28:49 (+23.6)  loss = 3.1726e-02
# tf_epoch = 225000  elapsed = 29:13 (+23.6)  loss = 3.1186e-02
# tf_epoch = 226000  elapsed = 29:37 (+23.6)  loss = 3.0064e-02
# tf_epoch = 227000  elapsed = 30:00 (+23.6)  loss = 2.9643e-02
# tf_epoch = 228000  elapsed = 30:24 (+23.6)  loss = 2.9393e-02
# tf_epoch = 229000  elapsed = 30:47 (+23.5)  loss = 2.9073e-02
# tf_epoch = 230000  elapsed = 31:11 (+23.8)  loss = 2.8864e-02
# tf_epoch = 231000  elapsed = 31:35 (+23.6)  loss = 2.8679e-02
# tf_epoch = 232000  elapsed = 31:58 (+23.6)  loss = 2.8506e-02
# tf_epoch = 233000  elapsed = 32:22 (+23.7)  loss = 2.8341e-02
# tf_epoch = 234000  elapsed = 32:46 (+23.5)  loss = 2.8183e-02
# tf_epoch = 235000  elapsed = 33:09 (+23.6)  loss = 2.8030e-02
# tf_epoch = 236000  elapsed = 33:33 (+23.6)  loss = 2.7878e-02
# tf_epoch = 237000  elapsed = 33:57 (+23.8)  loss = 2.7727e-02
# tf_epoch = 238000  elapsed = 34:21 (+23.8)  loss = 2.7576e-02
# tf_epoch = 239000  elapsed = 34:44 (+23.5)  loss = 2.7420e-02
# tf_epoch = 240000  elapsed = 35:08 (+23.6)  loss = 2.7259e-02
# tf_epoch = 241000  elapsed = 35:32 (+23.7)  loss = 2.7088e-02
# tf_epoch = 242000  elapsed = 35:55 (+23.6)  loss = 2.6904e-02
# tf_epoch = 243000  elapsed = 36:19 (+23.6)  loss = 2.6702e-02
# tf_epoch = 244000  elapsed = 36:43 (+23.6)  loss = 2.6473e-02
# tf_epoch = 245000  elapsed = 37:06 (+23.7)  loss = 2.6215e-02
# tf_epoch = 246000  elapsed = 37:30 (+23.6)  loss = 2.5925e-02
# tf_epoch = 247000  elapsed = 37:54 (+23.7)  loss = 2.5596e-02
# tf_epoch = 248000  elapsed = 38:18 (+23.7)  loss = 2.5257e-02
# tf_epoch = 249000  elapsed = 38:41 (+23.7)  loss = 2.4945e-02
# tf_epoch = 250000  elapsed = 39:05 (+23.7)  loss = 2.4690e-02
# tf_epoch = 251000  elapsed = 39:29 (+23.7)  loss = 2.4491e-02
# tf_epoch = 252000  elapsed = 39:53 (+23.6)  loss = 2.4305e-02
# tf_epoch = 253000  elapsed = 40:16 (+23.6)  loss = 2.4129e-02
# tf_epoch = 254000  elapsed = 40:40 (+23.7)  loss = 2.3956e-02
# tf_epoch = 255000  elapsed = 41:04 (+23.6)  loss = 2.3781e-02
# tf_epoch = 256000  elapsed = 41:27 (+23.6)  loss = 2.3613e-02
# tf_epoch = 257000  elapsed = 41:51 (+23.5)  loss = 2.3444e-02
# tf_epoch = 258000  elapsed = 42:15 (+23.7)  loss = 2.3897e-02
# tf_epoch = 259000  elapsed = 42:38 (+23.7)  loss = 2.3367e-02
# tf_epoch = 260000  elapsed = 43:02 (+23.5)  loss = 2.3040e-02
# tf_epoch = 261000  elapsed = 43:26 (+23.7)  loss = 2.2821e-02
# tf_epoch = 262000  elapsed = 43:49 (+23.7)  loss = 2.2594e-02
# tf_epoch = 263000  elapsed = 44:13 (+23.5)  loss = 2.2399e-02
# tf_epoch = 264000  elapsed = 44:37 (+23.6)  loss = 2.2208e-02
# tf_epoch = 265000  elapsed = 45:00 (+23.5)  loss = 2.1999e-02
# tf_epoch = 266000  elapsed = 45:24 (+23.6)  loss = 2.1860e-02
# tf_epoch = 267000  elapsed = 45:47 (+23.6)  loss = 2.1702e-02
# tf_epoch = 268000  elapsed = 46:11 (+23.7)  loss = 2.1556e-02
# tf_epoch = 269000  elapsed = 46:35 (+23.6)  loss = 2.1402e-02
# tf_epoch = 270000  elapsed = 46:58 (+23.6)  loss = 2.1238e-02
# tf_epoch = 271000  elapsed = 47:22 (+23.7)  loss = 2.1057e-02
# tf_epoch = 272000  elapsed = 47:46 (+23.8)  loss = 2.0881e-02
# tf_epoch = 273000  elapsed = 48:10 (+23.6)  loss = 2.0710e-02
# tf_epoch = 274000  elapsed = 48:33 (+23.6)  loss = 2.0540e-02
# tf_epoch = 275000  elapsed = 48:57 (+23.7)  loss = 2.0404e-02
# tf_epoch = 276000  elapsed = 49:21 (+23.7)  loss = 2.0284e-02
# tf_epoch = 277000  elapsed = 49:44 (+23.5)  loss = 2.0173e-02
# tf_epoch = 278000  elapsed = 50:08 (+23.7)  loss = 2.0048e-02
# tf_epoch = 279000  elapsed = 50:32 (+23.5)  loss = 1.9945e-02
# tf_epoch = 280000  elapsed = 50:55 (+23.5)  loss = 1.9847e-02
# tf_epoch = 281000  elapsed = 51:19 (+23.5)  loss = 1.9753e-02
# tf_epoch = 282000  elapsed = 51:43 (+23.7)  loss = 1.9649e-02
# tf_epoch = 283000  elapsed = 52:06 (+23.7)  loss = 1.9554e-02
# tf_epoch = 284000  elapsed = 52:30 (+23.6)  loss = 1.9467e-02
# tf_epoch = 285000  elapsed = 52:54 (+23.8)  loss = 1.9387e-02
# tf_epoch = 286000  elapsed = 53:18 (+23.7)  loss = 1.9311e-02
# tf_epoch = 287000  elapsed = 53:41 (+23.7)  loss = 1.9239e-02
# tf_epoch = 288000  elapsed = 54:05 (+23.7)  loss = 1.9169e-02
# tf_epoch = 289000  elapsed = 54:29 (+23.6)  loss = 1.9092e-02
# tf_epoch = 290000  elapsed = 54:52 (+23.6)  loss = 1.8955e-02
# tf_epoch = 291000  elapsed = 55:16 (+23.8)  loss = 1.8824e-02
# tf_epoch = 292000  elapsed = 55:40 (+23.6)  loss = 1.8712e-02
# tf_epoch = 293000  elapsed = 56:04 (+23.8)  loss = 1.8615e-02
# tf_epoch = 294000  elapsed = 56:27 (+23.7)  loss = 1.8528e-02
# tf_epoch = 295000  elapsed = 56:51 (+23.5)  loss = 1.8448e-02
# tf_epoch = 296000  elapsed = 57:15 (+23.7)  loss = 1.8355e-02
# tf_epoch = 297000  elapsed = 57:38 (+23.7)  loss = 1.8273e-02
# tf_epoch = 298000  elapsed = 58:03 (+24.6)  loss = 1.8198e-02
# tf_epoch = 299000  elapsed = 58:28 (+24.5)  loss = 1.8125e-02
# -- Starting LBFGS optimization --
# ==================
# Training finished (epoch 300000): duration = 58:52  error = 9.6057e-01

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim(pinn, X_f, X_star, u_star, xlb, xub)

# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
