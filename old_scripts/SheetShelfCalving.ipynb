# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAInformedNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 0
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = False
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
#path = os.path.join(appDataPath, "SSA2D_circleF.mat")
path = os.path.join(appDataPath, "SSA2D_segCF.mat")
modelPath = "./Models/SheetCircleF"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAInformedNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8, 
        geoDataNN="./Models/SheetCircleF_H_bed/", 
        FrictionCNN="./Models/SheetCircleF_C/")

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": false,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# WARNING:tensorflow:From ./utils/logger.py:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# train the model
#pinn.fit(X_star, u_star)
pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:34 (+34.5)  loss = 2.3112e+05
# tf_epoch =   1000  elapsed = 01:14 (+40.4)  loss = 8.2183e+02
# tf_epoch =   2000  elapsed = 01:55 (+40.3)  loss = 3.6623e+02
# tf_epoch =   3000  elapsed = 02:36 (+40.8)  loss = 3.4007e+02
# tf_epoch =   4000  elapsed = 03:17 (+40.8)  loss = 3.2698e+02
# tf_epoch =   5000  elapsed = 03:57 (+40.5)  loss = 2.8920e+02
# tf_epoch =   6000  elapsed = 04:38 (+40.8)  loss = 2.3622e+02
# tf_epoch =   7000  elapsed = 05:19 (+41.1)  loss = 1.7142e+02
# tf_epoch =   8000  elapsed = 06:00 (+40.4)  loss = 1.2554e+02
# tf_epoch =   9000  elapsed = 06:40 (+40.4)  loss = 9.7951e+01
# tf_epoch =  10000  elapsed = 07:21 (+40.7)  loss = 7.4142e+01
# tf_epoch =  11000  elapsed = 08:01 (+40.1)  loss = 2.0152e+02
# tf_epoch =  12000  elapsed = 08:42 (+40.5)  loss = 1.1952e+02
# tf_epoch =  13000  elapsed = 09:22 (+40.4)  loss = 9.7610e+01
# tf_epoch =  14000  elapsed = 10:03 (+40.6)  loss = 1.9658e+02
# tf_epoch =  15000  elapsed = 10:43 (+40.6)  loss = 1.1248e+02
# tf_epoch =  16000  elapsed = 11:23 (+40.0)  loss = 7.5796e+01
# tf_epoch =  17000  elapsed = 12:04 (+40.4)  loss = 5.8680e+01
# tf_epoch =  18000  elapsed = 12:45 (+40.7)  loss = 4.7387e+01
# tf_epoch =  19000  elapsed = 13:25 (+40.2)  loss = 5.3164e+01
# tf_epoch =  20000  elapsed = 14:06 (+40.7)  loss = 3.5373e+01
# tf_epoch =  21000  elapsed = 14:46 (+40.3)  loss = 3.4361e+01
# tf_epoch =  22000  elapsed = 15:27 (+40.7)  loss = 3.0812e+01
# tf_epoch =  23000  elapsed = 16:07 (+40.6)  loss = 2.3394e+01
# tf_epoch =  24000  elapsed = 16:47 (+40.0)  loss = 4.4784e+01
# tf_epoch =  25000  elapsed = 17:28 (+40.4)  loss = 2.7976e+01
# tf_epoch =  26000  elapsed = 18:08 (+40.1)  loss = 2.3062e+01
# tf_epoch =  27000  elapsed = 18:48 (+40.4)  loss = 1.7748e+01
# tf_epoch =  28000  elapsed = 19:29 (+40.6)  loss = 1.6150e+01
# tf_epoch =  29000  elapsed = 20:10 (+40.5)  loss = 3.9595e+01
# tf_epoch =  30000  elapsed = 20:50 (+40.1)  loss = 2.0942e+01
# tf_epoch =  31000  elapsed = 21:30 (+40.2)  loss = 1.6968e+01
# tf_epoch =  32000  elapsed = 22:10 (+40.0)  loss = 2.3582e+01
# tf_epoch =  33000  elapsed = 22:50 (+40.4)  loss = 3.1243e+01
# tf_epoch =  34000  elapsed = 23:31 (+40.2)  loss = 1.3796e+01
# tf_epoch =  35000  elapsed = 24:11 (+40.6)  loss = 1.2665e+01
# tf_epoch =  36000  elapsed = 24:52 (+40.2)  loss = 4.5504e+01
# tf_epoch =  37000  elapsed = 25:33 (+40.8)  loss = 1.6605e+01
# tf_epoch =  38000  elapsed = 26:13 (+40.6)  loss = 1.1212e+01
# tf_epoch =  39000  elapsed = 26:54 (+40.6)  loss = 1.0540e+01
# tf_epoch =  40000  elapsed = 27:34 (+40.2)  loss = 3.6839e+01
# tf_epoch =  41000  elapsed = 28:14 (+40.0)  loss = 1.5938e+01
# tf_epoch =  42000  elapsed = 28:55 (+40.5)  loss = 9.7034e+00
# tf_epoch =  43000  elapsed = 29:35 (+40.3)  loss = 9.2091e+00
# tf_epoch =  44000  elapsed = 30:15 (+40.3)  loss = 3.9019e+01
# tf_epoch =  45000  elapsed = 30:56 (+40.1)  loss = 1.4717e+01
# tf_epoch =  46000  elapsed = 31:36 (+40.5)  loss = 8.6936e+00
# tf_epoch =  47000  elapsed = 32:17 (+40.4)  loss = 8.3045e+00
# tf_epoch =  48000  elapsed = 32:57 (+40.1)  loss = 1.3070e+01
# tf_epoch =  49000  elapsed = 33:37 (+40.1)  loss = 1.3356e+01
# tf_epoch =  50000  elapsed = 34:17 (+40.3)  loss = 1.1012e+01
# tf_epoch =  51000  elapsed = 34:58 (+40.6)  loss = 8.0172e+00
# tf_epoch =  52000  elapsed = 35:38 (+40.5)  loss = 7.6652e+00
# tf_epoch =  53000  elapsed = 36:19 (+40.2)  loss = 4.8155e+01
# tf_epoch =  54000  elapsed = 36:59 (+40.1)  loss = 1.2053e+01
# tf_epoch =  55000  elapsed = 37:39 (+40.2)  loss = 8.0688e+00
# tf_epoch =  56000  elapsed = 38:19 (+40.1)  loss = 7.4351e+00
# tf_epoch =  57000  elapsed = 38:59 (+40.0)  loss = 7.0440e+00
# tf_epoch =  58000  elapsed = 39:40 (+40.2)  loss = 1.1369e+01
# tf_epoch =  59000  elapsed = 40:20 (+40.3)  loss = 6.8785e+00
# tf_epoch =  60000  elapsed = 41:00 (+40.4)  loss = 6.6278e+00
# tf_epoch =  61000  elapsed = 41:40 (+39.9)  loss = 1.4947e+01
# tf_epoch =  62000  elapsed = 42:20 (+40.0)  loss = 6.6886e+00
# tf_epoch =  63000  elapsed = 43:01 (+40.4)  loss = 6.4354e+00
# tf_epoch =  64000  elapsed = 43:41 (+40.0)  loss = 6.2236e+00
# tf_epoch =  65000  elapsed = 44:22 (+40.7)  loss = 1.0140e+01
# tf_epoch =  66000  elapsed = 45:04 (+41.9)  loss = 6.2908e+00
# tf_epoch =  67000  elapsed = 45:44 (+40.4)  loss = 6.0909e+00
# tf_epoch =  68000  elapsed = 46:24 (+40.1)  loss = 1.4246e+01
# tf_epoch =  69000  elapsed = 47:06 (+42.0)  loss = 8.5829e+00
# tf_epoch =  70000  elapsed = 47:46 (+40.2)  loss = 6.1224e+00
# tf_epoch =  71000  elapsed = 48:27 (+40.7)  loss = 5.9134e+00
# tf_epoch =  72000  elapsed = 49:07 (+40.2)  loss = 1.4830e+01
# tf_epoch =  73000  elapsed = 49:48 (+40.3)  loss = 5.9958e+00
# tf_epoch =  74000  elapsed = 50:28 (+40.4)  loss = 5.7643e+00
# tf_epoch =  75000  elapsed = 51:09 (+41.2)  loss = 3.4108e+01
# tf_epoch =  76000  elapsed = 51:51 (+41.1)  loss = 1.7904e+01
# tf_epoch =  77000  elapsed = 52:31 (+40.6)  loss = 5.8004e+00
# tf_epoch =  78000  elapsed = 53:11 (+40.1)  loss = 5.5866e+00
# tf_epoch =  79000  elapsed = 53:52 (+40.3)  loss = 5.4241e+00
# tf_epoch =  80000  elapsed = 54:32 (+40.6)  loss = 9.6627e+00
# tf_epoch =  81000  elapsed = 55:13 (+40.6)  loss = 5.4565e+00
# tf_epoch =  82000  elapsed = 55:54 (+40.8)  loss = 5.3096e+00
# tf_epoch =  83000  elapsed = 56:34 (+40.1)  loss = 5.9909e+00
# tf_epoch =  84000  elapsed = 57:15 (+40.7)  loss = 5.2469e+00
# tf_epoch =  85000  elapsed = 57:57 (+42.1)  loss = 5.1307e+00
# tf_epoch =  86000  elapsed = 58:38 (+41.3)  loss = 6.6747e+00
# tf_epoch =  87000  elapsed = 59:19 (+40.9)  loss = 5.1684e+00
# tf_epoch =  88000  elapsed = 00:01 (+41.9)  loss = 5.0494e+00
# tf_epoch =  89000  elapsed = 00:43 (+41.9)  loss = 5.8901e+00
# tf_epoch =  90000  elapsed = 01:25 (+41.5)  loss = 5.0744e+00
# tf_epoch =  91000  elapsed = 02:05 (+40.7)  loss = 4.9713e+00
# tf_epoch =  92000  elapsed = 02:45 (+40.0)  loss = 2.2442e+01
# tf_epoch =  93000  elapsed = 03:26 (+40.6)  loss = 5.1049e+00
# tf_epoch =  94000  elapsed = 04:07 (+40.7)  loss = 4.9439e+00
# tf_epoch =  95000  elapsed = 04:48 (+40.6)  loss = 4.8475e+00
# tf_epoch =  96000  elapsed = 05:28 (+40.3)  loss = 8.1032e+00
# tf_epoch =  97000  elapsed = 06:08 (+40.3)  loss = 4.8753e+00
# tf_epoch =  98000  elapsed = 06:49 (+40.9)  loss = 4.7803e+00
# tf_epoch =  99000  elapsed = 07:30 (+41.0)  loss = 2.2014e+01
# -- Starting LBFGS optimization --
# ==================
# Training finished (epoch 100000): duration = 08:11  error = 9.4035e-02

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim(pinn, X_f, X_star, u_star, xlb, xub)

# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
