# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAInformedNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 300000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 0
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = False
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN.mat")
modelPath = "./Models/Helheim"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAInformedNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8, 
        loss_weights=[1e-6, 1e-12, 1e-16],
        geoDataNN="./Models/Helheim_H_bed/", 
        FrictionCNN="./Models/Helheim_C/")

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "tf_epochs": 300000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": false,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# WARNING:tensorflow:From ./utils/logger.py:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# train the model
#pinn.fit(X_star, u_star)
pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:19 (+19.2)  loss = 1.9070e+01
# tf_epoch =   1000  elapsed = 00:42 (+23.3)  loss = 2.1315e+00
# tf_epoch =   2000  elapsed = 01:05 (+23.3)  loss = 2.1187e+00
# tf_epoch =   3000  elapsed = 01:29 (+23.2)  loss = 2.1043e+00
# tf_epoch =   4000  elapsed = 01:52 (+23.5)  loss = 2.0818e+00
# tf_epoch =   5000  elapsed = 02:16 (+23.3)  loss = 2.0900e+00
# tf_epoch =   6000  elapsed = 02:39 (+23.6)  loss = 1.9714e+00
# tf_epoch =   7000  elapsed = 03:03 (+23.3)  loss = 1.9189e+00
# tf_epoch =   8000  elapsed = 03:26 (+23.3)  loss = 1.2180e+00
# tf_epoch =   9000  elapsed = 03:49 (+23.3)  loss = 1.1327e+00
# tf_epoch =  10000  elapsed = 04:13 (+23.3)  loss = 1.0282e+00
# tf_epoch =  11000  elapsed = 04:36 (+23.3)  loss = 9.3786e-01
# tf_epoch =  12000  elapsed = 04:59 (+23.3)  loss = 8.5357e-01
# tf_epoch =  13000  elapsed = 05:22 (+23.3)  loss = 6.4821e-01
# tf_epoch =  14000  elapsed = 05:46 (+23.3)  loss = 6.0915e-01
# tf_epoch =  15000  elapsed = 06:09 (+23.3)  loss = 5.7446e-01
# tf_epoch =  16000  elapsed = 06:32 (+23.3)  loss = 5.5571e-01
# tf_epoch =  17000  elapsed = 06:56 (+23.3)  loss = 5.4811e-01
# tf_epoch =  18000  elapsed = 07:19 (+23.3)  loss = 5.2644e-01
# tf_epoch =  19000  elapsed = 07:42 (+23.3)  loss = 5.2095e-01
# tf_epoch =  20000  elapsed = 08:06 (+23.3)  loss = 5.1028e-01
# tf_epoch =  21000  elapsed = 08:29 (+23.3)  loss = 5.1848e-01
# tf_epoch =  22000  elapsed = 08:52 (+23.3)  loss = 4.9468e-01
# tf_epoch =  23000  elapsed = 09:16 (+23.3)  loss = 4.8516e-01
# tf_epoch =  24000  elapsed = 09:39 (+23.3)  loss = 4.6236e-01
# tf_epoch =  25000  elapsed = 10:02 (+23.3)  loss = 4.4465e-01
# tf_epoch =  26000  elapsed = 10:26 (+23.3)  loss = 4.3119e-01
# tf_epoch =  27000  elapsed = 10:49 (+23.3)  loss = 4.2795e-01
# tf_epoch =  28000  elapsed = 11:12 (+23.3)  loss = 4.0386e-01
# tf_epoch =  29000  elapsed = 11:36 (+23.3)  loss = 4.0559e-01
# tf_epoch =  30000  elapsed = 11:59 (+23.3)  loss = 3.7799e-01
# tf_epoch =  31000  elapsed = 12:22 (+23.3)  loss = 3.6588e-01
# tf_epoch =  32000  elapsed = 12:46 (+23.3)  loss = 6.1485e-01
# tf_epoch =  33000  elapsed = 13:09 (+23.3)  loss = 3.4164e-01
# tf_epoch =  34000  elapsed = 13:32 (+23.3)  loss = 3.3635e-01
# tf_epoch =  35000  elapsed = 13:56 (+23.3)  loss = 3.3020e-01
# tf_epoch =  36000  elapsed = 14:19 (+23.3)  loss = 3.2808e-01
# tf_epoch =  37000  elapsed = 14:42 (+23.3)  loss = 3.0908e-01
# tf_epoch =  38000  elapsed = 15:06 (+23.3)  loss = 3.1449e-01
# tf_epoch =  39000  elapsed = 15:29 (+23.3)  loss = 3.0385e-01
# tf_epoch =  40000  elapsed = 15:52 (+23.3)  loss = 2.8978e-01
# tf_epoch =  41000  elapsed = 16:16 (+23.3)  loss = 2.9793e-01
# tf_epoch =  42000  elapsed = 16:39 (+23.3)  loss = 2.9163e-01
# tf_epoch =  43000  elapsed = 17:02 (+23.3)  loss = 2.8022e-01
# tf_epoch =  44000  elapsed = 17:26 (+23.3)  loss = 2.8157e-01
# tf_epoch =  45000  elapsed = 17:49 (+23.3)  loss = 2.7985e-01
# tf_epoch =  46000  elapsed = 18:12 (+23.3)  loss = 2.6960e-01
# tf_epoch =  47000  elapsed = 18:36 (+23.3)  loss = 2.6364e-01
# tf_epoch =  48000  elapsed = 18:59 (+23.3)  loss = 2.7220e-01
# tf_epoch =  49000  elapsed = 19:22 (+23.3)  loss = 2.5638e-01
# tf_epoch =  50000  elapsed = 19:46 (+23.3)  loss = 2.7114e-01
# tf_epoch =  51000  elapsed = 20:09 (+23.3)  loss = 2.4815e-01
# tf_epoch =  52000  elapsed = 20:32 (+23.3)  loss = 2.5721e-01
# tf_epoch =  53000  elapsed = 20:56 (+23.3)  loss = 2.5913e-01
# tf_epoch =  54000  elapsed = 21:19 (+23.3)  loss = 2.5088e-01
# tf_epoch =  55000  elapsed = 21:42 (+23.3)  loss = 2.4959e-01
# tf_epoch =  56000  elapsed = 22:06 (+23.3)  loss = 2.4802e-01
# tf_epoch =  57000  elapsed = 22:29 (+23.3)  loss = 2.3802e-01
# tf_epoch =  58000  elapsed = 22:52 (+23.3)  loss = 2.4210e-01
# tf_epoch =  59000  elapsed = 23:16 (+23.3)  loss = 2.3709e-01
# tf_epoch =  60000  elapsed = 23:39 (+23.3)  loss = 2.4419e-01
# tf_epoch =  61000  elapsed = 24:03 (+23.3)  loss = 2.4362e-01
# tf_epoch =  62000  elapsed = 24:26 (+23.3)  loss = 2.2824e-01
# tf_epoch =  63000  elapsed = 24:49 (+23.3)  loss = 2.2658e-01
# tf_epoch =  64000  elapsed = 25:13 (+23.3)  loss = 2.2531e-01
# tf_epoch =  65000  elapsed = 25:36 (+23.3)  loss = 2.6186e-01
# tf_epoch =  66000  elapsed = 25:59 (+23.3)  loss = 2.3589e-01
# tf_epoch =  67000  elapsed = 26:23 (+23.3)  loss = 2.2202e-01
# tf_epoch =  68000  elapsed = 26:46 (+23.3)  loss = 2.3003e-01
# tf_epoch =  69000  elapsed = 27:09 (+23.3)  loss = 2.3289e-01
# tf_epoch =  70000  elapsed = 27:33 (+23.3)  loss = 2.1502e-01
# tf_epoch =  71000  elapsed = 27:56 (+23.3)  loss = 2.2078e-01
# tf_epoch =  72000  elapsed = 28:19 (+23.3)  loss = 2.4428e-01
# tf_epoch =  73000  elapsed = 28:43 (+23.3)  loss = 2.1230e-01
# tf_epoch =  74000  elapsed = 29:06 (+23.3)  loss = 2.0437e-01
# tf_epoch =  75000  elapsed = 29:29 (+23.3)  loss = 2.0883e-01
# tf_epoch =  76000  elapsed = 29:53 (+23.3)  loss = 2.0411e-01
# tf_epoch =  77000  elapsed = 30:16 (+23.3)  loss = 1.9715e-01
# tf_epoch =  78000  elapsed = 30:39 (+23.3)  loss = 1.9677e-01
# tf_epoch =  79000  elapsed = 31:03 (+23.3)  loss = 1.8940e-01
# tf_epoch =  80000  elapsed = 31:26 (+23.3)  loss = 1.9647e-01
# tf_epoch =  81000  elapsed = 31:49 (+23.3)  loss = 1.8520e-01
# tf_epoch =  82000  elapsed = 32:13 (+23.3)  loss = 1.9012e-01
# tf_epoch =  83000  elapsed = 32:36 (+23.3)  loss = 1.8614e-01
# tf_epoch =  84000  elapsed = 32:59 (+23.3)  loss = 1.8048e-01
# tf_epoch =  85000  elapsed = 33:23 (+23.3)  loss = 1.8144e-01
# tf_epoch =  86000  elapsed = 33:46 (+23.3)  loss = 1.8560e-01
# tf_epoch =  87000  elapsed = 34:10 (+23.3)  loss = 1.8646e-01
# tf_epoch =  88000  elapsed = 34:33 (+23.3)  loss = 1.7808e-01
# tf_epoch =  89000  elapsed = 34:56 (+23.3)  loss = 1.8314e-01
# tf_epoch =  90000  elapsed = 35:20 (+23.3)  loss = 1.7310e-01
# tf_epoch =  91000  elapsed = 35:43 (+23.3)  loss = 1.7164e-01
# tf_epoch =  92000  elapsed = 36:06 (+23.3)  loss = 1.7074e-01
# tf_epoch =  93000  elapsed = 36:30 (+23.3)  loss = 1.6604e-01
# tf_epoch =  94000  elapsed = 36:53 (+23.3)  loss = 1.7039e-01
# tf_epoch =  95000  elapsed = 37:16 (+23.3)  loss = 1.6518e-01
# tf_epoch =  96000  elapsed = 37:40 (+23.4)  loss = 1.6366e-01
# tf_epoch =  97000  elapsed = 38:03 (+23.4)  loss = 1.7225e-01
# tf_epoch =  98000  elapsed = 38:27 (+23.3)  loss = 1.6166e-01
# tf_epoch =  99000  elapsed = 38:50 (+23.3)  loss = 1.6830e-01
# tf_epoch = 100000  elapsed = 39:13 (+23.3)  loss = 1.5925e-01
# tf_epoch = 101000  elapsed = 39:37 (+23.3)  loss = 1.6028e-01
# tf_epoch = 102000  elapsed = 40:00 (+23.3)  loss = 1.5697e-01
# tf_epoch = 103000  elapsed = 40:23 (+23.3)  loss = 1.6225e-01
# tf_epoch = 104000  elapsed = 40:47 (+23.3)  loss = 1.5911e-01
# tf_epoch = 105000  elapsed = 41:10 (+23.3)  loss = 1.6871e-01
# tf_epoch = 106000  elapsed = 41:33 (+23.3)  loss = 1.5411e-01
# tf_epoch = 107000  elapsed = 41:57 (+23.3)  loss = 1.5185e-01
# tf_epoch = 108000  elapsed = 42:20 (+23.3)  loss = 1.5297e-01
# tf_epoch = 109000  elapsed = 42:43 (+23.3)  loss = 1.5564e-01
# tf_epoch = 110000  elapsed = 43:07 (+23.3)  loss = 1.4910e-01
# tf_epoch = 111000  elapsed = 43:30 (+23.3)  loss = 1.4670e-01
# tf_epoch = 112000  elapsed = 43:54 (+23.3)  loss = 1.4669e-01
# tf_epoch = 113000  elapsed = 44:17 (+23.3)  loss = 1.4682e-01
# tf_epoch = 114000  elapsed = 44:40 (+23.3)  loss = 1.4838e-01
# tf_epoch = 115000  elapsed = 45:04 (+23.3)  loss = 1.4220e-01
# tf_epoch = 116000  elapsed = 45:27 (+23.3)  loss = 1.4197e-01
# tf_epoch = 117000  elapsed = 45:50 (+23.3)  loss = 1.4708e-01
# tf_epoch = 118000  elapsed = 46:14 (+23.3)  loss = 1.4808e-01
# tf_epoch = 119000  elapsed = 46:37 (+23.3)  loss = 1.4376e-01
# tf_epoch = 120000  elapsed = 47:00 (+23.3)  loss = 1.4431e-01
# tf_epoch = 121000  elapsed = 47:24 (+23.3)  loss = 1.3692e-01
# tf_epoch = 122000  elapsed = 47:47 (+23.3)  loss = 1.3732e-01
# tf_epoch = 123000  elapsed = 48:11 (+23.3)  loss = 1.3330e-01
# tf_epoch = 124000  elapsed = 48:34 (+23.3)  loss = 1.3537e-01
# tf_epoch = 125000  elapsed = 48:57 (+23.3)  loss = 1.3817e-01
# tf_epoch = 126000  elapsed = 49:21 (+23.3)  loss = 1.3220e-01
# tf_epoch = 127000  elapsed = 49:44 (+23.3)  loss = 1.3832e-01
# tf_epoch = 128000  elapsed = 50:07 (+23.3)  loss = 1.3138e-01
# tf_epoch = 129000  elapsed = 50:31 (+23.3)  loss = 1.2941e-01
# tf_epoch = 130000  elapsed = 50:54 (+23.3)  loss = 1.2831e-01
# tf_epoch = 131000  elapsed = 51:17 (+23.3)  loss = 1.4071e-01
# tf_epoch = 132000  elapsed = 51:41 (+23.3)  loss = 1.2973e-01
# tf_epoch = 133000  elapsed = 52:04 (+23.3)  loss = 1.2820e-01
# tf_epoch = 134000  elapsed = 52:28 (+23.3)  loss = 1.2358e-01
# tf_epoch = 135000  elapsed = 52:51 (+23.3)  loss = 1.2526e-01
# tf_epoch = 136000  elapsed = 53:14 (+23.3)  loss = 1.2053e-01
# tf_epoch = 137000  elapsed = 53:38 (+23.3)  loss = 1.3193e-01
# tf_epoch = 138000  elapsed = 54:01 (+23.3)  loss = 1.2527e-01
# tf_epoch = 139000  elapsed = 54:24 (+23.3)  loss = 1.1816e-01
# tf_epoch = 140000  elapsed = 54:48 (+23.3)  loss = 1.2047e-01
# tf_epoch = 141000  elapsed = 55:11 (+23.3)  loss = 1.1597e-01
# tf_epoch = 142000  elapsed = 55:34 (+23.3)  loss = 1.1564e-01
# tf_epoch = 143000  elapsed = 55:58 (+23.3)  loss = 1.2135e-01
# tf_epoch = 144000  elapsed = 56:21 (+23.3)  loss = 1.1314e-01
# tf_epoch = 145000  elapsed = 56:44 (+23.3)  loss = 1.1200e-01
# tf_epoch = 146000  elapsed = 57:08 (+23.3)  loss = 1.1086e-01
# tf_epoch = 147000  elapsed = 57:31 (+23.3)  loss = 1.1078e-01
# tf_epoch = 148000  elapsed = 57:55 (+23.3)  loss = 1.1468e-01
# tf_epoch = 149000  elapsed = 58:18 (+23.3)  loss = 1.0689e-01
# tf_epoch = 150000  elapsed = 58:41 (+23.3)  loss = 1.2365e-01
# tf_epoch = 151000  elapsed = 59:05 (+23.3)  loss = 1.0318e-01
# tf_epoch = 152000  elapsed = 59:28 (+23.3)  loss = 1.0623e-01
# tf_epoch = 153000  elapsed = 59:51 (+23.3)  loss = 1.0026e-01
# tf_epoch = 154000  elapsed = 00:15 (+23.5)  loss = 1.0177e-01
# tf_epoch = 155000  elapsed = 00:38 (+23.3)  loss = 1.0007e-01
# tf_epoch = 156000  elapsed = 01:02 (+23.3)  loss = 1.0647e-01
# tf_epoch = 157000  elapsed = 01:25 (+23.3)  loss = 9.6306e-02
# tf_epoch = 158000  elapsed = 01:48 (+23.3)  loss = 9.8024e-02
# tf_epoch = 159000  elapsed = 02:12 (+23.3)  loss = 1.0769e-01
# tf_epoch = 160000  elapsed = 02:35 (+23.3)  loss = 1.0230e-01
# tf_epoch = 161000  elapsed = 02:58 (+23.3)  loss = 9.8421e-02
# tf_epoch = 162000  elapsed = 03:22 (+23.3)  loss = 9.3157e-02
# tf_epoch = 163000  elapsed = 03:45 (+23.3)  loss = 9.3504e-02
# tf_epoch = 164000  elapsed = 04:08 (+23.3)  loss = 9.8042e-02
# tf_epoch = 165000  elapsed = 04:32 (+23.3)  loss = 9.4037e-02
# tf_epoch = 166000  elapsed = 04:55 (+23.3)  loss = 9.4971e-02
# tf_epoch = 167000  elapsed = 05:19 (+23.3)  loss = 9.3163e-02
# tf_epoch = 168000  elapsed = 05:42 (+23.3)  loss = 8.8322e-02
# tf_epoch = 169000  elapsed = 06:05 (+23.3)  loss = 9.0886e-02
# tf_epoch = 170000  elapsed = 06:29 (+23.3)  loss = 9.2152e-02
# tf_epoch = 171000  elapsed = 06:52 (+23.3)  loss = 9.0793e-02
# tf_epoch = 172000  elapsed = 07:15 (+23.3)  loss = 8.5205e-02
# tf_epoch = 173000  elapsed = 07:39 (+23.3)  loss = 1.0154e-01
# tf_epoch = 174000  elapsed = 08:02 (+23.3)  loss = 9.0637e-02
# tf_epoch = 175000  elapsed = 08:25 (+23.3)  loss = 8.6035e-02
# tf_epoch = 176000  elapsed = 08:49 (+23.3)  loss = 8.9173e-02
# tf_epoch = 177000  elapsed = 09:12 (+23.3)  loss = 1.2367e-01
# tf_epoch = 178000  elapsed = 09:36 (+23.3)  loss = 8.9382e-02
# tf_epoch = 179000  elapsed = 09:59 (+23.3)  loss = 9.6818e-02
# tf_epoch = 180000  elapsed = 10:22 (+23.3)  loss = 8.5896e-02
# tf_epoch = 181000  elapsed = 10:46 (+23.3)  loss = 8.7914e-02
# tf_epoch = 182000  elapsed = 11:09 (+23.3)  loss = 8.8171e-02
# tf_epoch = 183000  elapsed = 11:32 (+23.3)  loss = 8.0949e-02
# tf_epoch = 184000  elapsed = 11:56 (+23.3)  loss = 8.2340e-02
# tf_epoch = 185000  elapsed = 12:19 (+23.3)  loss = 9.1530e-02
# tf_epoch = 186000  elapsed = 12:42 (+23.3)  loss = 1.0725e-01
# tf_epoch = 187000  elapsed = 13:06 (+23.3)  loss = 7.9957e-02
# tf_epoch = 188000  elapsed = 13:29 (+23.3)  loss = 7.9555e-02
# tf_epoch = 189000  elapsed = 13:53 (+23.3)  loss = 8.2852e-02
# tf_epoch = 190000  elapsed = 14:16 (+23.3)  loss = 8.0626e-02
# tf_epoch = 191000  elapsed = 14:39 (+23.3)  loss = 7.9346e-02
# tf_epoch = 192000  elapsed = 15:03 (+23.3)  loss = 7.8985e-02
# tf_epoch = 193000  elapsed = 15:26 (+23.3)  loss = 8.4820e-02
# tf_epoch = 194000  elapsed = 15:49 (+23.3)  loss = 8.0278e-02
# tf_epoch = 195000  elapsed = 16:13 (+23.3)  loss = 7.9113e-02
# tf_epoch = 196000  elapsed = 16:36 (+23.4)  loss = 8.6880e-02
# tf_epoch = 197000  elapsed = 16:59 (+23.3)  loss = 8.3227e-02
# tf_epoch = 198000  elapsed = 17:23 (+23.3)  loss = 7.7789e-02
# tf_epoch = 199000  elapsed = 17:46 (+23.3)  loss = 8.1627e-02
# tf_epoch = 200000  elapsed = 18:10 (+23.3)  loss = 7.7312e-02
# tf_epoch = 201000  elapsed = 18:33 (+23.3)  loss = 7.7181e-02
# tf_epoch = 202000  elapsed = 18:56 (+23.3)  loss = 8.1764e-02
# tf_epoch = 203000  elapsed = 19:20 (+23.3)  loss = 7.7788e-02
# tf_epoch = 204000  elapsed = 19:43 (+23.3)  loss = 8.1640e-02
# tf_epoch = 205000  elapsed = 20:06 (+23.3)  loss = 7.4906e-02
# tf_epoch = 206000  elapsed = 20:30 (+23.3)  loss = 7.5324e-02
# tf_epoch = 207000  elapsed = 20:53 (+23.3)  loss = 7.4560e-02
# tf_epoch = 208000  elapsed = 21:16 (+23.3)  loss = 7.3921e-02
# tf_epoch = 209000  elapsed = 21:40 (+23.3)  loss = 8.3785e-02
# tf_epoch = 210000  elapsed = 22:03 (+23.3)  loss = 8.1107e-02
# tf_epoch = 211000  elapsed = 22:27 (+23.3)  loss = 7.9570e-02
# tf_epoch = 212000  elapsed = 22:50 (+23.3)  loss = 7.4779e-02
# tf_epoch = 213000  elapsed = 23:13 (+23.3)  loss = 8.2524e-02
# tf_epoch = 214000  elapsed = 23:37 (+23.3)  loss = 7.7361e-02
# tf_epoch = 215000  elapsed = 24:00 (+23.3)  loss = 7.4333e-02
# tf_epoch = 216000  elapsed = 24:23 (+23.3)  loss = 8.4607e-02
# tf_epoch = 217000  elapsed = 24:47 (+23.3)  loss = 7.4483e-02
# tf_epoch = 219000  elapsed = 25:33 (+23.3)  loss = 7.2406e-02
# tf_epoch = 220000  elapsed = 25:57 (+23.3)  loss = 7.3954e-02
# tf_epoch = 221000  elapsed = 26:20 (+23.3)  loss = 7.0995e-02
# tf_epoch = 222000  elapsed = 26:44 (+23.3)  loss = 7.0481e-02
# tf_epoch = 223000  elapsed = 27:07 (+23.3)  loss = 7.1250e-02
# tf_epoch = 224000  elapsed = 27:30 (+23.3)  loss = 7.0157e-02
# tf_epoch = 225000  elapsed = 27:54 (+23.3)  loss = 7.7034e-02
# tf_epoch = 226000  elapsed = 28:17 (+23.3)  loss = 6.9595e-02
# tf_epoch = 227000  elapsed = 28:40 (+23.3)  loss = 7.0238e-02
# tf_epoch = 228000  elapsed = 29:04 (+23.3)  loss = 7.0151e-02
# tf_epoch = 229000  elapsed = 29:27 (+23.3)  loss = 6.9193e-02
# tf_epoch = 230000  elapsed = 29:51 (+23.3)  loss = 6.8460e-02
# tf_epoch = 231000  elapsed = 30:14 (+23.3)  loss = 7.1389e-02
# tf_epoch = 232000  elapsed = 30:37 (+23.3)  loss = 6.8617e-02
# tf_epoch = 233000  elapsed = 31:01 (+23.3)  loss = 6.9367e-02
# tf_epoch = 234000  elapsed = 31:24 (+23.3)  loss = 7.0910e-02
# tf_epoch = 235000  elapsed = 31:47 (+23.3)  loss = 7.3018e-02
# tf_epoch = 236000  elapsed = 32:11 (+23.3)  loss = 7.0949e-02
# tf_epoch = 237000  elapsed = 32:34 (+23.3)  loss = 6.8369e-02
# tf_epoch = 238000  elapsed = 32:58 (+23.3)  loss = 7.5145e-02
# tf_epoch = 239000  elapsed = 33:21 (+23.3)  loss = 7.1872e-02
# tf_epoch = 240000  elapsed = 33:44 (+23.3)  loss = 7.1313e-02
# tf_epoch = 241000  elapsed = 34:08 (+23.3)  loss = 7.3269e-02
# tf_epoch = 242000  elapsed = 34:31 (+23.3)  loss = 7.1768e-02
# tf_epoch = 243000  elapsed = 34:54 (+23.3)  loss = 6.5635e-02
# tf_epoch = 244000  elapsed = 35:18 (+23.3)  loss = 7.1131e-02
# tf_epoch = 245000  elapsed = 35:41 (+23.3)  loss = 7.0135e-02
# tf_epoch = 246000  elapsed = 36:04 (+23.3)  loss = 6.8460e-02
# tf_epoch = 247000  elapsed = 36:28 (+23.3)  loss = 6.4342e-02
# tf_epoch = 248000  elapsed = 36:51 (+23.3)  loss = 6.8603e-02
# tf_epoch = 249000  elapsed = 37:15 (+23.3)  loss = 6.6580e-02
# tf_epoch = 250000  elapsed = 37:38 (+23.3)  loss = 6.4380e-02
# tf_epoch = 251000  elapsed = 38:01 (+23.3)  loss = 6.9926e-02
# tf_epoch = 252000  elapsed = 38:25 (+23.3)  loss = 6.7932e-02
# tf_epoch = 253000  elapsed = 38:48 (+23.3)  loss = 6.9172e-02
# tf_epoch = 254000  elapsed = 39:11 (+23.3)  loss = 6.5247e-02
# tf_epoch = 255000  elapsed = 39:35 (+23.3)  loss = 6.3797e-02
# tf_epoch = 256000  elapsed = 39:58 (+23.3)  loss = 6.1793e-02
# tf_epoch = 257000  elapsed = 40:22 (+23.3)  loss = 6.6184e-02
# tf_epoch = 258000  elapsed = 40:45 (+23.3)  loss = 6.1337e-02
# tf_epoch = 259000  elapsed = 41:08 (+23.3)  loss = 6.5146e-02
# tf_epoch = 260000  elapsed = 41:32 (+23.3)  loss = 6.6358e-02
# tf_epoch = 261000  elapsed = 41:55 (+23.3)  loss = 6.9571e-02
# tf_epoch = 262000  elapsed = 42:18 (+23.3)  loss = 6.0352e-02
# tf_epoch = 263000  elapsed = 42:42 (+23.3)  loss = 6.3498e-02
# tf_epoch = 264000  elapsed = 43:05 (+23.3)  loss = 5.9922e-02
# tf_epoch = 265000  elapsed = 43:29 (+23.3)  loss = 6.4603e-02
# tf_epoch = 266000  elapsed = 43:52 (+23.4)  loss = 6.3332e-02
# tf_epoch = 267000  elapsed = 44:15 (+23.3)  loss = 5.9056e-02
# tf_epoch = 268000  elapsed = 44:39 (+23.3)  loss = 6.4251e-02
# tf_epoch = 269000  elapsed = 45:02 (+23.3)  loss = 6.5315e-02
# tf_epoch = 270000  elapsed = 45:25 (+23.3)  loss = 5.8266e-02
# tf_epoch = 271000  elapsed = 45:49 (+23.3)  loss = 6.0468e-02
# tf_epoch = 272000  elapsed = 46:12 (+23.3)  loss = 6.2645e-02
# tf_epoch = 273000  elapsed = 46:36 (+23.4)  loss = 6.1720e-02
# tf_epoch = 274000  elapsed = 46:59 (+23.5)  loss = 6.1658e-02
# tf_epoch = 275000  elapsed = 47:22 (+23.4)  loss = 5.7949e-02
# tf_epoch = 276000  elapsed = 47:46 (+23.3)  loss = 6.1343e-02
# tf_epoch = 277000  elapsed = 48:09 (+23.3)  loss = 5.6585e-02
# tf_epoch = 278000  elapsed = 48:33 (+23.4)  loss = 5.6400e-02
# tf_epoch = 279000  elapsed = 48:56 (+23.4)  loss = 5.7971e-02
# tf_epoch = 280000  elapsed = 49:19 (+23.3)  loss = 6.0468e-02
# tf_epoch = 281000  elapsed = 49:43 (+23.5)  loss = 6.6258e-02
# tf_epoch = 282000  elapsed = 50:06 (+23.3)  loss = 5.5904e-02
# tf_epoch = 283000  elapsed = 50:30 (+23.3)  loss = 5.8482e-02
# tf_epoch = 284000  elapsed = 50:53 (+23.4)  loss = 6.3713e-02
# tf_epoch = 285000  elapsed = 51:17 (+23.3)  loss = 5.5729e-02
# tf_epoch = 286000  elapsed = 51:40 (+23.3)  loss = 5.8561e-02
# tf_epoch = 287000  elapsed = 52:03 (+23.3)  loss = 5.7415e-02
# tf_epoch = 288000  elapsed = 52:27 (+23.3)  loss = 5.5681e-02
# tf_epoch = 289000  elapsed = 52:50 (+23.3)  loss = 5.4749e-02
# tf_epoch = 290000  elapsed = 53:14 (+23.3)  loss = 6.1147e-02
# tf_epoch = 291000  elapsed = 53:37 (+23.3)  loss = 5.4611e-02
# tf_epoch = 292000  elapsed = 54:00 (+23.3)  loss = 8.9806e-02
# tf_epoch = 293000  elapsed = 54:24 (+23.3)  loss = 6.0374e-02
# tf_epoch = 294000  elapsed = 54:47 (+23.3)  loss = 5.7474e-02
# tf_epoch = 295000  elapsed = 55:10 (+23.3)  loss = 5.2437e-02
# tf_epoch = 296000  elapsed = 55:34 (+23.4)  loss = 5.2641e-02
# tf_epoch = 297000  elapsed = 55:57 (+23.3)  loss = 5.2472e-02
# tf_epoch = 298000  elapsed = 56:21 (+23.3)  loss = 5.6582e-02
# tf_epoch = 299000  elapsed = 56:44 (+23.3)  loss = 5.2357e-02
# -- Starting LBFGS optimization --
# ==================
# Training finished (epoch 300000): duration = 57:07  error = 9.7717e-01

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim(pinn, X_f, X_star, u_star, xlb, xub)

# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
