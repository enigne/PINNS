# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAInformedNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 0
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = False
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN.mat")
modelPath = "./Models/Helheim"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAInformedNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8, 
        loss_weights=[1e-2, 1e-6, 1e-12],
        geoDataNN="./Models/Helheim_H_bed/", 
        FrictionCNN="./Models/Helheim_C/")

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": false,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# WARNING:tensorflow:From ./utils/logger.py:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# train the model
#pinn.fit(X_star, u_star)
pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:20 (+20.6)  loss = 3.0924e+05
# tf_epoch =   1000  elapsed = 00:45 (+24.6)  loss = 4.0823e+04
# tf_epoch =   2000  elapsed = 01:09 (+24.0)  loss = 3.8347e+04
# tf_epoch =   3000  elapsed = 01:33 (+23.7)  loss = 3.7116e+04
# tf_epoch =   4000  elapsed = 01:57 (+24.0)  loss = 3.4251e+04
# tf_epoch =   5000  elapsed = 02:21 (+23.9)  loss = 3.3164e+04
# tf_epoch =   6000  elapsed = 02:45 (+24.3)  loss = 3.0506e+04
# tf_epoch =   7000  elapsed = 03:09 (+23.8)  loss = 2.9121e+04
# tf_epoch =   8000  elapsed = 03:32 (+23.4)  loss = 2.7422e+04
# tf_epoch =   9000  elapsed = 03:56 (+23.7)  loss = 2.1988e+04
# tf_epoch =  10000  elapsed = 04:20 (+23.4)  loss = 1.9865e+04
# tf_epoch =  11000  elapsed = 04:44 (+24.0)  loss = 1.7962e+04
# tf_epoch =  12000  elapsed = 05:07 (+23.4)  loss = 1.7232e+04
# tf_epoch =  13000  elapsed = 05:31 (+23.9)  loss = 1.6602e+04
# tf_epoch =  14000  elapsed = 05:55 (+23.9)  loss = 1.5978e+04
# tf_epoch =  15000  elapsed = 06:19 (+24.0)  loss = 1.5383e+04
# tf_epoch =  16000  elapsed = 06:42 (+23.4)  loss = 1.4907e+04
# tf_epoch =  17000  elapsed = 07:06 (+23.4)  loss = 1.4423e+04
# tf_epoch =  18000  elapsed = 07:29 (+23.5)  loss = 1.4388e+04
# tf_epoch =  19000  elapsed = 07:53 (+23.5)  loss = 1.3474e+04
# tf_epoch =  20000  elapsed = 08:17 (+23.6)  loss = 1.3141e+04
# tf_epoch =  21000  elapsed = 08:40 (+23.7)  loss = 1.2376e+04
# tf_epoch =  22000  elapsed = 09:04 (+23.6)  loss = 1.2647e+04
# tf_epoch =  23000  elapsed = 09:28 (+23.5)  loss = 1.1680e+04
# tf_epoch =  24000  elapsed = 09:51 (+23.8)  loss = 1.1268e+04
# tf_epoch =  25000  elapsed = 10:15 (+23.6)  loss = 1.1586e+04
# tf_epoch =  26000  elapsed = 10:39 (+23.9)  loss = 1.0630e+04
# tf_epoch =  27000  elapsed = 11:03 (+23.6)  loss = 1.0273e+04
# tf_epoch =  28000  elapsed = 11:27 (+23.9)  loss = 1.0010e+04
# tf_epoch =  29000  elapsed = 11:50 (+23.5)  loss = 1.0028e+04
# tf_epoch =  30000  elapsed = 12:14 (+23.8)  loss = 9.4466e+03
# tf_epoch =  31000  elapsed = 12:38 (+23.7)  loss = 9.3034e+03
# tf_epoch =  32000  elapsed = 13:01 (+23.4)  loss = 9.0245e+03
# tf_epoch =  33000  elapsed = 13:25 (+23.4)  loss = 8.9431e+03
# tf_epoch =  34000  elapsed = 13:48 (+23.5)  loss = 8.7780e+03
# tf_epoch =  35000  elapsed = 14:12 (+23.5)  loss = 8.5994e+03
# tf_epoch =  36000  elapsed = 14:35 (+23.7)  loss = 8.2762e+03
# tf_epoch =  37000  elapsed = 14:59 (+23.6)  loss = 8.1121e+03
# tf_epoch =  38000  elapsed = 15:23 (+23.7)  loss = 7.9287e+03
# tf_epoch =  39000  elapsed = 15:47 (+24.0)  loss = 9.2067e+03
# tf_epoch =  40000  elapsed = 16:10 (+23.4)  loss = 7.9315e+03
# tf_epoch =  41000  elapsed = 16:34 (+23.6)  loss = 7.7793e+03
# tf_epoch =  42000  elapsed = 16:58 (+23.7)  loss = 7.5929e+03
# tf_epoch =  43000  elapsed = 17:21 (+23.5)  loss = 7.7038e+03
# tf_epoch =  44000  elapsed = 17:45 (+23.8)  loss = 7.1817e+03
# tf_epoch =  45000  elapsed = 18:09 (+23.7)  loss = 6.9778e+03
# tf_epoch =  46000  elapsed = 18:33 (+23.6)  loss = 6.8137e+03
# tf_epoch =  47000  elapsed = 18:56 (+23.7)  loss = 7.2116e+03
# tf_epoch =  48000  elapsed = 19:20 (+23.9)  loss = 6.7039e+03
# tf_epoch =  49000  elapsed = 19:44 (+23.7)  loss = 7.6216e+03
# tf_epoch =  50000  elapsed = 20:08 (+23.5)  loss = 6.0701e+03
# tf_epoch =  51000  elapsed = 20:31 (+23.7)  loss = 5.7761e+03
# tf_epoch =  52000  elapsed = 20:55 (+23.8)  loss = 5.6349e+03
# tf_epoch =  53000  elapsed = 21:19 (+23.6)  loss = 5.4675e+03
# tf_epoch =  54000  elapsed = 21:42 (+23.4)  loss = 5.6805e+03
# tf_epoch =  55000  elapsed = 22:06 (+23.8)  loss = 6.7563e+03
# tf_epoch =  56000  elapsed = 22:30 (+23.4)  loss = 5.3329e+03
# tf_epoch =  57000  elapsed = 22:53 (+23.6)  loss = 5.4427e+03
# tf_epoch =  58000  elapsed = 23:17 (+23.6)  loss = 5.2698e+03
# tf_epoch =  59000  elapsed = 23:40 (+23.6)  loss = 5.0509e+03
# tf_epoch =  60000  elapsed = 24:04 (+23.6)  loss = 4.9642e+03
# tf_epoch =  61000  elapsed = 24:28 (+23.8)  loss = 5.0386e+03
# tf_epoch =  62000  elapsed = 24:51 (+23.5)  loss = 4.8890e+03
# tf_epoch =  63000  elapsed = 25:15 (+23.6)  loss = 5.5974e+03
# tf_epoch =  64000  elapsed = 25:39 (+23.5)  loss = 4.9668e+03
# tf_epoch =  65000  elapsed = 26:03 (+24.1)  loss = 4.7857e+03
# tf_epoch =  66000  elapsed = 26:27 (+23.8)  loss = 4.7844e+03
# tf_epoch =  67000  elapsed = 26:50 (+23.4)  loss = 5.6817e+03
# tf_epoch =  68000  elapsed = 27:14 (+23.5)  loss = 4.8538e+03
# tf_epoch =  69000  elapsed = 27:37 (+23.4)  loss = 4.8411e+03
# tf_epoch =  70000  elapsed = 28:01 (+23.6)  loss = 4.5948e+03
# tf_epoch =  71000  elapsed = 28:24 (+23.5)  loss = 4.4309e+03
# tf_epoch =  72000  elapsed = 28:48 (+23.6)  loss = 4.2916e+03
# tf_epoch =  73000  elapsed = 29:12 (+23.4)  loss = 4.4605e+03
# tf_epoch =  74000  elapsed = 29:35 (+23.5)  loss = 4.2860e+03
# tf_epoch =  75000  elapsed = 29:59 (+23.9)  loss = 4.1946e+03
# tf_epoch =  76000  elapsed = 30:23 (+23.4)  loss = 4.2772e+03
# tf_epoch =  77000  elapsed = 30:46 (+23.7)  loss = 4.2220e+03
# tf_epoch =  78000  elapsed = 31:10 (+23.5)  loss = 4.1004e+03
# tf_epoch =  79000  elapsed = 31:33 (+23.5)  loss = 3.8870e+03
# tf_epoch =  80000  elapsed = 31:57 (+23.6)  loss = 3.8710e+03
# tf_epoch =  81000  elapsed = 32:21 (+23.6)  loss = 3.8463e+03
# tf_epoch =  82000  elapsed = 32:44 (+23.6)  loss = 3.7250e+03
# tf_epoch =  83000  elapsed = 33:08 (+23.5)  loss = 7.9970e+03
# tf_epoch =  84000  elapsed = 33:31 (+23.4)  loss = 3.7534e+03
# tf_epoch =  85000  elapsed = 33:55 (+23.8)  loss = 3.7216e+03
# tf_epoch =  86000  elapsed = 34:19 (+23.8)  loss = 3.5793e+03
# tf_epoch =  87000  elapsed = 34:43 (+23.4)  loss = 3.5856e+03
# tf_epoch =  88000  elapsed = 35:06 (+23.7)  loss = 3.5339e+03
# tf_epoch =  89000  elapsed = 35:30 (+23.9)  loss = 3.5029e+03
# tf_epoch =  90000  elapsed = 35:54 (+23.6)  loss = 3.3951e+03
# tf_epoch =  91000  elapsed = 36:17 (+23.4)  loss = 3.3381e+03
# tf_epoch =  92000  elapsed = 36:41 (+23.5)  loss = 3.4131e+03
# tf_epoch =  93000  elapsed = 37:05 (+23.7)  loss = 3.3398e+03
# tf_epoch =  94000  elapsed = 37:28 (+23.5)  loss = 3.2938e+03
# tf_epoch =  95000  elapsed = 37:52 (+23.5)  loss = 3.2012e+03
# tf_epoch =  96000  elapsed = 38:16 (+23.8)  loss = 3.2719e+03
# tf_epoch =  97000  elapsed = 38:39 (+23.6)  loss = 3.2020e+03
# tf_epoch =  98000  elapsed = 39:03 (+23.4)  loss = 3.1095e+03
# tf_epoch =  99000  elapsed = 39:27 (+24.0)  loss = 3.0880e+03
# -- Starting LBFGS optimization --
# ==================
# Training finished (epoch 100000): duration = 39:50  error = 8.4616e-01

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim(pinn, X_f, X_star, u_star, xlb, xub)

# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
