# %%
from experiments import *

# %%
inputlist = ["Helheim_Weertman_iT080_PINN_fastflow_CF_1500"] # , "Helheim_Weertman_iT080_PINN_fastflow_CF_1000"] 
outputlist = ["SSA2D_FlightTrackH250"] #, "SSA2D_FlightTrackH500"] 
wfList = [7, 8, 9, 10]

# %%
for s in range(5):
    for i in range(len(inputlist)):
        for wf in wfList:
            experiment_2D_3NN_test((5, 3, 5, wf, 14), epochADAM=500000, seed=None, N_u=4000, N_H=4000, N_C=None, N_f=9000, NNeurons=20, NLayers=6, FlightTrack=True, inputFileName=inputlist[i], outputFileName=outputlist[i])
# Out:
# Use 255 flight track data for the ice thickness training data
# Hyperparameters:
# {
#   "N_u": 4000,
#   "N_s": 4000,
#   "N_H": 4000,
#   "FlightTrack": true,
#   "N_C": null,
#   "N_f": 9000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "h_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "C_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "tf_epochs": 500000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "log_frequency": 10000,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Training set:
#
# uv: (4000, 2)
#
# s: (4000, 1)
#
# H: (797, 1)
#
# C: (542, 1)
#
#
# Training started
# ================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer (MinmaxSc (None, 2)                 6
# _________________________________________________________________
# dense (Dense)                (None, 20)                60
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 42
# _________________________________________________________________
# up_scale_layer (UpScaleLayer (None, 2)                 6
# =================================================================
# Total params: 2,214
# Trainable params: 2,202
# Non-trainable params: 12
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_1 (Minmax (None, 2)                 6
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                60
# _________________________________________________________________
# dense_8 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_9 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 42
# _________________________________________________________________
# up_scale_layer_1 (UpScaleLay (None, 2)                 6
# =================================================================
# Total params: 2,214
# Trainable params: 2,202
# Non-trainable params: 12
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_2 (Minmax (None, 2)                 6
# _________________________________________________________________
# dense_14 (Dense)             (None, 20)                60
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_17 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_18 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_19 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 21
# _________________________________________________________________
# up_scale_layer_2 (UpScaleLay (None, 1)                 4
# =================================================================
# Total params: 2,191
# Trainable params: 2,181
# Non-trainable params: 10
# _________________________________________________________________
# (None, None, None)
# [1.e-05 1.e-03 1.e-05 1.e-07 1.e-14]
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:23 (+23.8)  loss = 4.3168e+05
# tf_epoch =  10000  elapsed = 08:23 (+59.4)  loss = 8.0203e+01
# tf_epoch =  20000  elapsed = 16:21 (+58.1)  loss = 1.7767e+01
# tf_epoch =  30000  elapsed = 24:20 (+59.1)  loss = 1.1985e+01
# tf_epoch =  40000  elapsed = 32:20 (+00.0)  loss = 9.3671e+00
# tf_epoch =  50000  elapsed = 40:19 (+58.5)  loss = 7.9021e+00
# tf_epoch =  60000  elapsed = 48:18 (+59.0)  loss = 6.9347e+00
# tf_epoch =  70000  elapsed = 56:17 (+59.1)  loss = 5.8955e+00
# tf_epoch =  80000  elapsed = 04:16 (+58.9)  loss = 5.3569e+00
# tf_epoch =  90000  elapsed = 12:15 (+59.6)  loss = 4.8555e+00
# tf_epoch = 100000  elapsed = 20:14 (+58.8)  loss = 4.5196e+00
# tf_epoch = 110000  elapsed = 28:13 (+58.9)  loss = 4.1977e+00
# tf_epoch = 120000  elapsed = 36:12 (+59.1)  loss = 4.0144e+00
# tf_epoch = 130000  elapsed = 44:13 (+00.5)  loss = 3.8458e+00
# tf_epoch = 140000  elapsed = 52:11 (+58.1)  loss = 3.6447e+00
# tf_epoch = 150000  elapsed = 00:12 (+00.4)  loss = 3.4742e+00
# tf_epoch = 160000  elapsed = 08:11 (+59.2)  loss = 3.3618e+00
# tf_epoch = 170000  elapsed = 16:10 (+59.0)  loss = 3.2882e+00
# tf_epoch = 180000  elapsed = 24:08 (+58.3)  loss = 3.2541e+00
# tf_epoch = 190000  elapsed = 32:07 (+58.5)  loss = 3.0652e+00
# tf_epoch = 200000  elapsed = 40:05 (+58.7)  loss = 3.0003e+00
# tf_epoch = 210000  elapsed = 48:05 (+59.4)  loss = 2.9241e+00
