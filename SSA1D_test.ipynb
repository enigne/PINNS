# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from utils import *
from equations import *

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 100
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 200
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [1, 20, 20, 20, 20, 20, 20, 20, 20, 4]
hp["h_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
#path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
#path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
#path = os.path.join(appDataPath, "SSA2D_segCF.mat")
#path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow_CF.mat")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_flowline_CF.mat")

modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, Exact_vel, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb, mu = prep_Helheim_data_flowline(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSA1D_calvingfront_invertC(hp, logger, X_f,
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb,
        modelPath, reloadModel,
        mu=mu,
        loss_weights=[1e-5, 1e-3, 1e-5, 1e-8, 1e-14])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)

# train the model
pinn.fit(X_u_train, u_train)
# pinn.fit(X_bc, u_bc)
# Out:
# Hyperparameters:
# {
#   "N_u": 100,
#   "N_f": 200,
#   "layers": [
#     1,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     4
#   ],
#   "h_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "C_layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Training started
# ================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer (MinmaxSc (None, 1)                 4
# _________________________________________________________________
# dense (Dense)                (None, 20)                40
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 84
# _________________________________________________________________
# up_scale_layer (UpScaleLayer (None, 4)                 10
# =================================================================
# Total params: 3,078
# Trainable params: 3,064
# Non-trainable params: 14
# _________________________________________________________________
# None
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:06 (+06.2)  loss = 8.0166e+02
# tf_epoch =   1000  elapsed = 00:12 (+06.4)  loss = 3.9295e+02
# tf_epoch =   2000  elapsed = 00:19 (+06.4)  loss = 7.0539e+02
# tf_epoch =   3000  elapsed = 00:25 (+06.4)  loss = 2.2221e+02
# tf_epoch =   4000  elapsed = 00:32 (+06.4)  loss = 1.7538e+02
# tf_epoch =   5000  elapsed = 00:38 (+06.5)  loss = 1.7042e+02
# tf_epoch =   6000  elapsed = 00:45 (+06.9)  loss = 1.4095e+02
# tf_epoch =   7000  elapsed = 00:53 (+07.5)  loss = 2.3281e+03
# tf_epoch =   8000  elapsed = 01:00 (+07.5)  loss = 1.0831e+03
# tf_epoch =   9000  elapsed = 01:08 (+07.5)  loss = 9.6770e+02
# tf_epoch =  10000  elapsed = 01:15 (+07.4)  loss = 9.2932e+02
# tf_epoch =  11000  elapsed = 01:23 (+07.5)  loss = 9.1015e+02
# tf_epoch =  12000  elapsed = 01:30 (+07.4)  loss = 8.5043e+02
# tf_epoch =  13000  elapsed = 01:37 (+07.2)  loss = 4.7739e+02
# tf_epoch =  14000  elapsed = 01:45 (+07.4)  loss = 2.8096e+02
# tf_epoch =  15000  elapsed = 01:52 (+07.3)  loss = 1.5986e+02
# tf_epoch =  16000  elapsed = 02:00 (+07.3)  loss = 1.1630e+02
# tf_epoch =  17000  elapsed = 02:07 (+07.3)  loss = 1.1157e+02
# tf_epoch =  18000  elapsed = 02:14 (+07.2)  loss = 1.0478e+02
# tf_epoch =  19000  elapsed = 02:22 (+07.3)  loss = 9.1636e+01
# tf_epoch =  20000  elapsed = 02:29 (+07.2)  loss = 6.3836e+01
# tf_epoch =  21000  elapsed = 02:36 (+07.2)  loss = 4.6777e+01
# tf_epoch =  22000  elapsed = 02:44 (+07.3)  loss = 1.3691e+01
# tf_epoch =  23000  elapsed = 02:51 (+07.2)  loss = 1.0387e+01
# tf_epoch =  24000  elapsed = 02:58 (+07.3)  loss = 7.3763e+00
# tf_epoch =  25000  elapsed = 03:05 (+07.3)  loss = 4.6207e+00
# tf_epoch =  26000  elapsed = 03:13 (+07.2)  loss = 4.0793e+00
# tf_epoch =  27000  elapsed = 03:20 (+07.3)  loss = 3.8729e+00
# tf_epoch =  28000  elapsed = 03:27 (+07.2)  loss = 3.7614e+00
# tf_epoch =  29000  elapsed = 03:35 (+07.3)  loss = 3.3284e+00
# tf_epoch =  30000  elapsed = 03:42 (+07.3)  loss = 2.9339e+00
# tf_epoch =  31000  elapsed = 03:49 (+07.4)  loss = 2.4314e+00
# tf_epoch =  32000  elapsed = 03:57 (+07.3)  loss = 2.0661e+00
# tf_epoch =  33000  elapsed = 04:04 (+07.5)  loss = 1.7162e+00
# tf_epoch =  34000  elapsed = 04:12 (+07.3)  loss = 1.7466e+00
# tf_epoch =  35000  elapsed = 04:19 (+07.3)  loss = 1.6915e+00
# tf_epoch =  36000  elapsed = 04:26 (+07.4)  loss = 1.6404e+00
# tf_epoch =  37000  elapsed = 04:34 (+07.4)  loss = 1.6138e+00
# tf_epoch =  38000  elapsed = 04:41 (+07.5)  loss = 1.4727e+00
# tf_epoch =  39000  elapsed = 04:49 (+07.3)  loss = 1.3892e+00
# tf_epoch =  40000  elapsed = 04:56 (+07.3)  loss = 1.5378e+00
# tf_epoch =  41000  elapsed = 05:04 (+07.6)  loss = 1.3388e+00
# tf_epoch =  42000  elapsed = 05:11 (+07.3)  loss = 1.4837e+00
# tf_epoch =  43000  elapsed = 05:18 (+07.3)  loss = 1.2796e+00
# tf_epoch =  44000  elapsed = 05:26 (+07.3)  loss = 1.4004e+00
# tf_epoch =  45000  elapsed = 05:33 (+07.2)  loss = 1.2889e+00
# tf_epoch =  46000  elapsed = 05:40 (+07.4)  loss = 1.3007e+00
# tf_epoch =  47000  elapsed = 05:48 (+07.3)  loss = 1.0920e+00
# tf_epoch =  48000  elapsed = 05:55 (+07.2)  loss = 1.1516e+00
# tf_epoch =  49000  elapsed = 06:02 (+07.3)  loss = 1.1394e+00
# tf_epoch =  50000  elapsed = 06:10 (+07.3)  loss = 1.0731e+00
# tf_epoch =  51000  elapsed = 06:17 (+07.3)  loss = 1.0406e+00
# tf_epoch =  52000  elapsed = 06:24 (+07.4)  loss = 1.0217e+00
# tf_epoch =  53000  elapsed = 06:32 (+07.3)  loss = 8.5246e-01
# tf_epoch =  54000  elapsed = 06:39 (+07.4)  loss = 9.0370e-01
# tf_epoch =  55000  elapsed = 06:47 (+07.4)  loss = 9.5257e-01
# tf_epoch =  56000  elapsed = 06:54 (+07.3)  loss = 9.6519e-01
# tf_epoch =  57000  elapsed = 07:01 (+07.2)  loss = 9.5704e-01
# tf_epoch =  58000  elapsed = 07:09 (+07.3)  loss = 8.3442e-01
# tf_epoch =  59000  elapsed = 07:16 (+07.2)  loss = 9.1096e-01
# tf_epoch =  60000  elapsed = 07:23 (+07.2)  loss = 7.9597e-01
# tf_epoch =  61000  elapsed = 07:31 (+07.3)  loss = 8.7116e-01
# tf_epoch =  62000  elapsed = 07:38 (+07.2)  loss = 8.8931e-01
# tf_epoch =  63000  elapsed = 07:45 (+07.3)  loss = 8.7965e-01
# tf_epoch =  64000  elapsed = 07:52 (+07.2)  loss = 8.2032e-01
# tf_epoch =  65000  elapsed = 08:00 (+07.2)  loss = 8.4834e-01
# tf_epoch =  66000  elapsed = 08:07 (+07.3)  loss = 8.5478e-01
# tf_epoch =  67000  elapsed = 08:14 (+07.2)  loss = 7.7930e-01
# tf_epoch =  68000  elapsed = 08:22 (+07.4)  loss = 8.2057e-01
# tf_epoch =  69000  elapsed = 08:29 (+06.9)  loss = 7.2318e-01
# tf_epoch =  70000  elapsed = 08:36 (+07.2)  loss = 7.1744e-01
# tf_epoch =  71000  elapsed = 08:44 (+07.5)  loss = 7.6954e-01
# tf_epoch =  72000  elapsed = 08:51 (+07.4)  loss = 7.9613e-01
# tf_epoch =  73000  elapsed = 08:58 (+07.3)  loss = 7.6054e-01
# tf_epoch =  74000  elapsed = 09:06 (+07.3)  loss = 1.2362e+00
# tf_epoch =  75000  elapsed = 09:13 (+07.5)  loss = 8.4273e-01
# tf_epoch =  76000  elapsed = 09:21 (+07.6)  loss = 8.6950e-01
# tf_epoch =  77000  elapsed = 09:28 (+07.3)  loss = 7.6417e-01
# tf_epoch =  78000  elapsed = 09:35 (+07.3)  loss = 8.3893e-01
# tf_epoch =  79000  elapsed = 09:43 (+07.3)  loss = 7.1075e-01
# tf_epoch =  80000  elapsed = 09:50 (+07.2)  loss = 7.1693e-01
# tf_epoch =  81000  elapsed = 09:57 (+07.3)  loss = 7.0060e-01
# tf_epoch =  82000  elapsed = 10:05 (+07.3)  loss = 6.9709e-01
# tf_epoch =  83000  elapsed = 10:12 (+07.4)  loss = 6.3377e-01
# tf_epoch =  84000  elapsed = 10:20 (+07.4)  loss = 6.1344e-01
# tf_epoch =  85000  elapsed = 10:27 (+07.3)  loss = 6.3143e-01
# tf_epoch =  86000  elapsed = 10:34 (+07.4)  loss = 6.7012e-01
# tf_epoch =  87000  elapsed = 10:42 (+07.4)  loss = 6.4361e-01
# tf_epoch =  88000  elapsed = 10:49 (+07.3)  loss = 5.7025e-01
# tf_epoch =  89000  elapsed = 10:57 (+07.4)  loss = 5.8687e-01
# tf_epoch =  90000  elapsed = 11:04 (+07.4)  loss = 5.9259e-01
# tf_epoch =  91000  elapsed = 11:12 (+07.4)  loss = 5.5351e-01
# tf_epoch =  92000  elapsed = 11:19 (+07.4)  loss = 6.0340e-01
# tf_epoch =  93000  elapsed = 11:27 (+07.3)  loss = 5.3349e-01
# tf_epoch =  94000  elapsed = 11:34 (+07.4)  loss = 5.9323e-01
# tf_epoch =  95000  elapsed = 11:41 (+07.3)  loss = 5.1377e-01
# tf_epoch =  96000  elapsed = 11:49 (+07.5)  loss = 5.6488e-01
# tf_epoch =  97000  elapsed = 11:56 (+07.4)  loss = 5.1956e-01
# tf_epoch =  98000  elapsed = 12:04 (+07.5)  loss = 4.9259e-01
# tf_epoch =  99000  elapsed = 12:11 (+07.4)  loss = 4.7374e-01
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =   1000  elapsed = 12:38 (+26.4)  loss = 4.2980e-01
# nt_epoch =   2000  elapsed = 12:55 (+17.3)  loss = 4.1754e-01
# nt_epoch =   3000  elapsed = 13:13 (+17.9)  loss = 4.0155e-01
# nt_epoch =   4000  elapsed = 13:30 (+17.3)  loss = 3.8149e-01
# nt_epoch =   5000  elapsed = 13:47 (+16.9)  loss = 3.6538e-01
# nt_epoch =   6000  elapsed = 14:04 (+17.0)  loss = 3.5717e-01
# nt_epoch =   7000  elapsed = 14:21 (+16.9)  loss = 3.5056e-01
# nt_epoch =   8000  elapsed = 14:38 (+16.9)  loss = 3.4443e-01
# nt_epoch =   9000  elapsed = 14:55 (+17.1)  loss = 3.3527e-01
# nt_epoch =  10000  elapsed = 15:13 (+17.1)  loss = 3.2810e-01
# nt_epoch =  11000  elapsed = 15:29 (+16.7)  loss = 3.1939e-01
# nt_epoch =  12000  elapsed = 15:46 (+16.5)  loss = 3.1368e-01
# nt_epoch =  13000  elapsed = 16:03 (+16.8)  loss = 3.0730e-01
# nt_epoch =  14000  elapsed = 16:20 (+17.2)  loss = 3.0394e-01
# nt_epoch =  15000  elapsed = 16:37 (+17.2)  loss = 3.0170e-01
# nt_epoch =  16000  elapsed = 16:54 (+16.7)  loss = 2.9836e-01
# nt_epoch =  17000  elapsed = 17:11 (+17.2)  loss = 2.9549e-01
# nt_epoch =  18000  elapsed = 17:28 (+17.1)  loss = 2.8990e-01
# nt_epoch =  19000  elapsed = 17:45 (+17.0)  loss = 2.8412e-01
# nt_epoch =  20000  elapsed = 18:02 (+16.8)  loss = 2.8055e-01
# nt_epoch =  21000  elapsed = 18:19 (+16.8)  loss = 2.7703e-01
# nt_epoch =  22000  elapsed = 18:36 (+17.0)  loss = 2.7370e-01
# nt_epoch =  23000  elapsed = 18:53 (+17.1)  loss = 2.7060e-01
# nt_epoch =  24000  elapsed = 19:10 (+16.9)  loss = 2.6813e-01
# nt_epoch =  25000  elapsed = 19:27 (+16.8)  loss = 2.6598e-01
# nt_epoch =  26000  elapsed = 19:44 (+16.9)  loss = 2.6389e-01
# nt_epoch =  27000  elapsed = 20:01 (+17.2)  loss = 2.6176e-01
# nt_epoch =  28000  elapsed = 20:18 (+17.1)  loss = 2.6013e-01
# nt_epoch =  29000  elapsed = 20:35 (+16.9)  loss = 2.5863e-01
# nt_epoch =  30000  elapsed = 20:52 (+16.8)  loss = 2.5682e-01
# nt_epoch =  31000  elapsed = 21:09 (+16.9)  loss = 2.5438e-01
# nt_epoch =  32000  elapsed = 21:26 (+16.7)  loss = 2.5276e-01
# nt_epoch =  33000  elapsed = 21:43 (+17.0)  loss = 2.5137e-01
# nt_epoch =  34000  elapsed = 22:00 (+16.6)  loss = 2.4954e-01
# nt_epoch =  35000  elapsed = 22:17 (+17.0)  loss = 2.4802e-01
# nt_epoch =  36000  elapsed = 22:34 (+17.0)  loss = 2.4567e-01
# nt_epoch =  37000  elapsed = 22:51 (+17.0)  loss = 2.4417e-01
# nt_epoch =  38000  elapsed = 23:07 (+16.4)  loss = 2.4219e-01
# nt_epoch =  39000  elapsed = 23:24 (+16.5)  loss = 2.4046e-01
# nt_epoch =  40000  elapsed = 23:41 (+16.8)  loss = 2.3857e-01
# nt_epoch =  41000  elapsed = 23:57 (+16.7)  loss = 2.3679e-01
# nt_epoch =  42000  elapsed = 24:14 (+16.9)  loss = 2.3564e-01
# nt_epoch =  43000  elapsed = 24:32 (+17.3)  loss = 2.3446e-01
# nt_epoch =  44000  elapsed = 24:49 (+17.2)  loss = 2.3328e-01
# nt_epoch =  45000  elapsed = 25:06 (+17.3)  loss = 2.3227e-01
# nt_epoch =  46000  elapsed = 25:23 (+17.2)  loss = 2.3139e-01
# nt_epoch =  47000  elapsed = 25:41 (+17.0)  loss = 2.3017e-01
# nt_epoch =  48000  elapsed = 25:58 (+17.4)  loss = 2.2928e-01
# nt_epoch =  49000  elapsed = 26:15 (+17.3)  loss = 2.2827e-01
# ==================
# Training finished (epoch 150000): duration = 26:21  error = 6.4139e-01

# %%
# plot
plot_1D_solutions_all(pinn, X_f, X_star, u_star, xlb, xub)

# history
plot_log_history(pinn)

# %%
X_cf
# Out:
# array([91850.35135099])
