# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from utils import *
from equations import *

# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 100
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 500
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [1, 20, 20, 20, 20, 1]
hp["h_layers"] = [1, 20, 20, 20, 20, 2]
hp["C_layers"] = [1, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 50000
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 10000
hp["use_tfp"] = True
# Record the history
hp["save_history"] = True
hp["history_frequency"] = 10
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
#path = os.path.join(appDataPath, "SSA2D_nocalving.mat")
#path = os.path.join(appDataPath, "SSA2D_seg_nocalving.mat")
#path = os.path.join(appDataPath, "SSA2D_segCF.mat")
#path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_fastflow_CF.mat")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN_flowline_CF_2dInv.mat")

modelPath = "./Models/test"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, Exact_vel, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb, mu = prep_Helheim_data_flowline(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
# pinn = SSA1D_calvingfront_invertC(hp, logger, X_f,
pinn = SSA1D_3NN_solve_vel(hp, logger, X_f,
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb,
        modelPath, reloadModel,
        mu=mu,
        loss_weights=[1e-5, 1e-5, 1e-3, 1e-8, 1e-10])

X_u = pinn.tensor(X_star)
u = pinn.tensor(u_star)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)

# train the model
pinn.fit(X_u_train, u_train)
# pinn.fit(X_bc, u_bc)
# Out:
# Hyperparameters:
# {
#   "N_u": 100,
#   "N_f": 500,
#   "layers": [
#     1,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "h_layers": [
#     1,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "C_layers": [
#     1,
#     20,
#     20,
#     20,
#     20,
#     1
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 50000,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 10000,
#   "use_tfp": true,
#   "save_history": true,
#   "history_frequency": 10
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# GPU-accerelated: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Training started
# ================
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer (MinmaxSc (None, 1)                 4
# _________________________________________________________________
# dense (Dense)                (None, 20)                40
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# _________________________________________________________________
# up_scale_layer (UpScaleLayer (None, 1)                 4
# =================================================================
# Total params: 1,329
# Trainable params: 1,321
# Non-trainable params: 8
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_1 (Minmax (None, 1)                 4
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_8 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 42
# _________________________________________________________________
# up_scale_layer_1 (UpScaleLay (None, 2)                 6
# =================================================================
# Total params: 1,352
# Trainable params: 1,342
# Non-trainable params: 10
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# minmax_scale_layer_2 (Minmax (None, 1)                 4
# _________________________________________________________________
# dense_10 (Dense)             (None, 20)                40
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_12 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_13 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 21
# _________________________________________________________________
# up_scale_layer_2 (UpScaleLay (None, 1)                 4
# =================================================================
# Total params: 1,329
# Trainable params: 1,321
# Non-trainable params: 8
# _________________________________________________________________
# (None, None, None)
# [1.e-05 1.e-05 1.e-03 1.e-08 1.e-10]
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:07 (+07.1)  loss = 2.3227e+08
# tf_epoch =  10000  elapsed = 01:12 (+05.8)  loss = 2.9840e+02
# tf_epoch =  20000  elapsed = 02:17 (+04.9)  loss = 4.6889e+01
# tf_epoch =  30000  elapsed = 03:17 (+59.3)  loss = 4.0094e+01
# tf_epoch =  40000  elapsed = 04:16 (+59.4)  loss = 8.6625e+00
# tf_epoch =  50000  elapsed = 05:16 (+59.6)  loss = 1.0196e+01
# tf_epoch =  60000  elapsed = 06:15 (+59.3)  loss = 9.0215e+00
# tf_epoch =  70000  elapsed = 07:15 (+59.3)  loss = 7.6863e+00
# tf_epoch =  80000  elapsed = 08:14 (+59.4)  loss = 6.8267e+00
# tf_epoch =  90000  elapsed = 09:13 (+59.1)  loss = 6.6729e+00
# -- Starting tfp-L-BFGS optimization --
# nt_epoch =  10000  elapsed = 12:36 (+22.2)  loss = 3.9216e+00
# nt_epoch =  20000  elapsed = 14:56 (+20.2)  loss = 3.6364e+00
# nt_epoch =  30000  elapsed = 17:16 (+20.1)  loss = 2.4179e+00
# nt_epoch =  40000  elapsed = 19:37 (+21.0)  loss = 2.0954e+00
# ==================
# Training finished (epoch 150000): duration = 21:31  error = 9.6016e-01

# %%
# plot
plot_1D_solutions_all(pinn, X_f, X_star, u_star, xlb, xub)

# history
plot_log_history(pinn)
