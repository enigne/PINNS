# %%
import sys
import os
import tensorflow as tf
import numpy as np
sys.path.append(".")
sys.path.append("./utils")
from custom_lbfgs import *
from SSAutil import *
from neuralnetwork import NeuralNetwork, MinmaxScaleLayer, UpScaleLayer
from SSA_equations.SSANN import SSAInformedNN
from logger import Logger
from plotting import *
import matplotlib.pyplot as plt

# %%
# Manually making sure the numpy random seeds are "the same" on all devices
np.random.seed(1234)
tf.random.set_seed(1234)

# Hyper parameters {{{
hp = {}
# Data size on the solution u
hp["N_u"] = 3000
# Collocation points size, where we’ll check for f = 0
hp["N_f"] = 1000
# DeepNN topology (2-sized input [x t], 8 hidden layer of 20-width, 1-sized output [u]
hp["layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 2]
#hp["C_layers"] = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]
# Setting up the TF SGD-based optimizer (set tf_epochs=0 to cancel it)
hp["tf_epochs"] = 100000
hp["tf_lr"] = 0.001
hp["tf_b1"] = 0.99
hp["tf_eps"] = 1e-1
# Setting up the quasi-newton LBGFS optimizer (set nt_epochs=0 to cancel it)
hp["nt_epochs"] = 0
hp["nt_lr"] = 0.8
hp["nt_ncorr"] = 50
hp["log_frequency"] = 1000
hp["use_tfp"] = False
# Record the history
hp["save_history"] = True
# path for loading data and saving models
repoPath = "./"
appDataPath = os.path.join(repoPath, "matlab_SSA", "DATA")
path = os.path.join(appDataPath, "Helheim_Weertman_iT080_PINN.mat")
modelPath = "./Models/Helheim"
reloadModel = False # reload from previous training
#}}}

# %%
# load the data
x, y, Exact_vx, Exact_vy, X_star, u_star, X_u_train, u_train, X_f, X_bc, u_bc, X_cf, n_cf, xub, xlb, uub, ulb = prep_Helheim_data(path, hp["N_u"], hp["N_f"])

# Creating the model and training
logger = Logger(hp)
pinn = SSAInformedNN(hp, logger, X_f, 
        X_bc, u_bc,
        X_cf, n_cf,
        xub, xlb, uub, ulb, 
        modelPath, reloadModel,
        eta=1.8157e8, 
        loss_weights=[1e-2, 1e-8, 1e-12],
        geoDataNN="./Models/Helheim_H_bed/", 
        FrictionCNN="./Models/Helheim_C/")

X_u = pinn.tensor(X_u_train)
u = pinn.tensor(u_train)
# error function for logger
def error():
    return pinn.test_error(X_u, u)
logger.set_error_fn(error)
# Out:
# Hyperparameters:
# {
#   "N_u": 3000,
#   "N_f": 1000,
#   "layers": [
#     2,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     20,
#     2
#   ],
#   "tf_epochs": 100000,
#   "tf_lr": 0.001,
#   "tf_b1": 0.99,
#   "tf_eps": 0.1,
#   "nt_epochs": 0,
#   "nt_lr": 0.8,
#   "nt_ncorr": 50,
#   "log_frequency": 1000,
#   "use_tfp": false,
#   "save_history": true
# }
#
# TensorFlow version: 2.4.1
# Eager execution: True
# WARNING:tensorflow:From ./utils/logger.py:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU-accerelated: True
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# train the model
#pinn.fit(X_star, u_star)
pinn.fit(X_bc, u_bc)

# save
#pinn.model.save("./Models/SSA2D_friction_1e_4_TF"+str(hp["tf_epochs"]) +"_NT"+str(hp["nt_epochs"]))
# Out:
# Training started
# ================
# -- Starting Adam optimization --
# tf_epoch =      0  elapsed = 00:19 (+19.7)  loss = 1.9070e+05
# tf_epoch =   1000  elapsed = 00:42 (+23.2)  loss = 2.1168e+04
# tf_epoch =   2000  elapsed = 01:06 (+23.1)  loss = 2.0389e+04
# tf_epoch =   3000  elapsed = 01:29 (+23.1)  loss = 1.8599e+04
# tf_epoch =   4000  elapsed = 01:52 (+23.3)  loss = 1.2265e+04
# tf_epoch =   5000  elapsed = 02:15 (+23.1)  loss = 1.0104e+04
# tf_epoch =   6000  elapsed = 02:38 (+23.1)  loss = 9.4153e+03
# tf_epoch =   7000  elapsed = 03:02 (+23.1)  loss = 7.8214e+03
# tf_epoch =   8000  elapsed = 03:25 (+23.1)  loss = 1.0438e+04
# tf_epoch =   9000  elapsed = 03:48 (+23.1)  loss = 7.0403e+03
# tf_epoch =  10000  elapsed = 04:11 (+23.1)  loss = 6.5896e+03
# tf_epoch =  11000  elapsed = 04:34 (+23.1)  loss = 5.6854e+03
# tf_epoch =  12000  elapsed = 04:57 (+23.1)  loss = 5.5687e+03
# tf_epoch =  13000  elapsed = 05:21 (+23.1)  loss = 5.3248e+03
# tf_epoch =  14000  elapsed = 05:44 (+23.1)  loss = 5.4429e+03
# tf_epoch =  15000  elapsed = 06:07 (+23.1)  loss = 5.1069e+03
# tf_epoch =  16000  elapsed = 06:30 (+23.1)  loss = 4.9328e+03
# tf_epoch =  17000  elapsed = 06:53 (+23.1)  loss = 5.0213e+03
# tf_epoch =  18000  elapsed = 07:16 (+23.1)  loss = 4.5616e+03
# tf_epoch =  19000  elapsed = 07:40 (+23.1)  loss = 4.3376e+03
# tf_epoch =  20000  elapsed = 08:03 (+23.1)  loss = 4.2188e+03
# tf_epoch =  21000  elapsed = 08:26 (+23.1)  loss = 4.3415e+03
# tf_epoch =  22000  elapsed = 08:49 (+23.1)  loss = 4.0080e+03
# tf_epoch =  23000  elapsed = 09:12 (+23.1)  loss = 3.3758e+03
# tf_epoch =  24000  elapsed = 09:35 (+23.1)  loss = 3.7124e+03
# tf_epoch =  25000  elapsed = 09:59 (+23.1)  loss = 3.1995e+03
# tf_epoch =  26000  elapsed = 10:22 (+23.1)  loss = 3.4637e+03
# tf_epoch =  27000  elapsed = 10:45 (+23.1)  loss = 3.0620e+03
# tf_epoch =  28000  elapsed = 11:08 (+23.1)  loss = 2.9249e+03
# tf_epoch =  29000  elapsed = 11:31 (+23.1)  loss = 3.3425e+03
# tf_epoch =  30000  elapsed = 11:54 (+23.1)  loss = 2.8736e+03
# tf_epoch =  31000  elapsed = 12:18 (+23.1)  loss = 2.6808e+03
# tf_epoch =  32000  elapsed = 12:41 (+23.1)  loss = 2.7939e+03
# tf_epoch =  33000  elapsed = 13:04 (+23.1)  loss = 2.5760e+03
# tf_epoch =  34000  elapsed = 13:27 (+23.1)  loss = 3.1415e+03
# tf_epoch =  35000  elapsed = 13:50 (+23.1)  loss = 3.1946e+03
# tf_epoch =  36000  elapsed = 14:13 (+23.1)  loss = 3.1350e+03
# tf_epoch =  37000  elapsed = 14:37 (+23.1)  loss = 2.5444e+03
# tf_epoch =  38000  elapsed = 15:00 (+23.1)  loss = 2.4099e+03
# tf_epoch =  39000  elapsed = 15:23 (+23.1)  loss = 2.3840e+03
# tf_epoch =  40000  elapsed = 15:46 (+23.1)  loss = 2.4472e+03
# tf_epoch =  41000  elapsed = 16:09 (+23.1)  loss = 2.7405e+03
# tf_epoch =  42000  elapsed = 16:33 (+23.1)  loss = 2.4123e+03
# tf_epoch =  43000  elapsed = 16:56 (+23.1)  loss = 2.2939e+03
# tf_epoch =  44000  elapsed = 17:19 (+23.1)  loss = 2.3040e+03
# tf_epoch =  45000  elapsed = 17:42 (+23.1)  loss = 2.4991e+03
# tf_epoch =  46000  elapsed = 18:05 (+23.1)  loss = 2.4426e+03
# tf_epoch =  47000  elapsed = 18:28 (+23.1)  loss = 2.3652e+03
# tf_epoch =  48000  elapsed = 18:52 (+23.1)  loss = 2.4961e+03
# tf_epoch =  49000  elapsed = 19:15 (+23.1)  loss = 2.1887e+03
# tf_epoch =  50000  elapsed = 19:38 (+23.1)  loss = 2.4635e+03
# tf_epoch =  51000  elapsed = 20:01 (+23.1)  loss = 2.2819e+03
# tf_epoch =  52000  elapsed = 20:24 (+23.1)  loss = 2.1525e+03
# tf_epoch =  53000  elapsed = 20:47 (+23.1)  loss = 2.4594e+03
# tf_epoch =  54000  elapsed = 21:11 (+23.1)  loss = 2.1848e+03
# tf_epoch =  55000  elapsed = 21:34 (+23.1)  loss = 2.4168e+03
# tf_epoch =  56000  elapsed = 21:57 (+23.1)  loss = 2.1181e+03
# tf_epoch =  57000  elapsed = 22:20 (+23.1)  loss = 2.0731e+03
# tf_epoch =  58000  elapsed = 22:43 (+23.1)  loss = 2.0737e+03
# tf_epoch =  59000  elapsed = 23:07 (+23.1)  loss = 2.1331e+03
# tf_epoch =  60000  elapsed = 23:30 (+23.1)  loss = 1.8363e+03
# tf_epoch =  61000  elapsed = 23:53 (+23.1)  loss = 1.7945e+03
# tf_epoch =  62000  elapsed = 24:16 (+23.1)  loss = 1.7424e+03
# tf_epoch =  63000  elapsed = 24:39 (+23.1)  loss = 1.7058e+03
# tf_epoch =  64000  elapsed = 25:02 (+23.1)  loss = 1.6090e+03
# tf_epoch =  65000  elapsed = 25:26 (+23.1)  loss = 1.6619e+03
# tf_epoch =  66000  elapsed = 25:49 (+23.1)  loss = 1.5441e+03
# tf_epoch =  67000  elapsed = 26:12 (+23.1)  loss = 1.4735e+03
# tf_epoch =  68000  elapsed = 26:35 (+23.1)  loss = 1.5503e+03
# tf_epoch =  69000  elapsed = 26:58 (+23.1)  loss = 1.5033e+03
# tf_epoch =  70000  elapsed = 27:21 (+23.1)  loss = 1.4190e+03
# tf_epoch =  71000  elapsed = 27:45 (+23.1)  loss = 1.3932e+03
# tf_epoch =  72000  elapsed = 28:08 (+23.1)  loss = 1.4003e+03
# tf_epoch =  73000  elapsed = 28:31 (+23.1)  loss = 1.4432e+03
# tf_epoch =  74000  elapsed = 28:54 (+23.1)  loss = 1.4942e+03
# tf_epoch =  75000  elapsed = 29:17 (+23.1)  loss = 1.3049e+03
# tf_epoch =  76000  elapsed = 29:41 (+23.1)  loss = 1.3201e+03
# tf_epoch =  77000  elapsed = 30:04 (+23.1)  loss = 1.5532e+03
# tf_epoch =  78000  elapsed = 30:27 (+23.1)  loss = 1.4308e+03
# tf_epoch =  79000  elapsed = 30:50 (+23.1)  loss = 1.2809e+03
# tf_epoch =  80000  elapsed = 31:13 (+23.2)  loss = 1.3056e+03
# tf_epoch =  81000  elapsed = 31:36 (+23.1)  loss = 1.2882e+03
# tf_epoch =  82000  elapsed = 32:00 (+23.1)  loss = 1.3860e+03
# tf_epoch =  83000  elapsed = 32:23 (+23.1)  loss = 1.2531e+03
# tf_epoch =  84000  elapsed = 32:46 (+23.1)  loss = 1.4051e+03
# tf_epoch =  85000  elapsed = 33:09 (+23.1)  loss = 1.3866e+03
# tf_epoch =  86000  elapsed = 33:32 (+23.1)  loss = 1.3429e+03
# tf_epoch =  87000  elapsed = 33:56 (+23.1)  loss = 1.3489e+03
# tf_epoch =  88000  elapsed = 34:19 (+23.1)  loss = 1.2015e+03
# tf_epoch =  89000  elapsed = 34:42 (+23.1)  loss = 1.1899e+03
# tf_epoch =  90000  elapsed = 35:05 (+23.1)  loss = 1.2405e+03
# tf_epoch =  91000  elapsed = 35:28 (+23.1)  loss = 1.3813e+03
# tf_epoch =  92000  elapsed = 35:51 (+23.1)  loss = 1.1994e+03
# tf_epoch =  93000  elapsed = 36:15 (+23.1)  loss = 1.3334e+03
# tf_epoch =  94000  elapsed = 36:38 (+23.1)  loss = 1.2597e+03
# tf_epoch =  95000  elapsed = 37:01 (+23.1)  loss = 1.2391e+03
# tf_epoch =  96000  elapsed = 37:24 (+23.1)  loss = 1.3636e+03
# tf_epoch =  97000  elapsed = 37:47 (+23.1)  loss = 1.1712e+03
# tf_epoch =  98000  elapsed = 38:11 (+23.1)  loss = 1.1202e+03
# tf_epoch =  99000  elapsed = 38:34 (+23.1)  loss = 1.3219e+03
# -- Starting LBFGS optimization --
# ==================
# Training finished (epoch 100000): duration = 38:57  error = 8.1004e-01

# %%
# plot
#plot_Helheim(pinn, X_f, X_u_train, u_train, xlb, xub)
plot_Helheim(pinn, X_f, X_star, u_star, xlb, xub)

# fit the data
#pinn.fit(X_u_train, u_train)
#u_pred, v_pred = pinn.predict(X_star)

# test
#plot_H_bed(pinn, X_star, u_star, xlb, xub)
